# %%
import sqlite3
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### setup DBs connection

# %%
#Setup Connection with the 1st DBs
conn = sqlite3.connect('databases/deliveroo.db')
# Attach the other two databases
conn.execute("ATTACH DATABASE 'databases/takeaway.db' AS tw;")
conn.execute("ATTACH DATABASE 'databases/ubereats.db' AS ue;")

# Verify attached databases
databases = conn.execute("PRAGMA database_list;").fetchall()
print("Attached Databases:")
for db in databases:
    print(db)
# Out:
# Attached Databases:
# (0, 'main', 'd:\\Becode\\delivery-market-analysis-with-SQL\\databases\\deliveroo.db')
# (2, 'tw', 'd:\\Becode\\delivery-market-analysis-with-SQL\\databases\\takeaway.db')
# (3, 'ue', 'd:\\Becode\\delivery-market-analysis-with-SQL\\databases\\ubereats.db')

# %% [markdown]
# #### How do delivery fees vary across platforms and locations?

# %%
## takeaway

try:
    takeAwy ="""SELECT
                        tw.locations.postalCode,
                        ROUND(AVG(tw.restaurants.deliveryFee),2) as delivery_fee
                    FROM
                        tw.restaurants
                    INNER JOIN
                        tw.locations_to_restaurants
                    ON
                        tw.restaurants.primarySlug = tw.locations_to_restaurants.restaurant_id
                    INNER JOIN
                        tw.locations
                    ON
                        tw.locations_to_restaurants.location_id = tw.locations.ID
                    WHERE
                        tw.locations.postalCode IS NOT NULL
                        AND tw.restaurants.deliveryFee IS NOT NULL
                    GROUP BY
                        tw.locations.postalCode
                    ORDER BY
                delivery_fee DESC;"""
    takeAwy_results = conn.execute(takeAwy).fetchall()
    for row in takeAwy_results:
        print(row)

except sqlite3.OperationalError as e:
    print("Error:", e)
# Out:
# (3791, 7.13)
# (3793, 6.0)
# (3061, 5.86)
# (9688, 5.6)
# (3792, 5.58)
# (3717, 5.4)
# (3790, 5.18)
# (1761, 5.18)
# (1750, 5.11)
# (1755, 4.9)
# (1741, 4.85)
# (3640, 4.76)
# (3806, 4.74)
# (1671, 4.71)
# (3803, 4.69)
# (1742, 4.52)
# (3960, 4.46)
# (3798, 4.46)
# (9690, 4.44)
# (9681, 4.43)
# (1602, 4.43)
# (9031, 4.4)
# (9820, 4.36)
# (9051, 4.35)
# (9070, 4.3)
# (9030, 4.3)
# (1701, 4.3)
# (3891, 4.29)
# (9032, 4.23)
# (9040, 4.22)
# (1760, 4.15)
# (1600, 4.14)
# (9050, 4.13)
# (2030, 4.06)
# (9000, 4.05)
# (8570, 4.03)
# (8511, 4.03)
# (8710, 4.02)
# (3680, 4.02)
# (3440, 4.02)
# (9881, 4.0)
# (9680, 4.0)
# (8851, 4.0)
# (8470, 3.99)
# (1700, 3.97)
# (8780, 3.95)
# (3890, 3.95)
# (9041, 3.93)
# (1620, 3.93)
# (9052, 3.9)
# (8810, 3.89)
# (3404, 3.88)
# (2050, 3.85)
# (8340, 3.83)
# (3870, 3.82)
# (8850, 3.79)
# (8791, 3.79)
# (3545, 3.79)
# (3080, 3.76)
# (8020, 3.74)
# (9970, 3.73)
# (9968, 3.72)
# (1703, 3.72)
# (2020, 3.68)
# (2000, 3.68)
# (9961, 3.67)
# (3090, 3.66)
# (1670, 3.66)
# (8531, 3.64)
# (9971, 3.63)
# (1560, 3.63)
# (3040, 3.62)
# (2060, 3.62)
# (1740, 3.61)
# (1140, 3.6)
# (8200, 3.58)
# (3078, 3.58)
# (2018, 3.57)
# (9600, 3.55)
# (3401, 3.54)
# (1541, 3.54)
# (8310, 3.53)
# (2170, 3.53)
# (1654, 3.53)
# (1652, 3.53)
# (2140, 3.51)
# (8000, 3.5)
# (3700, 3.5)
# (3071, 3.5)
# (3950, 3.49)
# (8530, 3.48)
# (2600, 3.48)
# (8540, 3.47)
# (8460, 3.47)
# (8792, 3.46)
# (9506, 3.44)
# (3400, 3.43)
# (1601, 3.43)
# (3940, 3.4)
# (3473, 3.4)
# (2070, 3.4)
# (8790, 3.38)
# (3450, 3.38)
# (8510, 3.35)
# (3800, 3.35)
# (1932, 3.35)
# (8573, 3.33)
# (8572, 3.33)
# (3668, 3.33)
# (1933, 3.33)
# (1547, 3.33)
# (9500, 3.3)
# (8600, 3.3)
# (1630, 3.3)
# (2910, 3.29)
# (1650, 3.29)
# (1501, 3.27)
# (8730, 3.26)
# (1800, 3.26)
# (3384, 3.24)
# (2100, 3.24)
# (1785, 3.22)
# (9401, 3.21)
# (3930, 3.21)
# (9772, 3.2)
# (1702, 3.2)
# (9771, 3.18)
# (8760, 3.18)
# (1651, 3.18)
# (8950, 3.17)
# (3990, 3.17)
# (3540, 3.17)
# (1730, 3.17)
# (3650, 3.16)
# (3070, 3.16)
# (8520, 3.15)
# (1970, 3.15)
# (1731, 3.14)
# (9980, 3.13)
# (8770, 3.13)
# (8700, 3.13)
# (3060, 3.13)
# (1831, 3.13)
# (3850, 3.12)
# (1500, 3.12)
# (9770, 3.11)
# (8740, 3.11)
# (8580, 3.11)
# (1861, 3.11)
# (8500, 3.1)
# (3670, 3.1)
# (3970, 3.09)
# (9790, 3.08)
# (9571, 3.08)
# (8432, 3.08)
# (3941, 3.07)
# (8800, 3.06)
# (3770, 3.05)
# (1653, 3.05)
# (9406, 3.04)
# (8550, 3.04)
# (8750, 3.03)
# (9870, 3.02)
# (8720, 3.02)
# (8951, 3.0)
# (8647, 3.0)
# (8640, 3.0)
# (9090, 2.99)
# (8560, 2.99)
# (1930, 2.98)
# (1502, 2.98)
# (1981, 2.97)
# (1950, 2.97)
# (9403, 2.96)
# (8450, 2.96)
# (3454, 2.96)
# (8755, 2.95)
# (3832, 2.95)
# (8582, 2.93)
# (3660, 2.93)
# (3582, 2.93)
# (3210, 2.93)
# (3202, 2.93)
# (8870, 2.92)
# (3460, 2.92)
# (1540, 2.92)
# (3470, 2.91)
# (9400, 2.9)
# (8501, 2.9)
# (3360, 2.89)
# (1770, 2.89)
# (8860, 2.88)
# (1853, 2.87)
# (2640, 2.84)
# (1780, 2.84)
# (9880, 2.83)
# (3220, 2.83)
# (3560, 2.82)
# (1640, 2.82)
# (9402, 2.81)
# (1745, 2.8)
# (1570, 2.8)
# (9661, 2.79)
# (3900, 2.79)
# (9991, 2.78)
# (8400, 2.78)
# (2811, 2.78)
# (9960, 2.77)
# (8830, 2.77)
# (3212, 2.77)
# (3971, 2.76)
# (2150, 2.75)
# (8880, 2.74)
# (3461, 2.74)
# (3050, 2.74)
# (1980, 2.73)
# (3020, 2.71)
# (2660, 2.7)
# (3530, 2.69)
# (3550, 2.68)
# (9660, 2.67)
# (1851, 2.67)
# (1790, 2.67)
# (9900, 2.66)
# (1830, 2.66)
# (3910, 2.65)
# (9404, 2.64)
# (8680, 2.64)
# (9910, 2.61)
# (9700, 2.6)
# (8840, 2.6)
# (8581, 2.59)
# (2610, 2.59)
# (3665, 2.58)
# (3001, 2.56)
# (2812, 2.56)
# (9931, 2.55)
# (9921, 2.55)
# (3000, 2.55)
# (1860, 2.55)
# (9570, 2.54)
# (8210, 2.54)
# (2900, 2.54)
# (9060, 2.53)
# (2160, 2.52)
# (3012, 2.51)
# (8957, 2.5)
# (8890, 2.5)
# (3920, 2.5)
# (1674, 2.5)
# (3830, 2.49)
# (1820, 2.48)
# (9940, 2.47)
# (3600, 2.47)
# (3010, 2.47)
# (3350, 2.46)
# (9572, 2.45)
# (2820, 2.45)
# (1673, 2.45)
# (8650, 2.44)
# (8211, 2.44)
# (9470, 2.43)
# (3300, 2.43)
# (3290, 2.43)
# (1982, 2.43)
# (8480, 2.42)
# (3840, 2.42)
# (8553, 2.4)
# (8930, 2.39)
# (3740, 2.39)
# (3580, 2.39)
# (1880, 2.37)
# (8490, 2.36)
# (3831, 2.36)
# (9800, 2.35)
# (8377, 2.35)
# (3271, 2.35)
# (1852, 2.35)
# (3520, 2.33)
# (3052, 2.33)
# (3053, 2.31)
# (9636, 2.3)
# (9240, 2.3)
# (3293, 2.3)
# (9890, 2.29)
# (3051, 2.29)
# (2800, 2.29)
# (3191, 2.28)
# (3200, 2.27)
# (9850, 2.26)
# (2860, 2.26)
# (9255, 2.25)
# (8954, 2.25)
# (3630, 2.25)
# (3471, 2.25)
# (8610, 2.22)
# (8300, 2.22)
# (3270, 2.22)
# (1910, 2.22)
# (9831, 2.21)
# (3732, 2.21)
# (3690, 2.2)
# (3945, 2.18)
# (2490, 2.18)
# (3590, 2.17)
# (9472, 2.16)
# (9185, 2.16)
# (3620, 2.15)
# (9750, 2.14)
# (8587, 2.13)
# (8554, 2.13)
# (2920, 2.13)
# (9990, 2.12)
# (3272, 2.1)
# (3190, 2.1)
# (9042, 2.09)
# (2890, 2.09)
# (8630, 2.07)
# (8301, 2.07)
# (9180, 2.06)
# (8551, 2.06)
# (3320, 2.05)
# (1840, 2.05)
# (9810, 2.04)
# (3723, 2.04)
# (2400, 2.03)
# (8820, 2.0)
# (3472, 2.0)
# (3380, 2.0)
# (9451, 1.99)
# (8980, 1.99)
# (3621, 1.97)
# (2110, 1.97)
# (3294, 1.94)
# (3501, 1.93)
# (3221, 1.93)
# (3111, 1.92)
# (1850, 1.92)
# (9950, 1.91)
# (3201, 1.91)
# (8380, 1.89)
# (3581, 1.89)
# (9270, 1.88)
# (8953, 1.88)
# (2830, 1.88)
# (9220, 1.86)
# (8670, 1.85)
# (8421, 1.85)
# (9160, 1.83)
# (9840, 1.82)
# (3980, 1.82)
# (2491, 1.82)
# (1320, 1.81)
# (9280, 1.8)
# (8952, 1.8)
# (9520, 1.79)
# (8940, 1.79)
# (2380, 1.79)
# (9290, 1.77)
# (3211, 1.77)
# (9473, 1.74)
# (3722, 1.74)
# (3110, 1.74)
# (9932, 1.72)
# (9310, 1.72)
# (8956, 1.71)
# (8430, 1.71)
# (9830, 1.7)
# (9200, 1.69)
# (8920, 1.67)
# (3570, 1.66)
# (3390, 1.66)
# (9630, 1.65)
# (3512, 1.65)
# (8420, 1.64)
# (3500, 1.64)
# (9230, 1.63)
# (8904, 1.63)
# (8902, 1.62)
# (9080, 1.61)
# (3720, 1.61)
# (3510, 1.61)
# (2880, 1.61)
# (2990, 1.6)
# (2650, 1.6)
# (8434, 1.59)
# (3730, 1.59)
# (3721, 1.58)
# (2180, 1.57)
# (9550, 1.56)
# (3511, 1.56)
# (2870, 1.56)
# (2530, 1.55)
# (9930, 1.54)
# (9300, 1.54)
# (9250, 1.54)
# (9450, 1.52)
# (8958, 1.5)
# (8660, 1.5)
# (3321, 1.5)
# (9620, 1.49)
# (9551, 1.49)
# (9260, 1.49)
# (8900, 1.47)
# (9552, 1.46)
# (9140, 1.45)
# (9340, 1.44)
# (3631, 1.44)
# (3118, 1.44)
# (2381, 1.44)
# (9521, 1.42)
# (8620, 1.42)
# (3140, 1.42)
# (3128, 1.42)
# (3120, 1.4)
# (2430, 1.4)
# (9420, 1.39)
# (3583, 1.39)
# (3054, 1.37)
# (9320, 1.36)
# (8552, 1.36)
# (2801, 1.36)
# (8908, 1.34)
# (9308, 1.31)
# (9860, 1.3)
# (2460, 1.3)
# (2322, 1.25)
# (2450, 1.24)
# (9920, 1.21)
# (8370, 1.21)
# (2440, 1.2)
# (2861, 1.18)
# (2431, 1.17)
# (9150, 1.15)
# (9100, 1.15)
# (3130, 1.15)
# (2387, 1.14)
# (8433, 1.13)
# (3370, 1.13)
# (9190, 1.09)
# (9112, 1.07)
# (3150, 1.07)
# (2321, 1.07)
# (9120, 1.06)
# (2560, 1.05)
# (9992, 1.0)
# (9982, 1.0)
# (9981, 1.0)
# (9667, 1.0)
# (9111, 1.0)
# (8970, 1.0)
# (8583, 1.0)
# (3391, 1.0)
# (3381, 1.0)
# (3018, 0.98)
# (2850, 0.96)
# (2960, 0.94)
# (2580, 0.94)
# (2360, 0.93)
# (9170, 0.92)
# (2950, 0.92)
# (2531, 0.92)
# (2350, 0.92)
# (2250, 0.92)
# (8431, 0.9)
# (2940, 0.89)
# (2310, 0.89)
# (2930, 0.88)
# (2500, 0.88)
# (2040, 0.88)
# (2223, 0.84)
# (2520, 0.83)
# (2382, 0.83)
# (2328, 0.83)
# (2323, 0.83)
# (2570, 0.82)
# (2330, 0.8)
# (2300, 0.8)
# (2260, 0.79)
# (2230, 0.79)
# (2590, 0.77)
# (2242, 0.77)
# (8906, 0.75)
# (2627, 0.75)
# (2970, 0.74)
# (2845, 0.72)
# (2320, 0.68)
# (2221, 0.68)
# (2340, 0.67)
# (2240, 0.65)
# (2840, 0.64)
# (2243, 0.64)
# (2547, 0.59)
# (2480, 0.55)
# (2220, 0.55)
# (2270, 0.53)
# (2288, 0.52)
# (2235, 0.52)
# (3724, 0.5)
# (2630, 0.5)
# (2470, 0.5)
# (9130, 0.46)
# (2200, 0.46)
# (2222, 0.45)
# (2980, 0.44)
# (2280, 0.44)
# (2550, 0.43)
# (2275, 0.43)
# (2620, 0.41)
# (2540, 0.41)
# (2390, 0.35)
# (2290, 0.25)
# (2370, 0.17)
# (9988, 0.0)
# (8978, 0.0)
# (8972, 0.0)

# %%
## Deliveroo
try:
    deliveroo ="""SELECT
                    restaurants.postal_code,
                    ROUND(AVG(restaurants.delivery_fee),2) AS delivery_fee
    
                FROM
                    restaurants
                WHERE
                    restaurants.delivery_fee IS NOT NULL
                    AND restaurants.postal_code IS NOT NULL
                GROUP BY
                    restaurants.postal_code
                ORDER BY
                    delivery_fee ASC;"""
    deliveroo_results = conn.execute(deliveroo).fetchall()
    for row in deliveroo_results:
        print(row)

except sqlite3.OperationalError as e:
    print("Error:", e)
# Out:
# ('2050', 1.0)
# ('1020', 4.41)
# ('8501', 4.59)
# ('1800', 4.68)
# ('9300', 4.8)
# ('1150', 4.85)
# ('8310', 4.89)
# ('2140', 4.92)
# ('3800', 4.92)
# ('1090', 4.93)
# ('2018', 4.93)
# ('2600', 4.93)
# ('8500', 4.94)
# ('3500', 4.96)
# ('8000', 4.96)
# ('9000', 4.97)
# ('2000', 4.98)
# ('3000', 4.98)
# ('', 4.99)
# ('1000', 4.99)
# ('1030', 4.99)
# ('1040', 4.99)
# ('1060', 4.99)
# ('1080', 4.99)
# ('1081', 4.99)
# ('1082', 4.99)
# ('1083', 4.99)
# ('1120', 4.99)
# ('1130', 4.99)
# ('1140', 4.99)
# ('1160', 4.99)
# ('1180', 4.99)
# ('1190', 4.99)
# ('1200', 4.99)
# ('1210', 4.99)
# ('1330', 4.99)
# ('1410', 4.99)
# ('1600', 4.99)
# ('1620', 4.99)
# ('1700', 4.99)
# ('1702', 4.99)
# ('1780', 4.99)
# ('1830', 4.99)
# ('1831', 4.99)
# ('1850', 4.99)
# ('1853', 4.99)
# ('1930', 4.99)
# ('1932', 4.99)
# ('1950', 4.99)
# ('1970', 4.99)
# ('2020', 4.99)
# ('2030', 4.99)
# ('2060', 4.99)
# ('2100', 4.99)
# ('2110', 4.99)
# ('2150', 4.99)
# ('2160', 4.99)
# ('2170', 4.99)
# ('2180', 4.99)
# ('2300', 4.99)
# ('2360', 4.99)
# ('2610', 4.99)
# ('2640', 4.99)
# ('2660', 4.99)
# ('2800', 4.99)
# ('2812', 4.99)
# ('2900', 4.99)
# ('3001', 4.99)
# ('3010', 4.99)
# ('3020', 4.99)
# ('3360', 4.99)
# ('3511', 4.99)
# ('3600', 4.99)
# ('4000', 4.99)
# ('8200', 4.99)
# ('8300', 4.99)
# ('8400', 4.99)
# ('8510', 4.99)
# ('8800', 4.99)
# ('9030', 4.99)
# ('9040', 4.99)
# ('9041', 4.99)
# ('9050', 4.99)
# ('9070', 4.99)
# ('9100', 4.99)
# ('9200', 4.99)
# ('9308', 4.99)

# %% [markdown]
# #### Which restaurants have the best price-to-rating ratio?

# %%
##Deliveroo
try :
    deliveroo ="""SELECT 
                    menu_items.restaurant_id, 
                    restaurants.name, 
                    ROUND(AVG(menu_items.price_float), 2) AS avg_price,
                    restaurants.rating,
                    restaurants.rating_number,
                    ROUND(
                        (restaurants.rating * restaurants.rating_number) / (restaurants.rating_number + 10), 2
                    ) AS weighted_rating,
                    ROUND(AVG(menu_items.price_float) / 
                        ((restaurants.rating * restaurants.rating_number) / (restaurants.rating_number + 10)), 2
                    ) AS price_to_weighted_rating_ratio,
                    CASE 
                        WHEN AVG(menu_items.price_float) < 10 THEN 'Low'
                        WHEN AVG(menu_items.price_float) BETWEEN 10 AND 20 THEN 'Medium'
                        WHEN AVG(menu_items.price_float) BETWEEN 20 AND 30 THEN 'High'
                        ELSE 'Premium'
                    END AS price_bucket
                FROM 
                    menu_items
                INNER JOIN 
                    restaurants
                ON 
                    menu_items.restaurant_id = restaurants.id
                WHERE 
                    menu_items.price_float IS NOT NULL 
                    AND menu_items.price_float > 0
                    AND restaurants.rating IS NOT NULL
                    AND restaurants.rating > 0
                    AND restaurants.rating_number IS NOT NULL
                    AND restaurants.rating_number > 0
                GROUP BY 
                    menu_items.restaurant_id, restaurants.name, restaurants.rating, restaurants.rating_number
                HAVING
                    price_bucket != 'Low'
                ORDER BY
                    price_to_weighted_rating_ratio ASC;"""
    deliveroo_results = conn.execute(deliveroo).fetchall()
    for row in deliveroo_results:
        print(row)

except sqlite3.OperationalError as e:
    print("Error:", e)
# Out:
# (210621, 'Sanseveria Bagelsalon', 10.11, 4.6, '500+', 4.51, 2.24, 'Medium')
# (280238, 'Nijo x Doubleyou Kitchen', 10.16, 4.7, '241', 4.51, 2.25, 'Medium')
# (15370, 'Little BÚN - Theater', 10.25, 4.5, '332', 4.37, 2.35, 'Medium')
# (97348, 'Sushi Hungry Eye', 10.29, 4.5, '309', 4.36, 2.36, 'Medium')
# (17719, 'O Beyrouth', 10.22, 4.4, '493', 4.31, 2.37, 'Medium')
# (250201, 'Takumi Japanese Noodlebar', 10.6, 4.6, '343', 4.47, 2.37, 'Medium')
# (353326, 'Sushi Buzz', 10.24, 4.6, '148', 4.31, 2.38, 'Medium')
# (256097, 'Takumi Chicken Ramen Kitchen', 10.78, 4.6, '500+', 4.51, 2.39, 'Medium')
# (383094, 'Piano A apulian pizza', 10.31, 4.5, '231', 4.31, 2.39, 'Medium')
# (387342, 'Chez Giovanni', 10.08, 4.4, '234', 4.22, 2.39, 'Medium')
# (29034, 'Sette Piatti', 11.03, 4.8, '203', 4.57, 2.41, 'Medium')
# (239430, 'Restaurant Italien Pasta Comedia', 10.06, 4.3, '319', 4.17, 2.41, 'Medium')
# (281976, 'Lhasa Tibet kitchen', 10.04, 4.4, '166', 4.15, 2.42, 'Medium')
# (75163, 'Burger Folie', 10.12, 4.3, '278', 4.15, 2.44, 'Medium')
# (117054, 'Pasta Ruffo', 11.01, 4.6, '500+', 4.51, 2.44, 'Medium')
# (65266, 'Taste Of Curry', 10.31, 4.3, '500+', 4.22, 2.45, 'Medium')
# (66461, 'Sushi Mama', 10.38, 4.3, '500+', 4.22, 2.46, 'Medium')
# (296030, 'damas ', 10.5, 4.7, '99', 4.27, 2.46, 'Medium')
# (299915, 'Favoriete', 10.36, 4.4, '214', 4.2, 2.46, 'Medium')
# (61424, 'Chez Hassan', 10.31, 4.5, '122', 4.16, 2.48, 'Medium')
# (247234, 'Takumi Ramen Kitchen', 10.94, 4.5, '500+', 4.41, 2.48, 'Medium')
# (23311, 'Loa Streetfood', 10.93, 4.5, '375', 4.38, 2.49, 'Medium')
# (60034, 'Pizza Hut', 10.54, 4.4, '251', 4.23, 2.49, 'Medium')
# (330796, 'Gks express', 11.12, 4.6, '333', 4.47, 2.49, 'Medium')
# (384074, "M'adam traiteur", 10.31, 4.5, '116', 4.14, 2.49, 'Medium')
# (58071, 'Ocean Sushi', 10.77, 4.4, '500+', 4.31, 2.5, 'Medium')
# (30964, "Win's Asian Cuisine", 11.12, 4.5, '474', 4.41, 2.52, 'Medium')
# (181555, 'Bananenleef', 10.52, 4.3, '283', 4.15, 2.53, 'Medium')
# (60365, 'Pizza Hut', 10.72, 4.3, '500+', 4.22, 2.54, 'Medium')
# (36224, 'Yu-Thai', 10.73, 4.3, '500+', 4.22, 2.55, 'Medium')
# (61951, "Magnum & Ben & Jerry's - Ice Cream Store", 10.56, 4.3, '259', 4.14, 2.55, 'Medium')
# (116896, "Croque'n Roll", 10.8, 4.4, '266', 4.24, 2.55, 'Medium')
# (19446, 'De Broers van Julienne', 10.53, 4.3, '216', 4.11, 2.56, 'Medium')
# (78209, 'Taste of India', 11.62, 4.6, '439', 4.5, 2.58, 'Medium')
# (241089, 'Royale Pizza Express', 10.3, 4.2, '196', 4.0, 2.58, 'Medium')
# (167555, 'Da Mario Take Away', 10.23, 4.4, '84', 3.93, 2.6, 'Medium')
# (254914, 'Sangeetha Vegetarian Restaurant Antwerp', 10.42, 4.2, '201', 4.0, 2.6, 'Medium')
# (284843, 'Taste of India', 11.62, 4.6, '324', 4.46, 2.6, 'Medium')
# (374011, 'POP', 10.02, 4.3, '87', 3.86, 2.6, 'Medium')
# (299415, 'Vikings', 11.01, 4.4, '227', 4.21, 2.61, 'Medium')
# (62687, 'Bouchéry', 11.0, 4.7, '85', 4.21, 2.62, 'Medium')
# (160177, 'Quo Vadis', 10.44, 4.2, '190', 3.99, 2.62, 'Medium')
# (78749, "That's Amore", 11.59, 4.5, '500+', 4.41, 2.63, 'Medium')
# (243077, 'JEAN sur MER Harbor Cafe', 10.85, 4.3, '218', 4.11, 2.64, 'Medium')
# (267753, 'Otomat Leopoldplaats', 10.87, 4.2, '500+', 4.12, 2.64, 'Medium')
# (14867, 'Burgerij Eilandje', 10.4, 4.2, '141', 3.92, 2.65, 'Medium')
# (333187, 'Garlic n Greens', 10.4, 4.3, '103', 3.92, 2.65, 'Medium')
# (316335, 'De stoepa', 11.26, 4.6, '116', 4.23, 2.66, 'Medium')
# (37133, 'Tutti Atelier', 11.7, 4.5, '385', 4.39, 2.67, 'Medium')
# (47370, 'Hoshi Hoshi', 10.75, 4.3, '144', 4.02, 2.67, 'Medium')
# (60363, 'Pizza Hut', 10.67, 4.1, '396', 4.0, 2.67, 'Medium')
# (211029, 'Wok & Momo House', 11.35, 4.4, '289', 4.25, 2.67, 'Medium')
# (51820, "Eetcafe 't Prison", 11.25, 4.4, '201', 4.19, 2.68, 'Medium')
# (345580, 'Oishi sushi', 11.3, 4.3, '500+', 4.22, 2.68, 'Medium')
# (95795, 'La Sushiria', 11.01, 4.2, '405', 4.1, 2.69, 'Medium')
# (283302, 'Jilles Beer & Burgers - Centrum', 10.46, 4.1, '179', 3.88, 2.69, 'Medium')
# (361799, 'Pizza Italia', 10.59, 4.3, '110', 3.94, 2.69, 'Medium')
# (30080, 'Thai Café', 11.64, 4.4, '500+', 4.31, 2.7, 'Medium')
# (60566, 'New Hong Kong Bruxelles', 10.83, 4.2, '214', 4.01, 2.7, 'Medium')
# (262552, 'Sushiria Uccle', 10.96, 4.2, '281', 4.06, 2.7, 'Medium')
# (276004, 'K&B- Kitchen & Bar at Courtyard', 10.91, 4.4, '112', 4.04, 2.7, 'Medium')
# (70660, 'Bowls', 11.96, 4.5, '500+', 4.41, 2.71, 'Medium')
# (197177, 'China Wok Gent', 10.45, 4.0, '271', 3.86, 2.71, 'Medium')
# (307389, 'Royal India', 11.72, 4.7, '114', 4.32, 2.71, 'Medium')
# (51118, 'Monkey King', 11.48, 4.3, '500+', 4.22, 2.72, 'Medium')
# (262778, "Magnum & Ben & Jerry's - Ice Cream Store", 10.56, 4.3, '92', 3.88, 2.72, 'Medium')
# (320208, 'Yaki Noodles Bar', 11.72, 4.4, '500+', 4.31, 2.72, 'Medium')
# (121800, 'Oost-Azië', 11.41, 4.3, '355', 4.18, 2.73, 'Medium')
# (289780, 'Sushi Plaza', 11.28, 4.2, '459', 4.11, 2.74, 'Medium')
# (70764, "Seli's Noodlebar", 11.58, 4.3, '500+', 4.22, 2.75, 'Medium')
# (359085, 'Pema Sushi', 11.44, 4.3, '296', 4.16, 2.75, 'Medium')
# (42713, 'Ikura Sushi', 11.13, 4.1, '500+', 4.02, 2.77, 'Medium')
# (64591, 'Himalaya', 10.17, 4.1, '85', 3.67, 2.77, 'Medium')
# (14962, 'Bia Mara', 11.03, 4.3, '121', 3.97, 2.78, 'Medium')
# (71989, "L'Atelier", 11.01, 4.2, '170', 3.97, 2.78, 'Medium')
# (234364, 'Etna Trattoria', 10.62, 4.0, '209', 3.82, 2.78, 'Medium')
# (335500, 'Sushi Paradijs', 11.63, 4.4, '193', 4.18, 2.78, 'Medium')
# (355014, 'Pizza Hut Strombeek-Bever', 10.7, 4.6, '51', 3.85, 2.78, 'Medium')
# (45798, 'Collina 2 go', 12.58, 4.6, '395', 4.49, 2.8, 'Medium')
# (324615, 'Takumi Ramen & Yakisoba', 12.17, 4.5, '290', 4.35, 2.8, 'Medium')
# (83936, 'Taco Santo', 11.3, 4.4, '108', 4.03, 2.81, 'Medium')
# (108416, 'Sushi Leuven', 12.41, 4.5, '500+', 4.41, 2.81, 'Medium')
# (287613, 'Pizza Gulhan', 11.44, 4.2, '297', 4.06, 2.82, 'Medium')
# (299710, 'Pizarro Antwerpen', 12.19, 4.4, '500+', 4.31, 2.82, 'Medium')
# (57156, 'Zushi', 12.48, 4.5, '500+', 4.41, 2.83, 'Medium')
# (336308, 'Thai Café', 11.64, 4.2, '500+', 4.12, 2.83, 'Medium')
# (336495, 'The peps Sushi &Bar', 10.73, 4.3, '75', 3.79, 2.83, 'Medium')
# (68312, 'Unique Asia Restaurant', 10.96, 4.3, '88', 3.86, 2.84, 'Medium')
# (96849, 'Orient Kitchen Bruxelles', 11.57, 4.3, '176', 4.07, 2.84, 'Medium')
# (216285, 'Sushi Palace Gent', 12.24, 4.4, '500+', 4.31, 2.84, 'Medium')
# (280623, 'Café des Arts ', 12.73, 4.7, '203', 4.48, 2.84, 'Medium')
# (287298, 'Pizza Hut Wemmel', 10.82, 4.1, '133', 3.81, 2.84, 'Medium')
# (324109, 'Pici Centrum ', 12.34, 4.5, '275', 4.34, 2.84, 'Medium')
# (51828, 'Indian Royal Food', 10.37, 4.1, '80', 3.64, 2.85, 'Medium')
# (64649, 'Café Pistolet', 10.5, 4.6, '40', 3.68, 2.85, 'Medium')
# (79241, 'Romeo e Giulietta', 11.34, 4.3, '123', 3.98, 2.85, 'Medium')
# (137524, 'pizza overpoort', 11.31, 4.1, '293', 3.96, 2.85, 'Medium')
# (427182, 'Brasserie Rekruut', 11.55, 4.4, '115', 4.05, 2.85, 'Medium')
# (69302, 'China Keuken', 12.06, 4.3, '500+', 4.22, 2.86, 'Medium')
# (103661, 'Pici Zurenborg ', 11.63, 4.3, '177', 4.07, 2.86, 'Medium')
# (142092, 'TANDOORI-PASTA', 12.6, 4.5, '500+', 4.41, 2.86, 'Medium')
# (317638, 'Pita Piramide Aalst', 10.63, 4.4, '54', 3.71, 2.86, 'Medium')
# (156304, 'Les Tartes de Françoise', 12.92, 4.6, '470', 4.5, 2.87, 'Medium')
# (324671, 'Ali Baba Stalenstraat', 10.9, 4.2, '95', 3.8, 2.87, 'Medium')
# (349877, 'Sushi Shisaido', 12.05, 4.4, '209', 4.2, 2.87, 'Medium')
# (28801, 'Destiny Asian Food', 11.24, 4.2, '128', 3.9, 2.89, 'Medium')
# (382522, 'Xiongmao Panda', 11.85, 4.3, '204', 4.1, 2.89, 'Medium')
# (154786, 'Les Tartes de Françoise', 12.92, 4.6, '295', 4.45, 2.9, 'Medium')
# (299746, 'BeSushi Pokebowl', 12.17, 4.6, '102', 4.19, 2.9, 'Medium')
# (154795, 'Les Tartes de Françoise', 12.92, 4.6, '283', 4.44, 2.91, 'Medium')
# (165973, 'Frituur Rosa - Delforge Kurt', 11.24, 4.4, '71', 3.86, 2.91, 'Medium')
# (227814, 'Himalayan Cuisine', 11.2, 4.3, '86', 3.85, 2.91, 'Medium')
# (281799, 'Royal Lebanon', 11.68, 4.6, '68', 4.01, 2.91, 'Medium')
# (95898, 'Baskuul', 11.42, 4.4, '81', 3.92, 2.92, 'Medium')
# (258884, 'Thai Café Hasselt', 11.57, 4.1, '297', 3.97, 2.92, 'Medium')
# (83068, 'Tasty Thai Express', 11.83, 4.3, '152', 4.03, 2.93, 'Medium')
# (290607, 'Uzume Sushi Overpoort', 12.65, 4.4, '500+', 4.31, 2.93, 'Medium')
# (20900, 'Da Toni', 12.98, 4.5, '500+', 4.41, 2.94, 'Medium')
# (154789, 'Les Tartes de Françoise', 12.92, 4.6, '220', 4.4, 2.94, 'Medium')
# (160210, 'Pizzeria La Lanterna', 11.71, 4.1, '331', 3.98, 2.94, 'Medium')
# (173020, 'Basta!', 11.92, 4.2, '286', 4.06, 2.94, 'Medium')
# (184962, 'Verona | Antwerp', 11.94, 4.2, '288', 4.06, 2.94, 'Medium')
# (59465, 'Trattoria Trium', 11.72, 4.1, '297', 3.97, 2.95, 'Medium')
# (255254, 'Shad Antwerp', 12.11, 4.3, '211', 4.11, 2.95, 'Medium')
# (261169, "Pizza & Pasta Poppy's", 11.67, 4.2, '161', 3.95, 2.95, 'Medium')
# (153665, 'Les Tartes de Françoise - Jette', 12.92, 4.6, '191', 4.37, 2.96, 'Medium')
# (259087, "Mommy's Bastards", 10.42, 4.2, '52', 3.52, 2.96, 'Medium')
# (361317, "Odette's Croquettes", 11.72, 4.4, '89', 3.96, 2.96, 'Medium')
# (38041, 'De Orchidee', 12.54, 4.3, '500+', 4.22, 2.97, 'Medium')
# (46718, 'Indian Restaurant Rasoi', 11.35, 4.1, '139', 3.82, 2.97, 'Medium')
# (60041, 'Pizza Hut', 11.01, 4.1, '94', 3.71, 2.97, 'Medium')
# (36996, 'JusJus', 13.09, 4.7, '142', 4.39, 2.98, 'Medium')
# (78738, 'El Bocado', 12.68, 4.4, '281', 4.25, 2.98, 'Medium')
# (153660, 'Les Tartes de Françoise - Stockel', 12.92, 4.7, '120', 4.34, 2.98, 'Medium')
# (173853, 'Kintsugi Sushi Bar', 11.77, 4.4, '89', 3.96, 2.98, 'Medium')
# (254900, 'Indian Curry House Gent', 12.84, 4.4, '500+', 4.31, 2.98, 'Medium')
# (270346, 'Andalucia SeaFood', 11.07, 4.1, '97', 3.72, 2.98, 'Medium')
# (278018, "Arthie's ", 10.03, 3.9, '63', 3.37, 2.98, 'Medium')
# (372726, 'Peppermint Park', 11.59, 4.2, '124', 3.89, 2.98, 'Medium')
# (201552, 'Nepal Delight', 11.53, 4.1, '160', 3.86, 2.99, 'Medium')
# (209243, 'Taste of fresh', 12.87, 4.4, '439', 4.3, 2.99, 'Medium')
# (121811, 'Royal Tokyo Sushi Bar', 12.71, 4.3, '500+', 4.22, 3.02, 'Medium')
# (306515, 'THE PEARL ~ Sri Lankan & South Indian Restaurant', 11.8, 4.3, '99', 3.91, 3.02, 'Medium')
# (41007, 'Uzume Sushi', 12.73, 4.3, '448', 4.21, 3.03, 'Medium')
# (246602, 'Fons Burgers', 12.0, 4.5, '73', 3.96, 3.03, 'Medium')
# (444502, 'Nara Sushi Dendermonde', 10.3, 4.4, '34', 3.4, 3.03, 'Medium')
# (83009, 'Chanchal restaurant', 10.23, 4.3, '36', 3.37, 3.04, 'Medium')
# (288435, 'Thai Time', 12.92, 4.4, '282', 4.25, 3.04, 'Medium')
# (18271, 'Indus Pride', 12.47, 4.2, '361', 4.09, 3.05, 'Medium')
# (69950, 'India Palace', 12.85, 4.3, '476', 4.21, 3.05, 'Medium')
# (166348, 'Nieuw Oriental', 12.55, 4.2, '500+', 4.12, 3.05, 'Medium')
# (268254, 'New Asia', 12.75, 4.3, '371', 4.19, 3.05, 'Medium')
# (316313, 'Tom Yam & Pizzas Stockel', 11.79, 4.4, '73', 3.87, 3.05, 'Medium')
# (370218, 'Sakura Sushi & Sashimi Sint Truiden', 12.55, 4.3, '228', 4.12, 3.05, 'Medium')
# (49245, 'De Appel', 13.18, 4.4, '500+', 4.31, 3.06, 'Medium')
# (49678, 'New Holy Cow', 13.19, 4.4, '500+', 4.31, 3.06, 'Medium')
# (305785, 'Darband “persian cuisine”', 13.07, 4.5, '184', 4.27, 3.06, 'Medium')
# (317935, 'Boëna-To-Go', 12.78, 4.5, '127', 4.17, 3.06, 'Medium')
# (437515, 'Munis restaurant', 10.93, 4.1, '67', 3.57, 3.06, 'Medium')
# (7593, 'Meli Mêly', 13.17, 4.4, '411', 4.3, 3.07, 'Medium')
# (64003, 'La Penisola', 11.37, 4.0, '121', 3.69, 3.08, 'Medium')
# (154792, 'Les Tartes de Françoise', 12.92, 4.5, '136', 4.19, 3.08, 'Medium')
# (297694, 'PITAWAN', 12.26, 4.1, '347', 3.99, 3.08, 'Medium')
# (324599, 'Himalayan Restaurant OST', 12.53, 4.3, '178', 4.07, 3.08, 'Medium')
# (352769, 'Love sushi', 11.33, 4.4, '51', 3.68, 3.08, 'Medium')
# (404602, "Fratello's ", 11.19, 4.4, '47', 3.63, 3.08, 'Medium')
# (55472, 'Da Giovanni', 13.32, 4.4, '500+', 4.31, 3.09, 'Medium')
# (80266, 'Ama Sushi', 11.97, 4.4, '74', 3.88, 3.09, 'Medium')
# (177358, 'Pane e Focaccia', 11.89, 4.5, '59', 3.85, 3.09, 'Medium')
# (250203, 'Wagamama Keyserlei', 13.32, 4.4, '500+', 4.31, 3.09, 'Medium')
# (15124, 'De Bomma', 13.69, 4.5, '500+', 4.41, 3.1, 'Medium')
# (55582, 'Da Giovanni Eilandje', 12.99, 4.4, '207', 4.2, 3.1, 'Medium')
# (276844, "Judy's Lobster Shack", 13.6, 4.5, '369', 4.38, 3.1, 'Medium')
# (70206, 'De Kastart', 13.14, 4.3, '500+', 4.22, 3.12, 'Medium')
# (73421, 'Kanikama Sushi', 13.21, 4.3, '500+', 4.22, 3.13, 'Medium')
# (74584, 'Taj Mahal Antwerp', 12.44, 4.3, '122', 3.97, 3.13, 'Medium')
# (452110, 'Çigköftem 🌱   Berchem', 10.05, 4.4, '27', 3.21, 3.13, 'Medium')
# (149400, 'Beiruti', 12.31, 4.0, '500+', 3.92, 3.14, 'Medium')
# (248336, 'PIZZERIA ROSSI', 13.5, 4.4, '449', 4.3, 3.14, 'Medium')
# (505163, 'Humm Streetfood', 10.08, 4.4, '27', 3.21, 3.14, 'Medium')
# (73603, 'Bella Italia', 12.48, 4.2, '163', 3.96, 3.15, 'Medium')
# (153876, "Forno A'Legna", 11.94, 4.1, '124', 3.79, 3.15, 'Medium')
# (245759, 'Sforno', 14.14, 4.6, '401', 4.49, 3.15, 'Medium')
# (329359, 'Den Brandt', 12.28, 4.2, '125', 3.89, 3.16, 'Medium')
# (59445, 'Thai Café', 11.64, 4.3, '59', 3.68, 3.17, 'Medium')
# (230950, 'pita alexandria', 11.61, 4.1, '84', 3.66, 3.17, 'Medium')
# (312668, 'Irata sushi', 13.7, 4.4, '500+', 4.31, 3.17, 'Medium')
# (466751, 'Red Chillies', 11.94, 4.4, '59', 3.76, 3.17, 'Medium')
# (57226, 'Marco Polo Noodlebar', 13.43, 4.3, '500+', 4.22, 3.18, 'Medium')
# (201675, 'La Trattoria Italiana', 12.93, 4.2, '306', 4.07, 3.18, 'Medium')
# (151999, 'Shalimar Tandoori', 13.68, 4.4, '387', 4.29, 3.19, 'Medium')
# (300518, 'De Kraanvogel', 13.56, 4.5, '171', 4.25, 3.19, 'Medium')
# (144456, 'Epicuro', 13.06, 4.2, '336', 4.08, 3.2, 'Medium')
# (181568, 'Hau Wang', 12.47, 4.2, '126', 3.89, 3.2, 'Medium')
# (202986, 'Jardin Asiatique', 11.98, 4.3, '67', 3.74, 3.2, 'Medium')
# (266031, 'Gulzig', 13.36, 4.3, '338', 4.18, 3.2, 'Medium')
# (41122, 'LucMoon', 13.07, 4.4, '125', 4.07, 3.21, 'Medium')
# (312039, 'Bokertov Eilandje', 14.14, 4.5, '419', 4.4, 3.22, 'Medium')
# (22091, 'Lucy Chang Gent', 13.31, 4.2, '500+', 4.12, 3.23, 'Medium')
# (23723, 'Tenshi', 14.27, 4.5, '500+', 4.41, 3.23, 'Medium')
# (323887, 'Vesper ', 13.94, 4.6, '148', 4.31, 3.23, 'Medium')
# (47727, "Croque'n Roll - Leuven", 13.91, 4.5, '201', 4.29, 3.24, 'Medium')
# (104941, 'Iman Hallal Tandoori', 10.86, 4.0, '51', 3.34, 3.25, 'Medium')
# (110828, 'Domus', 13.86, 4.4, '300', 4.26, 3.25, 'Medium')
# (258850, 'glocal by Rock-Fort', 13.0, 4.5, '79', 3.99, 3.25, 'Medium')
# (64001, 'Racine PAKT', 11.08, 4.4, '34', 3.4, 3.26, 'Medium')
# (362177, 'La Rustica ', 10.33, 4.1, '34', 3.17, 3.26, 'Medium')
# (39848, 'Toshi Sushi', 10.62, 4.2, '34', 3.25, 3.27, 'Medium')
# (219460, 'Eat Wings Antwerpen', 13.08, 4.2, '203', 4.0, 3.27, 'Medium')
# (354938, 'Nani', 14.17, 4.5, '264', 4.34, 3.27, 'Medium')
# (426489, 'Tikka N Talk', 10.82, 3.8, '68', 3.31, 3.27, 'Medium')
# (156357, 'Bite Leuven', 13.86, 4.7, '88', 4.22, 3.28, 'Medium')
# (212407, 'Monkey Eleven', 13.5, 4.3, '199', 4.09, 3.3, 'Medium')
# (311573, 'Twilight Sushi', 13.58, 4.3, '225', 4.12, 3.3, 'Medium')
# (332442, "Flooh's Homemade Burgers", 12.43, 4.5, '51', 3.76, 3.3, 'Medium')
# (410039, 'De Loempiakraam', 11.18, 4.3, '37', 3.39, 3.3, 'Medium')
# (60791, 'Petit Paris', 13.64, 4.3, '234', 4.12, 3.31, 'Medium')
# (250574, 'Nuoc Mam', 14.95, 4.6, '500+', 4.51, 3.31, 'Medium')
# (418153, 'Hokkaido sushi LOV', 11.8, 4.1, '66', 3.56, 3.31, 'Medium')
# (21605, 'Nora Indian Restaurant', 13.68, 4.2, '500+', 4.12, 3.32, 'Medium')
# (56484, 'Mother India', 14.09, 4.5, '165', 4.24, 3.32, 'Medium')
# (142610, 'BBC HASSELT', 13.01, 4.3, '103', 3.92, 3.32, 'Medium')
# (225632, 'Pizzeria Number One', 10.16, 4.3, '24', 3.04, 3.35, 'Medium')
# (233387, 'Himschoot ', 14.04, 4.4, '201', 4.19, 3.35, 'Medium')
# (44577, 'Pasta Rigoletto', 12.83, 4.6, '49', 3.82, 3.36, 'Medium')
# (419328, 'El assyl', 11.77, 4.0, '70', 3.5, 3.36, 'Medium')
# (279307, 'Juni Thai Foody', 14.88, 4.5, '500+', 4.41, 3.37, 'Medium')
# (295442, 'Sushi Land', 10.59, 4.4, '25', 3.14, 3.37, 'Medium')
# (109006, "L'Estaminet", 13.15, 4.1, '189', 3.89, 3.38, 'Medium')
# (277416, 'Curry Masala', 13.21, 4.1, '204', 3.91, 3.38, 'Medium')
# (345283, 'Mia pizza evere BEVR', 11.93, 4.3, '46', 3.53, 3.38, 'Medium')
# (58990, 'The Lounge Dinner House', 10.54, 3.8, '45', 3.11, 3.39, 'Medium')
# (15033, 'Lucy Chang Antwerpen', 13.31, 4.0, '500+', 3.92, 3.4, 'Medium')
# (69985, 'Palmyra Leuven', 14.23, 4.4, '195', 4.19, 3.4, 'Medium')
# (58766, 'Wok Style', 10.69, 4.3, '27', 3.14, 3.41, 'Medium')
# (57995, 'Standard ', 14.1, 4.2, '500+', 4.12, 3.42, 'Medium')
# (173547, 'Gouden Paard', 13.6, 4.1, '326', 3.98, 3.42, 'Medium')
# (286255, 'Martino', 15.76, 4.7, '500+', 4.61, 3.42, 'Medium')
# (47354, 'Greenway Leuven', 15.42, 4.6, '410', 4.49, 3.43, 'Medium')
# (303342, 'Sushi Katelijne', 14.31, 4.3, '323', 4.17, 3.43, 'Medium')
# (301414, 'Authentic Canton Cuisine', 12.52, 4.0, '101', 3.64, 3.44, 'Medium')
# (8334, 'Thai Smile', 14.27, 4.5, '116', 4.14, 3.45, 'Medium')
# (109781, 'El Sombrero', 14.9, 4.4, '500+', 4.31, 3.45, 'Medium')
# (246918, 'Nonna stella Gent', 13.92, 4.1, '500+', 4.02, 3.46, 'Medium')
# (49688, 'Cremerie Germaine', 13.33, 4.6, '51', 3.85, 3.47, 'Medium')
# (327152, 'Sushi akito', 13.33, 4.0, '245', 3.84, 3.47, 'Medium')
# (428596, 'Lujain Resto', 10.52, 4.2, '26', 3.03, 3.47, 'Medium')
# (42020, "❌ Sapori d'Italia Antwerpen❌", 11.64, 4.3, '35', 3.34, 3.48, 'Medium')
# (160891, 'Benvenuto', 12.45, 4.3, '50', 3.58, 3.48, 'Medium')
# (36094, 'Brasserie Keizershof', 15.09, 4.5, '240', 4.32, 3.49, 'Medium')
# (52972, 'Namaste', 13.59, 4.3, '90', 3.87, 3.51, 'Medium')
# (309223, "Giussepe's", 14.44, 4.2, '500+', 4.12, 3.51, 'Medium')
# (273677, 'Jaipur Indian Tandoori', 12.49, 3.9, '102', 3.55, 3.52, 'Medium')
# (360170, "Croque 'n Roll", 14.36, 4.5, '93', 4.06, 3.53, 'Medium')
# (377657, 'Passione Ristorante Pizzeria', 13.86, 4.2, '141', 3.92, 3.53, 'Medium')
# (97946, 'De Lange Muur', 14.22, 4.1, '500+', 4.02, 3.54, 'Medium')
# (63095, 'Nour Al Cham Zain Damas', 12.86, 4.0, '94', 3.62, 3.56, 'Medium')
# (15312, 'Ristorante Pizzeria Nicoletta', 14.8, 4.3, '276', 4.15, 3.57, 'Medium')
# (193424, 'Wattman', 13.48, 4.1, '118', 3.78, 3.57, 'Medium')
# (299894, 'Le Lion Belge', 13.91, 4.5, '65', 3.9, 3.57, 'Medium')
# (300386, 'Les Tartes de Françoise ', 12.92, 4.6, '37', 3.62, 3.57, 'Medium')
# (77965, 'Shilies', 10.77, 3.8, '38', 3.01, 3.58, 'Medium')
# (88801, 'Ristorante Pizzeria La Sardegna', 14.28, 4.1, '351', 3.99, 3.58, 'Medium')
# (43047, 'Tenshi', 14.04, 4.4, '80', 3.91, 3.59, 'Medium')
# (78626, 'Nimmanhaemin', 15.13, 4.3, '418', 4.2, 3.6, 'Medium')
# (337857, 'B’artiste', 11.7, 4.4, '28', 3.24, 3.61, 'Medium')
# (28913, 'Les Deux Petits Diables', 14.59, 4.6, '71', 4.03, 3.62, 'Medium')
# (47565, 'Taste of Asia', 15.61, 4.4, '500+', 4.31, 3.62, 'Medium')
# (257085, 'Sensai', 11.8, 3.6, '95', 3.26, 3.62, 'Medium')
# (282212, 'Fernand ', 14.06, 4.6, '54', 3.88, 3.62, 'Medium')
# (311461, 'Kangei Sushi', 11.99, 4.1, '42', 3.31, 3.62, 'Medium')
# (254575, '5th Gok Gent', 12.96, 4.1, '68', 3.57, 3.63, 'Medium')
# (310546, 'IL Fuoco', 14.58, 4.3, '140', 4.01, 3.63, 'Medium')
# (243643, 'ORFEO', 14.71, 4.2, '264', 4.05, 3.64, 'Medium')
# (324598, 'Fusion Bites', 10.14, 4.0, '23', 2.79, 3.64, 'Medium')
# (350308, 'koji sushi (HAS)', 13.25, 3.9, '135', 3.63, 3.65, 'Medium')
# (15128, 'River Kwai', 15.89, 4.6, '170', 4.34, 3.66, 'Medium')
# (279898, 'El Churrasco Argentino', 14.89, 4.4, '123', 4.07, 3.66, 'Medium')
# (454988, 'Nirvana Kitchen LEUVEN', 14.67, 4.7, '58', 4.01, 3.66, 'Medium')
# (64092, 'Pizzeria Rosticceria da Valentina', 14.47, 4.2, '152', 3.94, 3.67, 'Medium')
# (153651, 'Les Tartes de Françoise - Waterloo', 12.92, 4.5, '36', 3.52, 3.67, 'Medium')
# (409424, 'Bollyfood Stories - Indian Soul Food', 10.89, 3.9, '32', 2.97, 3.67, 'Medium')
# (49677, 'Annapurna', 14.2, 4.2, '109', 3.85, 3.69, 'Medium')
# (94707, 'Nakhon Thai', 14.84, 4.1, '500+', 4.02, 3.69, 'Medium')
# (75729, 'Okoz', 13.43, 4.3, '53', 3.62, 3.71, 'Medium')
# (218661, 'Ibiza BOUFF', 13.97, 4.4, '60', 3.77, 3.71, 'Medium')
# (314533, 'The Doubleyou Kitchen', 10.5, 4.4, '18', 2.83, 3.71, 'Medium')
# (501501, "Luigi's", 10.25, 4.6, '15', 2.76, 3.71, 'Medium')
# (94626, 'Sabai Thaï', 15.18, 4.2, '351', 4.08, 3.72, 'Medium')
# (245773, 'Taste of india GNT', 13.27, 4.0, '83', 3.57, 3.72, 'Medium')
# (317497, 'Venezia del Nord', 12.25, 4.1, '41', 3.3, 3.72, 'Medium')
# (491642, 'Dagianni pizza', 12.81, 4.0, '62', 3.44, 3.72, 'Medium')
# (21985, 'Greenway Ghent', 16.07, 4.4, '500+', 4.31, 3.73, 'Medium')
# (27133, 'Orso Pizzeria', 16.06, 4.4, '457', 4.31, 3.73, 'Medium')
# (139206, 'Wok Dynasty', 12.8, 3.7, '122', 3.42, 3.74, 'Medium')
# (317692, 'Donatello', 14.94, 4.4, '99', 4.0, 3.74, 'Medium')
# (400792, 'Kefi Taverna', 12.62, 4.2, '41', 3.38, 3.74, 'Medium')
# (35939, 'Umi Sushi', 15.79, 4.3, '500+', 4.22, 3.75, 'Medium')
# (282210, 'Arte', 14.4, 4.3, '83', 3.84, 3.75, 'Medium')
# (79257, 'Cafè Latino', 15.84, 4.4, '219', 4.21, 3.76, 'Medium')
# (351204, 'Migoto', 15.85, 4.6, '102', 4.19, 3.78, 'Medium')
# (456663, 'My pizza KORTRIJK', 10.57, 3.7, '31', 2.8, 3.78, 'Medium')
# (33249, 'Shake Hands', 14.71, 4.5, '63', 3.88, 3.79, 'Medium')
# (204721, "l'Artista Mechelen", 15.55, 4.2, '420', 4.1, 3.79, 'Medium')
# (331756, 'Sushi Daily Cora Woluwe', 10.78, 3.9, '27', 2.85, 3.79, 'Medium')
# (20528, 'Greenway', 15.42, 4.2, '267', 4.05, 3.81, 'Medium')
# (161934, 'Pasta Gusto', 13.44, 4.0, '73', 3.52, 3.82, 'Medium')
# (281220, 'Visbar', 12.58, 4.1, '41', 3.3, 3.82, 'Medium')
# (455179, 'Corner City', 13.91, 4.2, '65', 3.64, 3.82, 'Medium')
# (36672, 'Caulifornication', 12.5, 4.1, '39', 3.26, 3.83, 'Medium')
# (279663, 'Boker Tov Markgrave', 16.88, 4.5, '500+', 4.41, 3.83, 'Medium')
# (294625, 'De Kreeftenfabriek', 13.16, 4.2, '45', 3.44, 3.83, 'Medium')
# (49633, 'Mémé Gusta', 14.82, 4.3, '88', 3.86, 3.84, 'Medium')
# (61135, 'Pizza Fresca Woluwe', 16.06, 4.3, '373', 4.19, 3.84, 'Medium')
# (301628, 'PizzaBiologica', 15.07, 4.4, '83', 3.93, 3.84, 'Medium')
# (87760, 'La Barchetta', 17.38, 4.6, '500+', 4.51, 3.85, 'Medium')
# (345789, "Murphy's Smashed Burgers", 12.06, 4.7, '20', 3.13, 3.85, 'Medium')
# (378859, 'Pattos', 15.51, 4.5, '85', 4.03, 3.85, 'Medium')
# (24449, 'Pasta Commedia', 15.84, 4.4, '129', 4.08, 3.88, 'Medium')
# (301791, 'El bocado', 12.76, 3.8, '64', 3.29, 3.88, 'Medium')
# (59633, 'Dilmon', 16.56, 4.6, '121', 4.25, 3.9, 'Medium')
# (279316, 'Malaciorta', 15.68, 4.3, '143', 4.02, 3.9, 'Medium')
# (462650, 'Bokertov Zuid', 14.41, 4.3, '61', 3.69, 3.9, 'Medium')
# (67458, 'Thai Zen', 16.5, 4.3, '500+', 4.22, 3.91, 'Medium')
# (261258, 'By Sam Oostende', 13.43, 4.3, '40', 3.44, 3.91, 'Medium')
# (80273, 'Bar Nine', 11.6, 4.3, '22', 2.96, 3.92, 'Medium')
# (265549, 'Sultan Al sham', 14.95, 4.2, '97', 3.81, 3.93, 'Medium')
# (284060, 'De Kameleon ', 16.0, 4.3, '181', 4.07, 3.93, 'Medium')
# (200981, 'Namaste Tandoori - Indian & Nepali Kitchen', 15.4, 4.5, '66', 3.91, 3.94, 'Medium')
# (28843, 'Anverres', 16.84, 4.5, '177', 4.26, 3.95, 'Medium')
# (58273, 'Yum Yum Sushi', 16.6, 4.3, '376', 4.19, 3.96, 'Medium')
# (175501, 'Brasserie Tuf Tuf', 16.0, 4.4, '111', 4.04, 3.96, 'Medium')
# (418510, 'Avido', 12.29, 4.3, '26', 3.11, 3.96, 'Medium')
# (72154, 'Sweet Lime', 17.05, 4.4, '393', 4.29, 3.97, 'Medium')
# (457690, 'In-Dish', 13.83, 4.4, '37', 3.46, 3.99, 'Medium')
# (57152, "Carlito's", 16.85, 4.3, '500+', 4.22, 4.0, 'Medium')
# (114021, 'Curry Palace & Tandoor', 12.75, 3.7, '61', 3.18, 4.01, 'Medium')
# (51832, 'Capital88', 17.0, 4.3, '500+', 4.22, 4.03, 'Medium')
# (80267, 'Wok Dynasty', 12.8, 3.8, '50', 3.17, 4.04, 'Medium')
# (247658, 'Pinocchio Gent', 16.07, 4.1, '334', 3.98, 4.04, 'Medium')
# (385604, 'M Steaks  Burgers House', 15.75, 4.4, '78', 3.9, 4.04, 'Medium')
# (488343, 'Kaffa Markgrave', 10.65, 4.1, '18', 2.64, 4.04, 'Medium')
# (123455, 'Bois Savanes', 16.0, 4.3, '111', 3.94, 4.06, 'Medium')
# (269974, 'Restaurant Vincenzo', 15.91, 4.3, '104', 3.92, 4.06, 'Medium')
# (319215, 'Kuala lumpur', 13.77, 4.6, '28', 3.39, 4.06, 'Medium')
# (74213, "Chi-Chi's", 13.72, 4.2, '40', 3.36, 4.08, 'Medium')
# (163983, 'Taj Mahal', 14.41, 4.1, '62', 3.53, 4.08, 'Medium')
# (190554, 'Wabi Sabi sushi & oriental food restaurant', 16.86, 4.2, '500+', 4.12, 4.09, 'Medium')
# (309668, 'La grappa', 13.28, 4.1, '38', 3.25, 4.09, 'Medium')
# (112181, 'Dim Yam Cha', 12.35, 4.2, '25', 3.0, 4.12, 'Medium')
# (162485, 'La Trattoria, Premium Pizza & wine', 17.13, 4.3, '297', 4.16, 4.12, 'Medium')
# (372640, "In 't Vrije", 14.89, 4.2, '62', 3.62, 4.12, 'Medium')
# (75191, 'Napoli Da Leonardo', 16.16, 4.4, '78', 3.9, 4.14, 'Medium')
# (234815, 'TapaBar Antwerpen', 11.45, 4.3, '18', 2.76, 4.14, 'Medium')
# (134920, 'Dal Pesce Innamorato', 17.02, 4.2, '407', 4.1, 4.15, 'Medium')
# (8321, 'Guignol', 16.85, 4.4, '114', 4.05, 4.16, 'Medium')
# (244363, 'POMODORO KORTRIJK', 11.6, 4.0, '23', 2.79, 4.16, 'Medium')
# (352388, 'The Crispy Crunch', 12.33, 4.3, '22', 2.96, 4.17, 'Medium')
# (362954, 'Falafel Habibi', 12.36, 4.0, '28', 2.95, 4.19, 'Medium')
# (250757, 'thaithanee', 15.36, 4.0, '108', 3.66, 4.2, 'Medium')
# (284845, 'Pizza Factory ', 17.69, 4.3, '500+', 4.22, 4.2, 'Medium')
# (456683, "The Cousin's Jette", 10.03, 4.1, '14', 2.39, 4.2, 'Medium')
# (57154, 'Narai Thai', 16.51, 4.1, '219', 3.92, 4.21, 'Medium')
# (105707, 'Punjab Tandoori Restaurant', 12.67, 3.7, '43', 3.0, 4.22, 'Medium')
# (17938, 'Le Zinneke', 17.89, 4.4, '249', 4.23, 4.23, 'Medium')
# (139258, 'Uma marisqueira', 14.29, 4.1, '47', 3.38, 4.23, 'Medium')
# (119965, 'Café Manger Leuven', 13.56, 4.0, '40', 3.2, 4.24, 'Medium')
# (39956, 'Borsalino - San Marino', 16.52, 4.1, '184', 3.89, 4.25, 'Medium')
# (156319, 'Wan Kou', 16.32, 4.1, '142', 3.83, 4.26, 'Medium')
# (358287, 'Poisson du Monde', 12.75, 3.4, '74', 3.0, 4.26, 'Medium')
# (400976, 'Mamma Roma ', 15.21, 4.1, '66', 3.56, 4.27, 'Medium')
# (41672, 'Nuova Era', 17.6, 4.2, '500+', 4.12, 4.28, 'Medium')
# (284445, 'Garden of India', 12.2, 3.8, '30', 2.85, 4.28, 'Medium')
# (33263, 'Bellini', 17.41, 4.2, '292', 4.06, 4.29, 'Medium')
# (53053, 'Cuore Di Puglia', 15.67, 3.9, '149', 3.65, 4.29, 'Medium')
# (85112, 'Chanchal Indian Restaurant', 11.22, 3.8, '22', 2.61, 4.29, 'Medium')
# (159422, 'Sushi Mantra Japanese restaurant', 10.32, 3.5, '22', 2.41, 4.29, 'Medium')
# (242184, 'Ankara', 10.29, 4.4, '12', 2.4, 4.29, 'Medium')
# (313706, 'Sushi Love', 16.02, 4.2, '79', 3.73, 4.3, 'Medium')
# (40813, 'Krua Thai', 17.63, 4.3, '197', 4.09, 4.31, 'Medium')
# (271597, 'Comme à la Maison - Waterloo', 13.66, 3.9, '43', 3.16, 4.32, 'Medium')
# (61622, 'Sakura Kortrijk', 15.4, 4.1, '65', 3.55, 4.33, 'Medium')
# (367765, 'Mozart Brugge', 18.14, 4.3, '369', 4.19, 4.33, 'Medium')
# (460987, 'Ling Tung', 10.71, 3.6, '22', 2.48, 4.33, 'Medium')
# (279869, 'Restaurant Chagall', 18.58, 4.6, '135', 4.28, 4.34, 'Medium')
# (452307, 'Savarin', 10.16, 3.8, '16', 2.34, 4.34, 'Medium')
# (32384, 'Restaurant San Marco', 17.91, 4.2, '500+', 4.12, 4.35, 'Medium')
# (224501, 'Masalatop Indian Restaurant/Tandoori Masala', 15.52, 4.1, '66', 3.56, 4.36, 'Medium')
# (335622, 'San Marco', 18.27, 4.5, '137', 4.19, 4.36, 'Medium')
# (109753, 'Da Adriano', 13.08, 4.1, '27', 2.99, 4.37, 'Medium')
# (223796, 'Sabatino', 14.75, 4.0, '54', 3.38, 4.37, 'Medium')
# (246450, "O'tagine Antwerp", 15.02, 4.1, '51', 3.43, 4.38, 'Medium')
# (268073, 'Pies and Fries by Het Rand', 15.6, 4.4, '42', 3.55, 4.39, 'Medium')
# (333196, 'Taste Of Asia Sushi', 18.41, 4.3, '405', 4.2, 4.39, 'Medium')
# (375004, "Tang's Palace", 17.33, 4.3, '106', 3.93, 4.41, 'Medium')
# (239436, 'Laila Tandoori GNT', 18.46, 4.4, '191', 4.18, 4.42, 'Medium')
# (23237, "L'Epicerie du Cirque", 11.9, 4.1, '19', 2.69, 4.43, 'Medium')
# (388186, 'Pizzeria Margherita', 16.55, 4.0, '139', 3.73, 4.44, 'Medium')
# (254913, 'La Cantina del coronel', 15.3, 4.0, '61', 3.44, 4.45, 'Medium')
# (70016, "Salt 'n Pepper", 10.47, 4.3, '12', 2.35, 4.47, 'Medium')
# (132779, 'Mexico', 12.48, 4.0, '23', 2.79, 4.48, 'Medium')
# (232726, 'Traiteur Toulouse', 15.3, 4.1, '50', 3.42, 4.48, 'Medium')
# (430875, 'Roti Antwerp', 11.09, 3.5, '24', 2.47, 4.49, 'Medium')
# (432559, 'PEAS', 13.9, 4.8, '18', 3.09, 4.5, 'Medium')
# (115579, 'El Warda', 16.78, 4.2, '78', 3.72, 4.51, 'Medium')
# (256297, 'The Waffle Factory Gent', 15.6, 3.7, '141', 3.45, 4.51, 'Medium')
# (488800, 'Cigkoftem  🌱  Zuid - Turkish Streetfood', 10.38, 4.6, '10', 2.3, 4.51, 'Medium')
# (246457, 'Kalypta', 16.0, 4.2, '54', 3.54, 4.52, 'Medium')
# (215625, 'Restaurant Little Asia (Thai & Vietnam Kitchen)', 14.98, 4.0, '46', 3.29, 4.56, 'Medium')
# (188287, 'Restaurant SUMO', 18.61, 4.6, '75', 4.06, 4.58, 'Medium')
# (385918, 'Arax', 18.14, 4.3, '116', 3.96, 4.58, 'Medium')
# (69658, 'Den Huzaar', 15.97, 4.1, '56', 3.48, 4.59, 'Medium')
# (249010, 'Curiosa', 18.38, 4.5, '78', 3.99, 4.61, 'Medium')
# (250007, 'Savoury', 14.84, 3.8, '55', 3.22, 4.62, 'Medium')
# (40944, 'Matterhorn', 16.61, 4.2, '58', 3.58, 4.64, 'Medium')
# (354228, 'Schuttershof', 15.72, 4.0, '54', 3.38, 4.66, 'Medium')
# (36435, 'Zorba de Griek', 18.49, 4.5, '71', 3.94, 4.69, 'Medium')
# (178860, 'La Calzoneria', 10.8, 4.2, '12', 2.29, 4.72, 'Medium')
# (417346, 'Bocca Nera', 15.72, 4.0, '50', 3.33, 4.72, 'Medium')
# (460131, 'Little BÚN - MAS', 11.61, 4.0, '16', 2.46, 4.72, 'Medium')
# (224560, 'Mister Buffet & Signore', 15.41, 4.1, '37', 3.23, 4.77, 'Medium')
# (281108, 'Da Basilico', 20.94, 4.5, '352', 4.38, 4.78, 'High')
# (438972, 'pizza Masters (Hasselt)', 12.33, 4.3, '15', 2.58, 4.78, 'Medium')
# (474919, 'Indian Tandoori brugge', 14.54, 4.2, '26', 3.03, 4.79, 'Medium')
# (310609, 'Royal Donuts Leuven', 16.18, 4.1, '46', 3.37, 4.8, 'Medium')
# (156325, 'Evita’s eethuis', 11.49, 4.2, '13', 2.37, 4.84, 'Medium')
# (290700, 'Neptune', 10.56, 4.9, '8', 2.18, 4.85, 'Medium')
# (28227, 'Caviste Lelièvre', 16.33, 4.6, '27', 3.36, 4.87, 'Medium')
# (93462, 'Gök 2', 17.84, 3.9, '156', 3.67, 4.87, 'Medium')
# (294609, 'la cite du mandarin', 13.86, 3.9, '27', 2.85, 4.87, 'Medium')
# (410121, 'Atlas Foods', 11.67, 4.1, '14', 2.39, 4.88, 'Medium')
# (188372, 'Halab al shahbae', 11.1, 3.6, '17', 2.27, 4.89, 'Medium')
# (254508, 'Croquettenbar Smaeck', 17.26, 4.4, '40', 3.52, 4.9, 'Medium')
# (192767, 'Bistro Pompidou', 13.92, 4.3, '19', 2.82, 4.94, 'Medium')
# (232944, 'Tontons', 21.71, 4.5, '417', 4.39, 4.94, 'High')
# (36863, "Simone's kitchen", 18.0, 4.3, '55', 3.64, 4.95, 'Medium')
# (264058, 'Ball Street NYC ', 16.06, 4.1, '38', 3.25, 4.95, 'Medium')
# (342324, 'Jb sushi bar & wok', 12.12, 4.3, '13', 2.43, 4.99, 'Medium')
# (438885, 'Fujiyama sushi', 14.46, 4.5, '18', 2.89, 5.0, 'Medium')
# (345894, 'Nightshop at door MEC', 19.86, 4.3, '117', 3.96, 5.01, 'Medium')
# (278585, 'Bistro Tout Court', 17.09, 4.2, '43', 3.41, 5.02, 'Medium')
# (367767, 'Mozart Aalst', 19.7, 4.3, '104', 3.92, 5.02, 'Medium')
# (287133, 'Barbercue Duhok', 14.43, 3.5, '44', 2.85, 5.06, 'Medium')
# (167489, 'de vlaamsche pot Brugge', 14.6, 3.7, '35', 2.88, 5.07, 'Medium')
# (301793, 'Grill land', 17.13, 4.4, '32', 3.35, 5.11, 'Medium')
# (27847, 'Per Bacco', 21.11, 4.4, '150', 4.13, 5.12, 'High')
# (245752, 'Grand Café Industrie', 16.14, 4.4, '25', 3.14, 5.13, 'Medium')
# (41559, 'MUDAY', 16.29, 4.0, '37', 3.15, 5.17, 'Medium')
# (15125, 'Le Max', 14.71, 4.3, '19', 2.82, 5.22, 'Medium')
# (241844, 'Samourai Leuven', 22.95, 4.5, '389', 4.39, 5.23, 'High')
# (305080, 'Ristorante Bianconero', 17.5, 4.5, '29', 3.35, 5.23, 'Medium')
# (17629, 'La Nuova Piazza', 12.83, 4.2, '14', 2.45, 5.24, 'Medium')
# (69399, 'MOON HOUSE', 18.09, 3.7, '136', 3.45, 5.25, 'Medium')
# (232857, 'Grade', 14.17, 4.6, '14', 2.68, 5.28, 'Medium')
# (89160, 'Sushi Gourmet Chazal', 11.65, 4.2, '11', 2.2, 5.3, 'Medium')
# (259511, 'Vlaminck’14', 18.41, 4.2, '47', 3.46, 5.32, 'Medium')
# (121142, 'Yousushi', 17.3, 4.6, '24', 3.25, 5.33, 'Medium')
# (108161, 'Almas al Sham', 10.98, 3.9, '11', 2.04, 5.37, 'Medium')
# (51011, 'Akdeniz', 19.2, 3.9, '105', 3.56, 5.39, 'Medium')
# (209085, "Carlito's Piazza", 15.84, 4.1, '25', 2.93, 5.41, 'Medium')
# (416065, 'La Pugliese Pizzeria', 14.48, 4.0, '20', 2.67, 5.43, 'Medium')
# (490228, 'Rōnin Asian Fusion', 12.54, 4.4, '11', 2.3, 5.44, 'Medium')
# (235052, 'PIZZI COTTO', 18.7, 4.1, '50', 3.42, 5.47, 'Medium')
# (382919, 'Brasserie lambik', 16.44, 4.1, '27', 2.99, 5.49, 'Medium')
# (491637, 'Everest Gurkha', 14.91, 4.3, '17', 2.71, 5.51, 'Medium')
# (280605, 'De Klimop', 23.63, 4.4, '359', 4.28, 5.52, 'High')
# (243155, 'La gondola Brugge', 23.35, 4.3, '500+', 4.22, 5.54, 'High')
# (437046, 'Restaurant Gabriel', 19.08, 4.4, '33', 3.38, 5.65, 'Medium')
# (59912, 'Amici Miei ', 10.65, 3.3, '13', 1.87, 5.71, 'Medium')
# (309630, 'EDO Sushi Antwerp', 11.44, 4.5, '8', 2.0, 5.72, 'Medium')
# (476532, 'Wabi sushi antwerpen', 11.74, 3.4, '15', 2.04, 5.76, 'Medium')
# (268166, 'Ambiente Wines', 16.44, 4.7, '15', 2.82, 5.83, 'Medium')
# (339035, 'Little Valley', 15.07, 4.2, '16', 2.58, 5.83, 'Medium')
# (54103, 'Tomi', 16.49, 4.2, '20', 2.8, 5.89, 'Medium')
# (347288, 'Rosso Forno', 12.01, 4.3, '9', 2.04, 5.9, 'Medium')
# (28841, 'Zurich', 20.52, 4.3, '42', 3.47, 5.91, 'High')
# (425621, 'Nieuw Swatow BV', 17.8, 4.1, '27', 2.99, 5.95, 'Medium')
# (479367, 'Pizzeria Giardino', 14.46, 4.1, '14', 2.39, 6.05, 'Medium')
# (336874, 'TIKA', 12.32, 4.9, '7', 2.02, 6.11, 'Medium')
# (279309, 'Ristorante Kwizien Divien', 13.6, 3.6, '16', 2.22, 6.14, 'Medium')
# (341091, 'La Bagatelle de Lou', 10.34, 5.0, '5', 1.67, 6.2, 'Medium')
# (416230, 'Rollin Smoke BBQ', 21.26, 3.9, '70', 3.41, 6.23, 'High')
# (34731, 'Meat and Eat', 16.48, 4.1, '18', 2.64, 6.25, 'Medium')
# (59729, "'t Hof van Rembrandt", 19.89, 4.4, '26', 3.18, 6.26, 'Medium')
# (276638, 'De Blauwe Schuit', 22.55, 4.1, '72', 3.6, 6.26, 'High')
# (121137, 'Karasu | Antwerpen', 19.36, 4.4, '23', 3.07, 6.31, 'Medium')
# (269936, 'Brasserie Van Bulck', 11.88, 3.2, '14', 1.87, 6.37, 'Medium')
# (227817, 'Mu-Ji Sushi', 10.38, 3.1, '11', 1.62, 6.39, 'Medium')
# (220120, 'Chalex Eetcafe Brasserie', 17.37, 4.4, '16', 2.71, 6.41, 'Medium')
# (306930, " L'italiano", 20.45, 3.6, '77', 3.19, 6.42, 'High')
# (151583, 'Gran Gusto Ristorante', 20.02, 4.3, '26', 3.11, 6.45, 'High')
# (352748, 'Julien', 11.43, 4.7, '6', 1.76, 6.49, 'Medium')
# (398309, 'Bodebar', 10.26, 4.2, '6', 1.58, 6.52, 'Medium')
# (108393, 'Neapolis', 13.37, 3.4, '15', 2.04, 6.55, 'Medium')
# (300661, 'Blend Wines ', 14.44, 4.9, '8', 2.18, 6.63, 'Medium')
# (479059, 'CIAO BELLA brugge', 15.44, 3.7, '16', 2.28, 6.78, 'Medium')
# (98476, 'Gitan', 12.31, 4.4, '7', 1.81, 6.8, 'Medium')
# (403186, 'Agora ', 16.58, 4.4, '12', 2.4, 6.91, 'Medium')
# (421049, 'Karine Dendermonde', 10.38, 4.0, '6', 1.5, 6.92, 'Medium')
# (277667, 'Chez Eline', 12.53, 3.1, '14', 1.81, 6.93, 'Medium')
# (132828, 'Tarboush', 11.49, 3.4, '9', 1.61, 7.14, 'Medium')
# (287330, 'Hoffys Take Away', 18.92, 4.0, '19', 2.62, 7.22, 'Medium')
# (279404, 'Tabù Waterloo', 17.31, 4.1, '14', 2.39, 7.24, 'Medium')
# (281166, 'Café Luca', 12.89, 4.0, '8', 1.78, 7.25, 'Medium')
# (356282, 'Greek Lab', 15.28, 3.5, '15', 2.1, 7.28, 'Medium')
# (235287, 'Danieli Il Divino', 25.28, 4.3, '41', 3.46, 7.31, 'High')
# (36524, 'De Superette', 19.17, 4.8, '12', 2.62, 7.32, 'Medium')
# (495092, 'Sushi and Saki', 13.24, 3.4, '11', 1.78, 7.43, 'Medium')
# (287305, 'Trattoria Murano', 16.02, 4.8, '8', 2.13, 7.51, 'Medium')
# (28842, 'Shilling', 19.44, 3.8, '20', 2.53, 7.67, 'Medium')
# (378494, 'Grom Gelato ', 15.95, 3.8, '12', 2.07, 7.7, 'Medium')
# (411841, 'Sushi Corner ', 24.07, 4.2, '29', 3.12, 7.71, 'High')
# (400677, 'Strombolino', 15.86, 4.6, '8', 2.04, 7.76, 'Medium')
# (298724, 'Meridian 3', 13.6, 3.8, '8', 1.69, 8.05, 'Medium')
# (20897, 'Brasserie HOBS', 19.69, 3.8, '18', 2.44, 8.06, 'Medium')
# (242617, 'De Wijngaert', 13.04, 3.9, '7', 1.61, 8.12, 'Medium')
# (41307, 'Esaki', 13.02, 4.8, '5', 1.6, 8.14, 'Medium')
# (374461, 'Il Momento', 10.1, 3.3, '6', 1.24, 8.16, 'Medium')
# (184953, 'Chokdee Thai', 33.03, 4.4, '101', 4.0, 8.25, 'Premium')
# (224180, 'Chicken Tok Tok', 33.61, 4.4, '112', 4.04, 8.32, 'Premium')
# (33256, "L'Harmony", 20.87, 3.6, '21', 2.44, 8.56, 'High')
# (242451, 'L’Officina Da Franco & Giacomo', 17.95, 4.3, '9', 2.04, 8.81, 'Medium')
# (89095, 'Sushi Gourmet Hippodroom', 11.65, 3.8, '5', 1.27, 9.2, 'Medium')
# (52613, 'Neuhaus Antwerpen', 32.86, 4.7, '31', 3.55, 9.25, 'Premium')
# (428756, 'GROM Gelato - Brugge', 15.95, 3.4, '10', 1.7, 9.39, 'Medium')
# (254506, 'Amigo', 13.17, 4.2, '5', 1.4, 9.4, 'Medium')
# (52614, 'Neuhaus Gent', 34.24, 4.6, '36', 3.6, 9.51, 'Premium')
# (70129, 'Little Beirut', 13.6, 3.1, '8', 1.38, 9.87, 'Medium')
# (52615, 'Neuhaus Leuven', 34.88, 4.6, '33', 3.53, 9.88, 'Premium')
# (115588, "Epiphany's kitchen", 15.7, 4.6, '5', 1.53, 10.24, 'Medium')
# (132949, 'OINARIS', 14.92, 3.8, '6', 1.42, 10.47, 'Medium')
# (442394, 'Foodhall MarkEat', 19.45, 4.8, '6', 1.8, 10.8, 'Medium')
# (244177, 'Davinci Zuid', 14.48, 4.0, '5', 1.33, 10.86, 'Medium')
# (78200, 'Casa Mia Antwerpen', 15.56, 3.3, '7', 1.36, 11.45, 'Medium')
# (311352, 'Taverne de arcades', 17.3, 3.6, '7', 1.48, 11.67, 'Medium')
# (40902, 'Verso Café', 24.98, 4.8, '8', 2.13, 11.71, 'High')
# (279864, 'Fiskeskur + Dabba King', 16.0, 3.8, '5', 1.27, 12.63, 'Medium')
# (325347, 'restaurant de koetse', 23.5, 4.1, '7', 1.69, 13.92, 'High')
# (315590, 'Ottoman grillhouse', 52.95, 4.2, '66', 3.65, 14.52, 'Premium')
# (285061, 'Neuhaus ', 35.42, 4.6, '10', 2.3, 15.4, 'Premium')
# (285060, 'Neuhaus Woluwe Shopping', 32.31, 5.0, '6', 1.88, 17.23, 'Premium')
# (57153, 'Lobster Pot', 35.96, 4.1, '10', 2.05, 17.54, 'Premium')
# (283895, 'Neuhaus Hasselt', 44.31, 4.2, '12', 2.29, 19.34, 'Premium')

# %%
try :
    takeAwy = """SELECT
                        tw.menuItems.primarySlug,
                        tw.restaurants.name,
                        ROUND(AVG(tw.menuItems.price_float), 2) AS avg_price,
                        tw.restaurants.ratings,
                        tw.restaurants.ratingsNumber,
                        ROUND(
                            (tw.restaurants.ratings * tw.restaurants.ratingsNumber) / (tw.restaurants.ratingsNumber + 10), 2
                        ) AS weighted_ratings,
                        ROUND(
                            AVG(tw.menuItems.price_float) /
                            ((tw.restaurants.ratings * tw.restaurants.ratingsNumber) / (tw.restaurants.ratingsNumber + 10)), 2
                        ) AS price_to_weighted_rating_ratio,
                        CASE 
                            WHEN AVG(tw.menuItems.price_float) < 10 THEN 'Low'
                            WHEN AVG(tw.menuItems.price_float) BETWEEN 10 AND 20 THEN 'Medium'
                            WHEN AVG(tw.menuItems.price_float) BETWEEN 20 AND 30 THEN 'High'
                            ELSE 'Premium'
                        END AS price_bucket
                FROM
                    tw.menuItems
                INNER JOIN
                    tw.restaurants
                ON 
                    tw.menuItems.primarySlug = tw.restaurants.primarySlug
                WHERE
                    tw.menuItems.price_float IS NOT NULL 
                    AND tw.menuItems.price_float > 0 
                    AND tw.restaurants.ratings IS NOT NULL
                    AND tw.restaurants.ratings > 0
                    AND tw.restaurants.ratingsNumber IS NOT NULL
                    AND tw.restaurants.ratingsNumber > 0
                GROUP BY
                    tw.menuItems.primarySlug,
                    tw.restaurants.name,
                    tw.restaurants.ratings,
                    tw.restaurants.ratingsNumber
                HAVING
                    price_bucket != 'Low'
                    AND price_to_weighted_rating_ratio IS NOT NULL
                    AND avg_price IS NOT NULL  
                ORDER BY
                    price_to_weighted_rating_ratio ASC;"""
    takeAwy_results = conn.execute(takeAwy).fetchall()
    for row in takeAwy_results:
        print(row)
except sqlite3.OperationalError as e:
    print("Error:", e)
# Out:
# ('pizza-alba', 'Il Girasole', 10.13, 4.8, 1869, 4.77, 2.12, 'Medium')
# ('baskent-ohcange', 'Baskent Meerhout', 10.33, 4.9, 879, 4.84, 2.13, 'Medium')
# ('mehmet-hoeselt', 'Eethuis Mehmet', 10.07, 4.7, 996, 4.65, 2.16, 'Medium')
# ('gok', 'Restaurant Gok', 10.04, 4.8, 237, 4.61, 2.18, 'Medium')
# ('asya-pizzaria', 'Asya Pizzeria', 10.23, 4.7, 1151, 4.66, 2.2, 'Medium')
# ('sushi-mama', 'Sushi Mama', 10.16, 4.6, 2203, 4.58, 2.22, 'Medium')
# ('kwat', 'Kwat', 10.55, 4.8, 345, 4.66, 2.26, 'Medium')
# ('pizzeria-gloria', 'Pizzeria Gloria', 10.47, 4.7, 720, 4.64, 2.26, 'Medium')
# ('venus-8', 'Venus 8', 10.08, 4.6, 315, 4.46, 2.26, 'Medium')
# ('anatolia-23-1', 'Anatolia 23', 10.29, 4.6, 652, 4.53, 2.27, 'Medium')
# ('de-notenboom', 'De Notenboom', 10.96, 4.9, 706, 4.83, 2.27, 'Medium')
# ('pizza-di-trevi-1', 'Pizza Di Trevi', 10.71, 4.7, 4902, 4.69, 2.28, 'Medium')
# ('ocean-sushi-mortsel', 'Ocean Sushi', 10.28, 4.5, 1355, 4.47, 2.3, 'Medium')
# ('pizzeria-messina', 'Pizzeria Messina', 10.34, 4.6, 437, 4.5, 2.3, 'Medium')
# ('yoki-sushi-grill', 'Yoki Sushi & Grill', 10.12, 4.7, 146, 4.4, 2.3, 'Medium')
# ('baskent-averbode-1', 'Baskent Averbode', 10.2, 4.5, 509, 4.41, 2.31, 'Medium')
# ('goodys', "Goody's", 10.35, 4.5, 2219, 4.48, 2.31, 'Medium')
# ('maldinis-pizza-2660', "Maldini's Pizza", 10.69, 4.7, 736, 4.64, 2.31, 'Medium')
# ('18-sushi', '18 Sushi', 10.67, 4.7, 420, 4.59, 2.32, 'Medium')
# ('midyat-1', 'Midyat', 10.13, 4.4, 1551, 4.37, 2.32, 'Medium')
# ('diamondpizzaberchem', 'Diamond Pizza Berchem', 11.08, 4.8, 1088, 4.76, 2.33, 'Medium')
# ('heist-kebab', 'Heist Kebab', 10.05, 4.5, 230, 4.31, 2.33, 'Medium')
# ('pitta-bodrum-9200', 'Pitta Bodrum', 10.17, 4.4, 1138, 4.36, 2.33, 'Medium')
# ('pizza-tiamo', 'Pizzeria Tiamo', 10.1, 4.8, 94, 4.34, 2.33, 'Medium')
# ('pizzaria-gunther', 'Pizzaria Gunther', 10.3, 4.6, 237, 4.41, 2.33, 'Medium')
# ('kebap-oelegem', 'Kebab Oelegem', 10.67, 4.6, 1016, 4.56, 2.34, 'Medium')
# ('kingribs-beveren-waas', 'KingRibs', 11.01, 4.8, 505, 4.71, 2.34, 'Medium')
# ('ninki', 'Sushi Ninki', 10.24, 4.5, 379, 4.38, 2.34, 'Medium')
# ('oish-sushi', 'Oishī Sushi', 10.65, 4.6, 765, 4.54, 2.35, 'Medium')
# ('pizza-way', 'Pizza Way', 11.04, 4.8, 512, 4.71, 2.35, 'Medium')
# ('squadra-opdorp', 'Squadra Opdorp', 10.99, 4.8, 397, 4.68, 2.35, 'Medium')
# ('yummy-bowl', 'Yummy Bowl', 10.66, 4.9, 122, 4.53, 2.35, 'Medium')
# ('boucherie-wayez', 'Boucherie Wayez', 10.82, 4.8, 210, 4.58, 2.36, 'Medium')
# ('t-oud-lier', "'t Oud Lier", 10.89, 4.8, 247, 4.61, 2.36, 'Medium')
# ('anka-kebap', 'Anka Kebab', 10.0, 4.3, 531, 4.22, 2.37, 'Medium')
# ('asian-express', 'Asian Express', 10.08, 4.5, 173, 4.25, 2.37, 'Medium')
# ('euro-kebab', 'Euro Kebab-Pizza', 10.25, 4.5, 250, 4.33, 2.37, 'Medium')
# ('le-palais-dasie-comines', "Le Palais d'Asie", 10.12, 4.7, 100, 4.27, 2.37, 'Medium')
# ('maharaja-tandoori-2', 'Maharaja Tandoori', 10.36, 4.4, 1341, 4.37, 2.37, 'Medium')
# ('maison-du-liban', 'O Beyrouth', 10.95, 4.7, 635, 4.63, 2.37, 'Medium')
# ('mozaique', 'Mozaique', 10.05, 4.8, 76, 4.24, 2.37, 'Medium')
# ('musty-kebab', 'Musty Kebab', 10.26, 4.4, 657, 4.33, 2.37, 'Medium')
# ('qi-tian', 'Qi Tian', 10.17, 4.3, 1254, 4.27, 2.38, 'Medium')
# ('aladin', 'Aladin', 10.15, 4.3, 798, 4.25, 2.39, 'Medium')
# ('miyako', 'Miyako', 10.54, 4.5, 472, 4.41, 2.39, 'Medium')
# ('efes-mol-1', 'Efes Mol', 10.02, 4.2, 2085, 4.18, 2.4, 'Medium')
# ('pizza-hanoo-1', 'Pizza Hanoo', 10.04, 4.4, 190, 4.18, 2.4, 'Medium')
# ('huzur-pizzeria-kebab-leopoldsburg', 'Huzur Pizzeria Kebab', 10.95, 4.6, 805, 4.54, 2.41, 'Medium')
# ('pizzalijn-berchem-1', 'Pizzalijn Berchem', 11.15, 4.7, 561, 4.62, 2.41, 'Medium')
# ('plaza-snacks', 'Plaza Snacks', 10.55, 4.9, 84, 4.38, 2.41, 'Medium')
# ('wang-buizingen', 'Wang', 10.66, 4.7, 165, 4.43, 2.41, 'Medium')
# ('au-fond-du-2500', 'Au Fond Du', 10.86, 4.8, 140, 4.48, 2.42, 'Medium')
# ('la-grande-muraille-simonis-1', 'La Grande Muraille Simonis', 11.02, 4.6, 937, 4.55, 2.42, 'Medium')
# ('pizza-place-londerzeel', 'Pizza Place', 10.59, 4.4, 1474, 4.37, 2.42, 'Medium')
# ('istanbul-hamme-1', 'Pizza Istanbul', 11.04, 4.6, 777, 4.54, 2.43, 'Medium')
# ('jerusalemgenk', 'Jerusalem', 10.73, 4.5, 547, 4.42, 2.43, 'Medium')
# ('sushi-centraal', 'Sushi Centraal', 10.11, 4.6, 96, 4.17, 2.43, 'Medium')
# ('gli-amici', 'Gli Amici', 11.22, 4.8, 238, 4.61, 2.44, 'Medium')
# ('makiline', 'Makiline', 10.67, 4.4, 1354, 4.37, 2.44, 'Medium')
# ('pitta-mr-food', 'Pizza Mr. Food', 10.45, 4.3, 1832, 4.28, 2.44, 'Medium')
# ('qivvi', 'Qivvi', 10.05, 4.7, 70, 4.11, 2.44, 'Medium')
# ('thai-moury-molenbeek', 'Thaï Moury', 10.19, 4.2, 940, 4.16, 2.45, 'Medium')
# ('ping', 'Ping', 11.47, 4.7, 1344, 4.67, 2.46, 'Medium')
# ('surin-thai-kitchen-grimbergen', 'Surin Thai Kitchen', 11.16, 4.8, 171, 4.53, 2.46, 'Medium')
# ('tortue-pizza', 'Tortue Pizza', 10.0, 4.1, 952, 4.06, 2.46, 'Medium')
# ('traiteur-simyur', 'Traiteur Sim & Yur', 11.03, 4.7, 208, 4.48, 2.46, 'Medium')
# ('wok-city', 'Wok City', 11.01, 4.5, 2069, 4.48, 2.46, 'Medium')
# ('argonautes', 'Argonautes', 11.79, 4.8, 1485, 4.77, 2.47, 'Medium')
# ('bella-italia-lennik', 'Bella Italia', 10.92, 4.6, 241, 4.42, 2.47, 'Medium')
# ('bella-rosa', 'Bella Rosa', 10.54, 4.3, 1361, 4.27, 2.47, 'Medium')
# ('fubao-uccle', 'Fubao', 10.43, 4.3, 540, 4.22, 2.47, 'Medium')
# ('hoshi-hoshi', 'Hoshi Hoshi', 10.65, 4.4, 533, 4.32, 2.47, 'Medium')
# ('resto-borsa', 'Resto Borsa', 10.05, 4.1, 1762, 4.08, 2.47, 'Medium')
# ('traiteur-liu', "Tang's Kitchenette", 11.23, 4.6, 884, 4.55, 2.47, 'Medium')
# ('unal-snacks', 'Unal Snacks', 11.44, 4.7, 691, 4.63, 2.47, 'Medium')
# ('boudas-wok-deurne', "Bouda's Wok", 10.99, 4.5, 688, 4.44, 2.48, 'Medium')
# ('pizza-di-trevi-2', 'Pizza Di Trevi', 11.06, 4.5, 1037, 4.46, 2.48, 'Medium')
# ('sultan-testelt-1', 'Sultan Testelt', 10.29, 4.2, 847, 4.15, 2.48, 'Medium')
# ('xin-yuan', 'Xin Yuan', 10.87, 4.5, 356, 4.38, 2.48, 'Medium')
# ('au-vogelenzang', 'Au Vogelenzang', 11.15, 4.9, 107, 4.48, 2.49, 'Medium')
# ('eethuis-orient', 'Orient KURINGEN', 10.86, 4.4, 1059, 4.36, 2.49, 'Medium')
# ('kimchi-sushi', 'Kimchi Sushi', 11.29, 4.7, 290, 4.54, 2.49, 'Medium')
# ('pizza-pisa', 'Pizza Pisa', 10.76, 4.4, 577, 4.33, 2.49, 'Medium')
# ('pizza-viaaa', 'Pizza Viaaa', 11.89, 4.8, 2114, 4.78, 2.49, 'Medium')
# ('sensei-sushi-meiser', 'Sensei Sushi Meiser', 10.24, 4.5, 106, 4.11, 2.49, 'Medium')
# ('anatolian-kebab', 'Anatolian Kebap', 10.51, 4.3, 432, 4.2, 2.5, 'Medium')
# ('bo-zin', 'Bô-Zin', 10.63, 4.4, 273, 4.24, 2.5, 'Medium')
# ('iman-halal-tandoori', 'Iman Hallal Tandoori', 10.42, 4.2, 1237, 4.17, 2.5, 'Medium')
# ('la-casa-mia-wuustwezel', 'La Casa Mia', 10.92, 4.7, 128, 4.36, 2.5, 'Medium')
# ('pizza-phone-antwerpen-zuid', 'Pizza Phone', 11.67, 4.7, 1387, 4.67, 2.5, 'Medium')
# ('akira', 'Akira', 10.2, 4.6, 75, 4.06, 2.51, 'Medium')
# ('au-village-de-shanghai-1030', 'Au Village de Shanghai', 11.11, 4.7, 159, 4.42, 2.51, 'Medium')
# ('eethuis-troja', 'Eethuis Troja', 10.68, 4.3, 825, 4.25, 2.51, 'Medium')
# ('impalas', "GooDiees by Impala'S", 11.6, 4.8, 252, 4.62, 2.51, 'Medium')
# ('kingribs-dendermonde', 'KingRibs', 10.96, 4.6, 181, 4.36, 2.51, 'Medium')
# ('mazzerina-genval', 'Mazzerina', 11.39, 4.7, 266, 4.53, 2.51, 'Medium')
# ('pizza-heat-wetteren', 'Pizza Heat', 12.25, 4.9, 1786, 4.87, 2.51, 'Medium')
# ('swagat', 'Swagat', 10.13, 4.3, 148, 4.03, 2.51, 'Medium')
# ('chateau-pineau', 'Chateau Pineau', 11.36, 4.8, 158, 4.51, 2.52, 'Medium')
# ('meli-mely', 'Meli Mely', 11.47, 4.6, 1136, 4.56, 2.52, 'Medium')
# ('pizza-pasta-concept', 'Pizza Pasta Concept', 12.07, 4.8, 2894, 4.78, 2.52, 'Medium')
# ('boelekewis', 'Boelekewis', 11.65, 4.9, 157, 4.61, 2.53, 'Medium')
# ('heide', 'Heide', 10.02, 4.1, 272, 3.95, 2.53, 'Medium')
# ('kingsrib', 'KingRibs', 10.9, 4.4, 478, 4.31, 2.53, 'Medium')
# ('pitta-pizza-izmir-eeklo', 'Pitta & Pizza Izmir Eeklo', 11.67, 4.7, 547, 4.62, 2.53, 'Medium')
# ('snack-opwijk', 'Snack Opwijk', 10.54, 4.3, 309, 4.17, 2.53, 'Medium')
# ('de-pizzabakker', 'De Pizzabakker', 11.1, 4.4, 1394, 4.37, 2.54, 'Medium')
# ('milano-pizza-grill', 'Milano Pizza Grill', 10.84, 4.3, 1209, 4.26, 2.54, 'Medium')
# ('oasis-pizza-kebab', 'Pizza & Kebab Zeebrugge', 10.17, 4.2, 198, 4.0, 2.54, 'Medium')
# ('pizza-yolo-ieper', 'Pizza Yolo', 11.86, 4.7, 1254, 4.66, 2.54, 'Medium')
# ('pizzeria-nina', 'Pizzeria Nina', 11.02, 4.5, 280, 4.34, 2.54, 'Medium')
# ('pizzeria-valsugana', 'Pizzeria Valsugana', 10.99, 4.4, 555, 4.32, 2.54, 'Medium')
# ('snack-unal', 'Snack Unal', 11.21, 4.5, 553, 4.42, 2.54, 'Medium')
# ('subayaku-geraardsbergen', 'Subayaku', 10.94, 4.5, 224, 4.31, 2.54, 'Medium')
# ('can-pizzeria', 'Can Pizzeria', 10.33, 4.2, 269, 4.05, 2.55, 'Medium')
# ('da-riccardo', 'Pastabar Da Riccardo', 11.12, 4.7, 127, 4.36, 2.55, 'Medium')
# ('eethuis-taksim', 'Eethuis Taksim', 10.28, 4.1, 573, 4.03, 2.55, 'Medium')
# ('grissini', 'Pizzeria Grissini & Kebab House', 11.18, 4.4, 2048, 4.38, 2.55, 'Medium')
# ('kaya-holsbeek', 'Kaya', 10.97, 4.6, 142, 4.3, 2.55, 'Medium')
# ('pizza-king-family', 'Pizza King Family', 10.4, 4.1, 2397, 4.08, 2.55, 'Medium')
# ('pizza-lesta', "Pizza L'Esta", 12.15, 4.9, 372, 4.77, 2.55, 'Medium')
# ('singapore', 'Singapore', 11.96, 4.7, 3491, 4.69, 2.55, 'Medium')
# ('speedy', 'Speedy Pizzas', 10.79, 4.3, 598, 4.23, 2.55, 'Medium')
# ('baskent-balen-balen', 'Baskent Balen', 10.34, 4.1, 658, 4.04, 2.56, 'Medium')
# ('by-blankenberge', 'Buon Appetito', 11.43, 4.5, 1547, 4.47, 2.56, 'Medium')
# ('doy-doys', 'Doy Doys', 10.07, 4.3, 105, 3.93, 2.56, 'Medium')
# ('mai-pizza', 'Grand Station', 10.97, 4.4, 371, 4.28, 2.56, 'Medium')
# ('yammi-yammi', 'Yammi Yammi', 10.05, 4.2, 147, 3.93, 2.56, 'Medium')
# ('il-colosseo-bruxelles', 'Il Colosseo', 10.69, 4.5, 124, 4.16, 2.57, 'Medium')
# ('le-pont-de-luttre', 'Le Pont De Luttre', 11.23, 4.4, 1538, 4.37, 2.57, 'Medium')
# ('lorchidee-de-chine', "L'orchidee de chine", 11.55, 4.7, 211, 4.49, 2.57, 'Medium')
# ('mandarin', 'Mandarin', 10.76, 4.2, 9824, 4.2, 2.57, 'Medium')
# ('mister-pizza-merelbeke', 'Mister Pizza', 10.94, 4.3, 996, 4.26, 2.57, 'Medium')
# ('pizza-pasta-locale', 'Pizza Pasta Locale', 10.89, 4.4, 264, 4.24, 2.57, 'Medium')
# ('pizza-town-houtem', 'Pizza Town Houtem', 11.24, 4.6, 189, 4.37, 2.57, 'Medium')
# ('sabina-pizza-dinner', 'Sabina Pizza & Dinner', 10.98, 4.4, 351, 4.28, 2.57, 'Medium')
# ('shangri-la-oupeye', 'Shangri-la', 12.0, 4.8, 363, 4.67, 2.57, 'Medium')
# ('gold-pizza', 'Gold Pizza', 11.24, 4.5, 327, 4.37, 2.58, 'Medium')
# ('masala-express-1', 'Masala Express', 11.45, 4.5, 638, 4.43, 2.58, 'Medium')
# ('pizzeria-bella-vissenaken', 'Pizzeria Bella', 10.64, 4.2, 499, 4.12, 2.58, 'Medium')
# ('pizzeria-papino-1', 'Pizzeria Papino', 10.04, 4.6, 55, 3.89, 2.58, 'Medium')
# ('sezer-snack-1', 'Sezer Snack-Pizza', 11.36, 4.4, 10368, 4.4, 2.58, 'Medium')
# ('speedy-company', 'Speedy Pizza', 12.05, 4.8, 374, 4.67, 2.58, 'Medium')
# ('apollon-vilvoorde', 'Apollon', 11.93, 4.7, 489, 4.61, 2.59, 'Medium')
# ('cesars', 'Cesars', 12.14, 4.7, 3632, 4.69, 2.59, 'Medium')
# ('chez-bibo', 'Chez Bibo', 10.43, 4.2, 224, 4.02, 2.59, 'Medium')
# ('de-zwaan-hoboken', 'De Zwaan', 11.3, 4.4, 1466, 4.37, 2.59, 'Medium')
# ('dr-grill', 'Dr. Grill', 11.24, 4.4, 785, 4.34, 2.59, 'Medium')
# ('eethuis-istanbul-turnhout', 'Eethuis Istanbul', 10.03, 3.9, 1240, 3.87, 2.59, 'Medium')
# ('himalayan-cuisine-berchem', 'Himalayan Cuisine', 12.03, 4.8, 300, 4.65, 2.59, 'Medium')
# ('pizza-heat-steenhuffel', 'Pizza Heat', 12.01, 4.7, 736, 4.64, 2.59, 'Medium')
# ('pizza-hot-kruibeke', 'Pizza HOT', 11.6, 4.6, 349, 4.47, 2.59, 'Medium')
# ('pizza-phone-merksem', 'Pizza Phone', 11.55, 4.5, 1101, 4.46, 2.59, 'Medium')
# ('pizza-phone-mortsel', 'Pizza Phone', 11.58, 4.5, 1338, 4.47, 2.59, 'Medium')
# ('pizza-valo', 'Pizza Valo', 10.92, 4.6, 109, 4.21, 2.59, 'Medium')
# ('pizzeria-de-ster', 'De ster pizzeria & doner kebap', 11.76, 4.6, 704, 4.54, 2.59, 'Medium')
# ('sathi-sushi', 'Aalst Sushi', 11.59, 4.5, 1935, 4.48, 2.59, 'Medium')
# ('amon-hoboken', 'Amon', 10.07, 3.9, 1220, 3.87, 2.6, 'Medium')
# ('deluxe-burger-dendermonde', 'Deluxe Burger Dendermonde', 10.83, 4.3, 322, 4.17, 2.6, 'Medium')
# ('p-p', 'Pizzeria Per Passione', 11.91, 4.6, 1799, 4.57, 2.6, 'Medium')
# ('phoenix-garden', 'Phoenix Garden', 11.1, 4.3, 1703, 4.27, 2.6, 'Medium')
# ('pidem', 'Pidem', 11.1, 4.5, 181, 4.26, 2.6, 'Medium')
# ('pizza-lestina', 'Pizza Lestina', 11.34, 4.5, 337, 4.37, 2.6, 'Medium')
# ('pizzeria-pinocchio-1930-zaventem', 'Pizzeria Pinocchio', 10.76, 4.3, 255, 4.14, 2.6, 'Medium')
# ('tasty-pizza-1030', 'Tasty Pizza', 11.87, 4.6, 1271, 4.56, 2.6, 'Medium')
# ('traiteur-tuk-tuk', 'Traiteur Tuk-Tuk', 10.49, 4.1, 696, 4.04, 2.6, 'Medium')
# ('apollo-pizza', 'Apollo Pizza', 11.98, 4.7, 402, 4.59, 2.61, 'Medium')
# ('morgana-ribs', 'KingRibs', 10.9, 4.2, 2154, 4.18, 2.61, 'Medium')
# ('pizza-di-roma-harelbeke', 'Pizza Di Roma', 11.9, 4.6, 1166, 4.56, 2.61, 'Medium')
# ('pizza-phone-turnhout', 'Pizza Phone', 11.18, 4.3, 2400, 4.28, 2.61, 'Medium')
# ('pizzaslice', 'Pizza Slice', 11.69, 4.5, 1593, 4.47, 2.61, 'Medium')
# ('sensei-sushi', 'Sensei Sushi Jette', 10.66, 4.1, 3975, 4.09, 2.61, 'Medium')
# ('fansa', 'Fansa', 10.92, 4.2, 1028, 4.16, 2.62, 'Medium')
# ('il-gusto-pizzeria', 'Il Gusto Pizzeria', 11.24, 4.3, 2361, 4.28, 2.62, 'Medium')
# ('la-monte-carlo', 'La Monte Carlo', 10.89, 4.2, 1022, 4.16, 2.62, 'Medium')
# ('oremare', 'Toscana', 11.74, 4.5, 1951, 4.48, 2.62, 'Medium')
# ('pep-pino', 'Pep & Pino', 10.84, 4.7, 73, 4.13, 2.62, 'Medium')
# ('sushi-wetteren', 'Sushi Wetteren', 11.21, 4.6, 131, 4.27, 2.62, 'Medium')
# ('taste-king-pizza', 'Taste King Pizza', 11.22, 4.3, 1732, 4.28, 2.62, 'Medium')
# ('wok-masala', 'Wok Masala', 10.39, 4.4, 90, 3.96, 2.62, 'Medium')
# ('baskent-peer', 'Baskent Peer', 10.95, 4.2, 1386, 4.17, 2.63, 'Medium')
# ('la-pizzetta-1', 'La Pizzetta', 11.08, 4.3, 499, 4.22, 2.63, 'Medium')
# ('pizza-bulls', 'Pizza Bulls', 10.91, 4.2, 936, 4.16, 2.63, 'Medium')
# ('pizza-gustosa', 'Pizza Gustosa', 12.02, 4.6, 1382, 4.57, 2.63, 'Medium')
# ('pronto-blankenberge', 'Pizza Pronto', 11.79, 4.5, 2578, 4.48, 2.63, 'Medium')
# ('benvenuto-bxl', 'Benvenuto', 10.02, 4.7, 42, 3.8, 2.64, 'Medium')
# ('bia-mara-leuven', 'Bia Mara', 10.13, 4.3, 83, 3.84, 2.64, 'Medium')
# ('eethuis-istanbul-ramsel-1', 'Eethuis Istanbul', 10.74, 4.2, 301, 4.06, 2.64, 'Medium')
# ('le-croissant', 'Le Croissant', 11.71, 4.5, 676, 4.43, 2.64, 'Medium')
# ('pizza-florida', 'Pizza Florida', 11.98, 4.8, 169, 4.53, 2.64, 'Medium')
# ('pizza-pita-ege-2', 'Pizza Pita Ege 2', 10.14, 3.9, 592, 3.84, 2.64, 'Medium')
# ('asmin', 'Asmin', 11.01, 4.3, 297, 4.16, 2.65, 'Medium')
# ('bosphore-grill', 'Bosphore Grill', 11.33, 4.5, 196, 4.28, 2.65, 'Medium')
# ('pizza-pitta-flora', 'Pizza Pitta Flora', 11.34, 4.3, 1799, 4.28, 2.65, 'Medium')
# ('sebo-tongeren', 'Sebo', 10.73, 4.2, 254, 4.04, 2.65, 'Medium')
# ('sultan', 'King Of Kebab', 12.08, 4.6, 1353, 4.57, 2.65, 'Medium')
# ('thai-break', 'Thai Break', 11.76, 4.6, 285, 4.44, 2.65, 'Medium')
# ('venus-7', 'Venus 7', 10.01, 3.9, 314, 3.78, 2.65, 'Medium')
# ('brasserie-du-tennis-woluwe', 'Brasserie du Tennis', 11.96, 4.7, 219, 4.49, 2.66, 'Medium')
# ('de-chef-1', 'De Chef', 10.27, 3.9, 1177, 3.87, 2.66, 'Medium')
# ('kyoto-1', 'Kyoto', 10.55, 4.6, 63, 3.97, 2.66, 'Medium')
# ('ninja-restaurant', 'Ninja Restaurant', 12.64, 4.8, 912, 4.75, 2.66, 'Medium')
# ('pizza-heat-1', 'Pizza Heat Berlare', 12.15, 4.6, 1099, 4.56, 2.66, 'Medium')
# ('pizza-heat-3', 'Pizza Heat', 11.27, 4.3, 599, 4.23, 2.66, 'Medium')
# ('scallies-ribs-1', "Scallie's Kitchen", 12.14, 4.6, 1199, 4.56, 2.66, 'Medium')
# ('sofram', 'Sofram', 10.63, 4.2, 200, 4.0, 2.66, 'Medium')
# ('sushi-city-oudenaarde', 'Sushi City', 10.3, 4.4, 74, 3.88, 2.66, 'Medium')
# ('belchicken-overpoortstraat', 'Belchicken Overpoortstraat', 10.19, 3.9, 430, 3.81, 2.67, 'Medium')
# ('pitza-service-3', 'Pitza Service', 11.69, 4.4, 1862, 4.38, 2.67, 'Medium')
# ('pizza-boxx', 'Pizza Boxx', 11.04, 4.3, 244, 4.13, 2.67, 'Medium')
# ('pizza-heat-temse', 'Pizza Heat Wachtebeke', 11.67, 4.4, 1395, 4.37, 2.67, 'Medium')
# ('shahi-tandor', 'Shahi Tandor', 10.67, 4.2, 198, 4.0, 2.67, 'Medium')
# ('eethuis-pasa', 'Pizza kebap Pasa', 10.98, 4.2, 405, 4.1, 2.68, 'Medium')
# ('eight-sushi', 'Eight Sushi', 12.67, 4.8, 674, 4.73, 2.68, 'Medium')
# ('millennium', 'Millenium Kebap', 11.19, 4.3, 329, 4.17, 2.68, 'Medium')
# ('pizza-berneau', 'Pizza Berneau', 10.4, 4.1, 179, 3.88, 2.68, 'Medium')
# ('pizza-heat-zottegem', 'Pizza Heat Zottegem', 11.24, 4.3, 415, 4.2, 2.68, 'Medium')
# ('pizzaheat', 'Pizza Heat Dendermonde', 11.97, 4.5, 1545, 4.47, 2.68, 'Medium')
# ('royale-pizza-express', 'Royale Pizza Express', 10.69, 4.1, 380, 3.99, 2.68, 'Medium')
# ('sushi-land', 'Sushi Land', 11.21, 4.3, 368, 4.19, 2.68, 'Medium')
# ('bosphorus-alken-1', 'Bosphorus', 10.16, 3.9, 324, 3.78, 2.69, 'Medium')
# ('eethuis-yuksel', 'Eethuis Yuksel', 11.17, 4.2, 1004, 4.16, 2.69, 'Medium')
# ('favoriet', 'Favoriete', 10.14, 3.9, 285, 3.77, 2.69, 'Medium')
# ('grill-house-centrum-genk', 'Grill House Centrum', 10.71, 4.1, 319, 3.98, 2.69, 'Medium')
# ('keyf-lounge', 'Keyf Lounge', 11.62, 4.9, 75, 4.32, 2.69, 'Medium')
# ('pitta-new-york-hamme-1', 'Pitta New York', 10.44, 4.1, 172, 3.87, 2.69, 'Medium')
# ('pizza-talia-lier', 'Pizza Talia', 11.22, 4.2, 1770, 4.18, 2.69, 'Medium')
# ('pizzeria-casa-grande', 'Pizzeria Casa Grande', 12.08, 4.6, 441, 4.5, 2.69, 'Medium')
# ('les-4-gouts', 'Les 4 Goûts', 11.09, 4.5, 105, 4.11, 2.7, 'Medium')
# ('pizza-heat-zele', 'Pizza Heat', 11.99, 4.5, 740, 4.44, 2.7, 'Medium')
# ('sushi-ledeberg-1', 'Sushi Ledeberg', 10.48, 4.2, 122, 3.88, 2.7, 'Medium')
# ('sushi-merksem', 'Sushi Merksem', 12.43, 4.7, 469, 4.6, 2.7, 'Medium')
# ('xu-jian-li', 'La Cité du Bonheur', 12.27, 4.6, 720, 4.54, 2.7, 'Medium')
# ('isis-1', 'Isis', 10.5, 3.9, 1814, 3.88, 2.71, 'Medium')
# ('la-cite-de-pekin', 'La Cité de Pékin', 10.75, 4.4, 91, 3.96, 2.71, 'Medium')
# ('liman', 'Liman Grill House', 12.03, 4.6, 291, 4.45, 2.71, 'Medium')
# ('pizza-deal-boechout', 'Pizza Deal', 12.62, 4.7, 1036, 4.66, 2.71, 'Medium')
# ('citron-vert-mouscron', 'Citron Vert', 10.54, 4.4, 73, 3.87, 2.72, 'Medium')
# ('king-pizza-merchtem', 'King Pizza', 11.25, 4.2, 648, 4.14, 2.72, 'Medium')
# ('libanese-snack', 'Libanese Snack', 11.03, 4.3, 161, 4.05, 2.72, 'Medium')
# ('pizza-star', 'Pizza Star', 11.61, 4.3, 1449, 4.27, 2.72, 'Medium')
# ('pizzeria-la-stella', 'Pizzeria La Stella', 11.34, 4.2, 1870, 4.18, 2.72, 'Medium')
# ('pyramide-hamont', 'Pyramide', 10.92, 4.9, 45, 4.01, 2.72, 'Medium')
# ('sint-lievens-sushihuis', 'Sint-Lievens Sushihuis', 11.85, 4.7, 129, 4.36, 2.72, 'Medium')
# ('thai-take-away-saengrawee', 'Thai Take Away Saengrawee', 11.71, 4.7, 109, 4.31, 2.72, 'Medium')
# ('arata-sushi', 'Arata Sushi', 12.97, 4.8, 906, 4.75, 2.73, 'Medium')
# ('everest-sushi', 'Everest Sushi', 11.41, 4.5, 132, 4.18, 2.73, 'Medium')
# ('pizza-verdi', 'Pizza Verdi', 11.83, 4.4, 697, 4.34, 2.73, 'Medium')
# ('sim-pizza', 'Sim Pizza', 12.28, 4.5, 7030, 4.49, 2.73, 'Medium')
# ('twilightsushi', 'Twilightsushi', 12.76, 4.8, 381, 4.68, 2.73, 'Medium')
# ('baskent-tessenderlo', 'Baskent Tessenderlo', 10.09, 3.7, 2070, 3.68, 2.74, 'Medium')
# ('nazar-pizza-kebap-putte-2', 'Nazar Pizza Kebap', 10.53, 3.9, 657, 3.84, 2.74, 'Medium')
# ('pizza-babbi-ledeberg', 'Pizza Babbi', 12.17, 4.5, 788, 4.44, 2.74, 'Medium')
# ('venezia-2910', 'Venezia', 11.56, 4.3, 480, 4.21, 2.74, 'Medium')
# ('chens-takeaway-begijnendijk', "Chen's Takeaway", 10.91, 4.6, 63, 3.97, 2.75, 'Medium')
# ('fangs-hapje', "Fang's Hapje", 10.97, 4.3, 128, 3.99, 2.75, 'Medium')
# ('il-cardinale-lier', 'Il Cardinale Lier', 11.71, 4.4, 301, 4.26, 2.75, 'Medium')
# ('kebabstore', 'Kebap Store', 10.61, 3.9, 836, 3.85, 2.75, 'Medium')
# ('kent-mol', 'Kent', 10.91, 4.3, 116, 3.96, 2.75, 'Medium')
# ('pitza-service-sint-niklaas', 'Pitza Service', 13.38, 4.9, 1315, 4.86, 2.75, 'Medium')
# ('pizza-masters-hasselt-1', 'Pizza Masters', 12.9, 4.7, 3274, 4.69, 2.75, 'Medium')
# ('pizzeria-da-romy-waregem', 'Pizzeria Da Romy', 11.83, 4.4, 439, 4.3, 2.75, 'Medium')
# ('tian-tan', 'Tian Tan', 11.48, 4.2, 1365, 4.17, 2.75, 'Medium')
# ('eethuis-milas', 'Eethuis Milas', 10.26, 3.9, 202, 3.72, 2.76, 'Medium')
# ('pizza-pazzia-toto', 'Pizza Pazzia Totò Dilbeek', 11.16, 4.1, 788, 4.05, 2.76, 'Medium')
# ('squisito-belsele-1', 'Pizza Squisito Belsele', 11.5, 4.6, 96, 4.17, 2.76, 'Medium')
# ('sushi-deinze', 'Sushi Deinze', 10.9, 4.1, 262, 3.95, 2.76, 'Medium')
# ('cannur-kebab', 'Cannur Pizza Pasta Pitta BBQ', 11.81, 4.3, 1134, 4.26, 2.77, 'Medium')
# ('eethuis-carlos-aarschot', 'De Echte Eethuis Carlos', 11.08, 5, 599, 4.0, 2.77, 'Medium')
# ('la-campagna', 'La Campagna', 11.39, 4.2, 440, 4.11, 2.77, 'Medium')
# ('milas', 'Milas', 11.8, 4.9, 66, 4.26, 2.77, 'Medium')
# ('noumidia-resto-turnhout', 'Noumidia Resto', 10.12, 4.1, 82, 3.65, 2.77, 'Medium')
# ('pizza-bodrum-ochange', 'Pizza Bodrum', 11.14, 4.1, 540, 4.03, 2.77, 'Medium')
# ('ramses-ii-wuustwezel', 'Ramses II', 11.03, 4.1, 317, 3.97, 2.77, 'Medium')
# ('sushi-buzz', 'Sushi Buzz', 10.75, 4.3, 91, 3.87, 2.77, 'Medium')
# ('taverne-fonske', 'Taverne Fonske', 12.1, 4.6, 196, 4.38, 2.77, 'Medium')
# ('bavet-gent-verlorenkost', 'Bavet', 11.75, 4.3, 629, 4.23, 2.78, 'Medium')
# ('eethuis-istanbul-deurne', 'Eethuis Istanbul', 11.77, 4.3, 741, 4.24, 2.78, 'Medium')
# ('karine', 'Karine Grembergen', 11.83, 4.4, 297, 4.26, 2.78, 'Medium')
# ('nara-sushi-restaurant', 'Nara Sushi & Restaurant', 10.45, 4.5, 51, 3.76, 2.78, 'Medium')
# ('number-one-kraainem', 'Pizzeria Number One', 11.24, 4.1, 687, 4.04, 2.78, 'Medium')
# ('pinocchio-2170', 'Pinocchio', 12.71, 4.6, 2109, 4.58, 2.78, 'Medium')
# ('pitza-service-aalst', 'Pitza Service', 12.4, 4.5, 1054, 4.46, 2.78, 'Medium')
# ('pizza-phone-linkeroever', 'Pizza Phone', 11.49, 4.2, 667, 4.14, 2.78, 'Medium')
# ('siam-rice', 'Siam Rice', 12.37, 4.7, 180, 4.45, 2.78, 'Medium')
# ('simple-asia-woluwe', 'Simple Asia', 12.97, 4.7, 1139, 4.66, 2.78, 'Medium')
# ('sushi-paradise-gent-1', 'Sushi Paradise', 12.1, 4.4, 840, 4.35, 2.78, 'Medium')
# ('chawlas-2', 'Taste of India', 11.41, 4.3, 201, 4.1, 2.79, 'Medium')
# ('excellasagne', 'Excellasagne', 11.7, 4.4, 201, 4.19, 2.79, 'Medium')
# ('neko-sushi', 'Neko Sushi', 12.1, 4.9, 78, 4.34, 2.79, 'Medium')
# ('njoy', 'Njoy!', 11.75, 4.3, 441, 4.2, 2.79, 'Medium')
# ('pizza-palace-9185', 'Pizza Town Wachtebeke', 11.62, 4.3, 299, 4.16, 2.79, 'Medium')
# ('rn-royal', 'M&N Royal', 11.2, 4.1, 491, 4.02, 2.79, 'Medium')
# ('yaki-noodle', 'Yaki Noodle Bar', 12.21, 4.5, 337, 4.37, 2.79, 'Medium')
# ('kebab-time-lommel-1', 'Kebab Time', 10.3, 3.9, 167, 3.68, 2.8, 'Medium')
# ('limpero', "L'impero", 10.2, 4.2, 66, 3.65, 2.8, 'Medium')
# ('sd-lavigna', 'SD LaVigna', 10.48, 4.2, 81, 3.74, 2.8, 'Medium')
# ('sushi-poel', 'Sushi Poel', 11.82, 4.4, 240, 4.22, 2.8, 'Medium')
# ('adam-restaurant', 'Adam Restaurant', 10.06, 4.4, 44, 3.59, 2.81, 'Medium')
# ('andalucia-borgerhout', 'Andalucia', 11.16, 4.1, 313, 3.97, 2.81, 'Medium')
# ('baskent-3900', 'LindelBaskent', 10.83, 3.9, 872, 3.86, 2.81, 'Medium')
# ('de-mijn', 'De Mijn Kebab', 10.18, 3.8, 196, 3.62, 2.81, 'Medium')
# ('hokkaido-sushi', 'Hokkaido Sushi', 11.06, 4.2, 152, 3.94, 2.81, 'Medium')
# ('kebap-corner', 'Kebap Corner', 10.58, 3.8, 969, 3.76, 2.81, 'Medium')
# ('la-cite-du-dragon', 'La Cité Du Dragon', 12.02, 4.3, 1508, 4.27, 2.81, 'Medium')
# ('pizza-club', 'Pizza Club', 12.23, 4.4, 943, 4.35, 2.81, 'Medium')
# ('pizza-la-famiglia-1', 'Pizza La Famiglia', 11.3, 4.2, 220, 4.02, 2.81, 'Medium')
# ('pizza-sam-heist', 'Pizza Sam', 11.65, 4.2, 684, 4.14, 2.81, 'Medium')
# ('unique-asia', 'Unique Asia Sushi', 10.87, 3.9, 1106, 3.87, 2.81, 'Medium')
# ('boston-pizza-burgers-2', 'Boston Pizza & Burgers', 11.81, 4.2, 2607, 4.18, 2.82, 'Medium')
# ('huzur-pizzeria-kebab-peer-1', 'Huzur Pizzeria Kebab', 11.89, 4.3, 515, 4.22, 2.82, 'Medium')
# ('pitta-pizza-ludwig', 'Pitta Pizza Ludwig', 10.1, 3.6, 1697, 3.58, 2.82, 'Medium')
# ('pizza-paleis-haasdonk', 'Pizza Paleis Haasdonk', 11.43, 4.1, 917, 4.06, 2.82, 'Medium')
# ('populair', 'Populair', 11.15, 4.1, 282, 3.96, 2.82, 'Medium')
# ('cyprus-1', 'Cyprus Grieks', 12.61, 4.5, 934, 4.45, 2.83, 'Medium')
# ('eethuis-bidos', 'Eethuis Bidos', 11.71, 4.2, 592, 4.13, 2.83, 'Medium')
# ('il-viadotto', 'Il Viadotto', 11.15, 4.5, 70, 3.94, 2.83, 'Medium')
# ('indian-tadka-istanbul-kebab', 'Indian tadka & Istanbul kebab', 11.89, 4.5, 143, 4.21, 2.83, 'Medium')
# ('margherita-pizza', 'Pizza Margherita', 12.66, 4.6, 361, 4.48, 2.83, 'Medium')
# ('mei-wei-cheng', 'Mei Wei Cheng', 11.78, 4.2, 1094, 4.16, 2.83, 'Medium')
# ('pizza-de-hoek', 'Pizza De Hoek', 10.84, 4.3, 82, 3.83, 2.83, 'Medium')
# ('besushi-pokebowl', 'BeSushi Pokebowl', 11.22, 4.2, 155, 3.95, 2.84, 'Medium')
# ('felix-pizza', 'Felix Pizza', 12.68, 4.6, 321, 4.46, 2.84, 'Medium')
# ('il-capo', 'IL Capo', 13.25, 4.7, 1127, 4.66, 2.84, 'Medium')
# ('nihao-berchem', 'Nihao', 11.6, 4.1, 1864, 4.08, 2.84, 'Medium')
# ('pizza-express-bruxelles', 'Pizza Express', 12.0, 4.6, 115, 4.23, 2.84, 'Medium')
# ('pizza-lacasa', 'Pizza Lacasa', 10.23, 3.9, 121, 3.6, 2.84, 'Medium')
# ('pizza-toni-antwerpen', 'Pizza Toni', 13.21, 4.8, 316, 4.65, 2.84, 'Medium')
# ('pyramide-wijnegem', 'Pyramide grillroom pizza pita pasta', 11.01, 4.1, 174, 3.88, 2.84, 'Medium')
# ('traiteur-emmanuel', 'Traiteur Emmanuel', 12.48, 4.5, 395, 4.39, 2.84, 'Medium')
# ('yam-yam-bredene', 'Yam Yam', 12.55, 4.5, 516, 4.41, 2.84, 'Medium')
# ('gusto-di', 'Gusto Di Bruxelles', 10.74, 3.8, 1221, 3.77, 2.85, 'Medium')
# ('king-pizza-more-sint-niklaas', 'King Pizza & More', 12.4, 4.4, 827, 4.35, 2.85, 'Medium')
# ('pitza-service-antwerpen-dam', 'Pitza Service', 10.74, 3.8, 1182, 3.77, 2.85, 'Medium')
# ('rupel-sushi', 'Rupel Sushi', 12.47, 4.7, 137, 4.38, 2.85, 'Medium')
# ('sushi-more', 'Sushi & More', 12.06, 4.4, 250, 4.23, 2.85, 'Medium')
# ('vistamar', 'Vistamar', 11.88, 4.4, 178, 4.17, 2.85, 'Medium')
# ('yarsagumba', 'Yarsagumba', 12.28, 4.4, 444, 4.3, 2.85, 'Medium')
# ('asian-huis', 'Tandoori Indian restaurant & pizza', 10.61, 3.9, 196, 3.71, 2.86, 'Medium')
# ('fresh-overpelt', 'Fresh!', 11.93, 4.3, 325, 4.17, 2.86, 'Medium')
# ('gusto-1', 'Gusto!', 11.9, 4.7, 78, 4.17, 2.86, 'Medium')
# ('kalura', 'Kalura Pizzeria', 11.82, 4.3, 242, 4.13, 2.86, 'Medium')
# ('kebap-anatolie', 'Kebap Anatolia', 10.94, 3.9, 549, 3.83, 2.86, 'Medium')
# ('kokoro-sushi', 'Kokoro Sushi', 11.51, 4.1, 583, 4.03, 2.86, 'Medium')
# ('napoli-schoten', 'Napoli Schoten', 12.49, 4.4, 1402, 4.37, 2.86, 'Medium')
# ('nefertete', 'Nefertete', 10.45, 3.8, 251, 3.65, 2.86, 'Medium')
# ('pizza-heat-ochange', 'Pizza Town Waasmunster', 12.16, 4.3, 923, 4.25, 2.86, 'Medium')
# ('pizza-la-vince', 'Pizza La Vince', 10.66, 3.8, 509, 3.73, 2.86, 'Medium')
# ('sushi-mankai', 'Sushi Mankai', 12.38, 4.5, 243, 4.32, 2.86, 'Medium')
# ('sushi-zelzate', 'Sushi Zelzate', 10.72, 3.9, 253, 3.75, 2.86, 'Medium')
# ('tenshi-sushi-stockel', 'Tenshi Sushi', 12.05, 4.3, 463, 4.21, 2.86, 'Medium')
# ('de-pyramiden', 'De Pyramiden', 11.53, 4.1, 468, 4.01, 2.87, 'Medium')
# ('eetboutique-kaya', 'Eetboutique Kaya', 10.05, 4.6, 32, 3.5, 2.87, 'Medium')
# ('pizza-efe-itegem', 'Pizza Efe Itegem', 10.86, 3.8, 2243, 3.78, 2.87, 'Medium')
# ('pizza-overpoort-new', 'Pizza Overpoort', 11.17, 4.3, 94, 3.89, 2.87, 'Medium')
# ('pizza-talia-1800', 'Pizza Talia', 12.24, 4.3, 1030, 4.26, 2.87, 'Medium')
# ('pizza-zaga-2860', 'Pizza Zaga', 11.88, 4.3, 269, 4.15, 2.87, 'Medium')
# ('pizzeria-nasreddin-1210-1', 'Pizzeria Nasreddin', 11.71, 4.1, 1585, 4.07, 2.87, 'Medium')
# ('tenshi-sushi-uccle', 'Tenshi Sushi', 12.61, 4.5, 441, 4.4, 2.87, 'Medium')
# ('the-chopsticks', 'The Chopsticks', 12.72, 4.7, 168, 4.44, 2.87, 'Medium')
# ('trattoria-borsalino', 'Trattoria Borsalino', 12.66, 4.6, 240, 4.42, 2.87, 'Medium')
# ('woodiz-basilique', 'Woodiz Basilique', 11.23, 4.3, 99, 3.91, 2.87, 'Medium')
# ('eethuis-hoekske', 'Eethuis Hoekske', 11.75, 4.1, 1696, 4.08, 2.88, 'Medium')
# ('friturist', 'Sushi Berchem', 12.35, 4.5, 202, 4.29, 2.88, 'Medium')
# ('kangei-sushibar', 'Kangei Sushi & Curry House', 12.04, 4.2, 1744, 4.18, 2.88, 'Medium')
# ('pizza-heat-kalken', 'Pizza Heat', 11.96, 4.8, 64, 4.15, 2.88, 'Medium')
# ('pizza-roma-4', 'Pizza Roma', 11.62, 4.1, 668, 4.04, 2.88, 'Medium')
# ('pizza-service-plantin-en-moretuslei', 'Pizza Service', 10.89, 3.8, 1862, 3.78, 2.88, 'Medium')
# ('rosso-peperone', 'Rosso Peperone', 13.35, 4.8, 276, 4.63, 2.88, 'Medium')
# ('4-seizoene', '4 Seizoenen', 13.34, 4.7, 522, 4.61, 2.89, 'Medium')
# ('bavet-leuven', 'Bavet', 10.18, 3.6, 428, 3.52, 2.89, 'Medium')
# ('has-pide', 'Has Pide', 11.9, 4.4, 146, 4.12, 2.89, 'Medium')
# ('pizza-point-westerlo', 'Pizza Point', 12.19, 4.3, 486, 4.21, 2.89, 'Medium')
# ('pompei-borgloon', 'Pizzeria Pompei', 12.81, 4.7, 169, 4.44, 2.89, 'Medium')
# ('yammyou-sushi', 'YammYou Sushi', 11.47, 4.1, 309, 3.97, 2.89, 'Medium')
# ('acqua-e-farina-1', 'Acqua e Farina', 12.19, 4.5, 143, 4.21, 2.9, 'Medium')
# ('brozen-wavre', 'Brozen', 11.36, 4.4, 80, 3.91, 2.9, 'Medium')
# ('la-cucina-tradizionale', 'La Cucina tradizionale', 11.2, 4.4, 71, 3.86, 2.9, 'Medium')
# ('mega-grill-grez-doiceau', 'Méga Grill Grez Doiceau', 13.02, 4.7, 205, 4.48, 2.9, 'Medium')
# ('milo-bebap-pizza-pasta', 'Milo Kebap Pizza Pasta', 10.93, 3.8, 1544, 3.78, 2.9, 'Medium')
# ('petales-de-rose', 'Pétales de Rose', 10.61, 4.2, 67, 3.65, 2.9, 'Medium')
# ('pizza-efe', 'Pizza Efe Hulshout', 10.08, 3.5, 1559, 3.48, 2.9, 'Medium')
# ('pizza-sam-blankenberge', 'Pizza Sam', 11.73, 4.1, 722, 4.04, 2.9, 'Medium')
# ('pizza-venist', 'Pizza Venise', 12.7, 4.4, 2013, 4.38, 2.9, 'Medium')
# ('ponto-pasta', 'Punto Pasta Ixelles', 12.03, 4.2, 823, 4.15, 2.9, 'Medium')
# ('toscane', 'Toscane', 13.0, 4.6, 383, 4.48, 2.9, 'Medium')
# ('brasserie-foyer', 'Brasserie Foyer', 11.23, 4.8, 41, 3.86, 2.91, 'Medium')
# ('chickn-choice', "Chick'n Choice", 10.3, 3.6, 537, 3.53, 2.91, 'Medium')
# ('pittaverne', 'Pittaverne', 11.95, 4.2, 473, 4.11, 2.91, 'Medium')
# ('pizza-king-gent', 'Pizza King', 12.72, 4.4, 1619, 4.37, 2.91, 'Medium')
# ('ararat-sint-truiden-2', 'Ararat', 11.45, 4.1, 218, 3.92, 2.92, 'Medium')
# ('eethuis-meyman-kuringen', 'Eethuis Meyman', 10.74, 4.8, 33, 3.68, 2.92, 'Medium')
# ('king-pizza-vilvoorde-3', 'King Pizza Vilvoorde', 11.31, 4.2, 120, 3.88, 2.92, 'Medium')
# ('pizza-apetito', 'Pizza Apetito', 12.51, 4.3, 4201, 4.29, 2.92, 'Medium')
# ('pizzeria-margarita', 'Pizzeria Margarita', 12.06, 4.2, 625, 4.13, 2.92, 'Medium')
# ('sushi-oostakker', 'Sushi Oostakker', 10.72, 4.9, 30, 3.67, 2.92, 'Medium')
# ('aki-sushi-hasselt-1', 'Aki Sushi', 13.64, 4.8, 311, 4.65, 2.93, 'Medium')
# ('honderd-jaar', 'Honderd Jaar', 12.31, 4.3, 450, 4.21, 2.93, 'Medium')
# ('indian-curry-house', 'Indian Curry House', 12.53, 4.4, 350, 4.28, 2.93, 'Medium')
# ('okinawa-sushi-grill', 'Okinawa Sushi & Grill', 13.26, 4.6, 608, 4.53, 2.93, 'Medium')
# ('forno-alegna', "Forno A'Legna", 11.68, 4.4, 92, 3.97, 2.94, 'Medium')
# ('incontro', 'Incontro', 11.86, 4.4, 108, 4.03, 2.94, 'Medium')
# ('king-pizza-willebroek', 'King Pizza', 10.81, 3.7, 1842, 3.68, 2.94, 'Medium')
# ('pasta-ruffo', 'Pasta Ruffo', 11.77, 4.3, 137, 4.01, 2.94, 'Medium')
# ('primavera-hoboken', 'Primavera', 12.56, 4.3, 1345, 4.27, 2.94, 'Medium')
# ('rai-sushi-wok', 'Rai Sushi & Wok', 12.35, 4.3, 457, 4.21, 2.94, 'Medium')
# ('romeo-e-giulietta', 'Romeo E Giulietta', 12.65, 4.5, 214, 4.3, 2.94, 'Medium')
# ('anatolia-2320', 'Anatolia Hoogstraten', 11.96, 4.1, 820, 4.05, 2.95, 'Medium')
# ('la-cucina-anderlecht', 'La Cucina', 11.28, 4.4, 66, 3.82, 2.95, 'Medium')
# ('m84u', 'M84U', 12.89, 4.5, 325, 4.37, 2.95, 'Medium')
# ('om-sushi', 'Om Sushi', 12.32, 4.2, 1411, 4.17, 2.95, 'Medium')
# ('orient-hasselt', 'Orient', 11.07, 3.8, 855, 3.76, 2.95, 'Medium')
# ('sushi-match', 'Sushi Match', 11.5, 4.4, 77, 3.89, 2.95, 'Medium')
# ('sushi-royal', 'Sushi Royal', 13.12, 4.5, 997, 4.46, 2.95, 'Medium')
# ('thai-spice-rhode-saint-genese', 'Thai Spice', 12.63, 4.5, 200, 4.29, 2.95, 'Medium')
# ('thai-time', 'Thai Time', 12.92, 4.7, 138, 4.38, 2.95, 'Medium')
# ('les-2-orients-laeken', 'Les 2 Orients', 11.49, 3.9, 3392, 3.89, 2.96, 'Medium')
# ('ocean-sushi-antwerpen', 'Ocean Sushi', 11.85, 4.1, 440, 4.01, 2.96, 'Medium')
# ('pitaverne-mortsel-2', 'Pitaverne Mortsel', 11.19, 3.8, 2318, 3.78, 2.96, 'Medium')
# ('pizza-delicia-3-buggenhout', 'Pizza Delicia 3', 10.5, 3.6, 685, 3.55, 2.96, 'Medium')
# ('pizza-sultan-westmeerbeek', 'Pizza Sultan Westmeerbeek', 11.95, 4.2, 261, 4.05, 2.96, 'Medium')
# ('wokmomohouse', 'Wok & Momo House', 12.87, 4.5, 287, 4.35, 2.96, 'Medium')
# ('boston-pizza-lede', 'Boston Pizza', 12.54, 4.3, 569, 4.23, 2.97, 'Medium')
# ('pizza-napoli-oudenaarde', 'Pizza Napoli', 11.51, 3.9, 1570, 3.88, 2.97, 'Medium')
# ('pronto-pizza-laeken', 'Pronto Pizza', 12.72, 4.3, 2946, 4.29, 2.97, 'Medium')
# ('china-town-2640', 'China Town', 12.73, 4.3, 1174, 4.26, 2.98, 'Medium')
# ('eker-sushi', 'Eker Sushi', 12.22, 4.3, 208, 4.1, 2.98, 'Medium')
# ('pizza-talia-original-geraardsbergen', 'Pizza Talia Original', 13.34, 4.5, 1553, 4.47, 2.98, 'Medium')
# ('fuji-estaimpuis', 'Fuji', 10.31, 3.7, 135, 3.44, 2.99, 'Medium')
# ('golden-dynasty', 'Golden Dynasty', 13.05, 4.4, 1211, 4.36, 2.99, 'Medium')
# ('harvest', 'Sushi Harvest', 12.08, 4.2, 246, 4.04, 2.99, 'Medium')
# ('jai-ho', 'Jai Ho', 10.33, 3.5, 827, 3.46, 2.99, 'Medium')
# ('pizza-service-duffel', 'Pizza Service', 13.46, 4.9, 113, 4.5, 2.99, 'Medium')
# ('sora-sushi', 'Sora Sushi', 11.92, 4.6, 64, 3.98, 2.99, 'Medium')
# ('harumi-sushi-bar', 'Harumi Sushi Bar', 13.09, 4.8, 100, 4.36, 3.0, 'Medium')
# ('la-monte-carlo-city', 'La Monte Carlo City', 12.37, 4.2, 543, 4.12, 3.0, 'Medium')
# ('la-pomme-waterloo', 'La Pomme', 12.21, 4.1, 1518, 4.07, 3.0, 'Medium')
# ('pitta-marmaris-geraardsbergen', 'Pitta Marmaris', 10.33, 3.7, 135, 3.44, 3.0, 'Medium')
# ('royal-tokyo-sushi-bar', 'Royal Tokyo Sushi Bar Antwerpen', 13.1, 4.4, 1244, 4.36, 3.0, 'Medium')
# ('toshi-sushi-1', 'Toshi Sushi', 12.13, 4.2, 265, 4.05, 3.0, 'Medium')
# ('bella-vita-ekeren', 'Bella Vita', 12.84, 4.3, 1048, 4.26, 3.01, 'Medium')
# ('ikura-sushi', 'Ikura Sushi', 11.02, 3.7, 1125, 3.67, 3.01, 'Medium')
# ('leo-sushi-leopoldsburg', 'Leo Sushi', 12.64, 4.4, 205, 4.2, 3.01, 'Medium')
# ('mekong-river', 'Mekong River', 11.3, 3.8, 767, 3.75, 3.01, 'Medium')
# ('ottoman-eethuis', 'Ottoman Eethuis', 12.24, 4.1, 1418, 4.07, 3.01, 'Medium')
# ('pizza-bella-vista', 'Pizza Bella Vista', 12.66, 4.5, 142, 4.2, 3.01, 'Medium')
# ('pizza-delicio-2', 'Pizza Service Wilrijk', 14.36, 4.8, 1452, 4.77, 3.01, 'Medium')
# ('pizza-memo', 'Memo Pizza', 11.65, 3.9, 1439, 3.87, 3.01, 'Medium')
# ('pizza-trenti-schoten-1', 'Pizza Trenti', 13.04, 4.4, 617, 4.33, 3.01, 'Medium')
# ('tasty-sushi-grill-bar', 'Tasty Sushi Grill & Bar', 11.9, 4.2, 161, 3.95, 3.01, 'Medium')
# ('yamiii', 'Yamiii', 10.71, 4.5, 38, 3.56, 3.01, 'Medium')
# ('balls-glory-antwerpen-1', 'Balls & Glory', 11.49, 4.2, 96, 3.8, 3.02, 'Medium')
# ('chef-kebab', 'Cheff Kebab', 11.64, 3.9, 895, 3.86, 3.02, 'Medium')
# ('kyoto-sushibar', 'Kyoto Sushibar', 11.3, 4.4, 57, 3.74, 3.02, 'Medium')
# ('lilse-kebap', 'Lilse Kebap', 11.73, 3.9, 1774, 3.88, 3.02, 'Medium')
# ('nihao', 'Ni Hao - Moshi Moshi', 12.96, 4.3, 5104, 4.29, 3.02, 'Medium')
# ('pizza-clara', 'Pizza Clara', 13.07, 4.4, 572, 4.32, 3.02, 'Medium')
# ('pizza-corner-9170-1', 'Pizza Corner', 12.36, 4.2, 364, 4.09, 3.02, 'Medium')
# ('pizza-pasta-express-antwerpen', 'Pizza Pasta Express', 11.85, 4.8, 45, 3.93, 3.02, 'Medium')
# ('pizza-service-diest', 'Pizza Service', 13.74, 4.6, 1048, 4.56, 3.02, 'Medium')
# ('pizza-time-evergem', 'Pizza Time Evergem', 14.66, 4.9, 1148, 4.86, 3.02, 'Medium')
# ('restaurant-le-royal', 'Restaurant le Royal', 12.09, 5, 359, 4.0, 3.02, 'Medium')
# ('gustosita', 'Gustositá', 13.12, 4.7, 116, 4.33, 3.03, 'Medium')
# ('pizza-giorno-schoten', 'Pizza Giorno', 10.39, 3.5, 471, 3.43, 3.03, 'Medium')
# ('saray-tienen-1', 'Saray', 11.11, 3.7, 992, 3.66, 3.03, 'Medium')
# ('arax-1', 'Arax', 12.5, 4.4, 146, 4.12, 3.04, 'Medium')
# ('merdin-2-rotselaar', 'Merdin 2', 13.07, 4.5, 213, 4.3, 3.04, 'Medium')
# ('palermo-pizza', 'Palermo Pizza', 11.38, 3.9, 232, 3.74, 3.04, 'Medium')
# ('pitta-karine', 'Karine Dendermonde', 11.81, 3.9, 2377, 3.88, 3.04, 'Medium')
# ('royale-pizza-louvain', 'Royale Pizza', 11.07, 3.9, 143, 3.65, 3.04, 'Medium')
# ('urban-pizza-gent', 'Urban pizza', 11.12, 3.7, 883, 3.66, 3.04, 'Medium')
# ('beirut-restaurant-libanais', 'Beïrut-Restaurant Libanais', 12.6, 4.3, 253, 4.14, 3.05, 'Medium')
# ('bombay-inn', 'Bombay inn', 10.55, 4.7, 28, 3.46, 3.05, 'Medium')
# ('donatellos-pizza-izegem', "Donatello's Pizza", 12.75, 4.3, 346, 4.18, 3.05, 'Medium')
# ('el-gusto-oudenaarde', 'El Gusto - Mexican Food & Grill', 11.15, 4.5, 43, 3.65, 3.05, 'Medium')
# ('metropolis', 'Meatropolis', 10.29, 4.4, 33, 3.38, 3.05, 'Medium')
# ('pizzeria-1357', 'Pizzeria 1357', 10.56, 4.9, 24, 3.46, 3.05, 'Medium')
# ('seven-pizza', 'Seven Pizza', 12.96, 4.5, 167, 4.25, 3.05, 'Medium')
# ('sushi-leuven', 'Sushi Leuven', 11.69, 3.9, 530, 3.83, 3.05, 'Medium')
# ('barnaba-koersel', 'Barnaba', 12.95, 4.9, 63, 4.23, 3.06, 'Medium')
# ('bella-ciaoo', 'Bella Ciaoo', 10.45, 4.6, 29, 3.42, 3.06, 'Medium')
# ('kai-sushi-and-seafood', 'Kai Sushi and Seafood', 13.24, 4.5, 257, 4.33, 3.06, 'Medium')
# ('la-bella-neerpelt-3910', 'La Bella', 10.15, 4.1, 42, 3.31, 3.06, 'Medium')
# ('miku-sushi', 'Kaiso Sushi', 13.52, 4.5, 566, 4.42, 3.06, 'Medium')
# ('pizza-portofino', 'Portofino', 11.5, 3.8, 777, 3.75, 3.06, 'Medium')
# ('pizza-service-ekeren', 'Pizza Service', 12.45, 4.1, 1239, 4.07, 3.06, 'Medium')
# ('soho', 'Soho', 11.37, 4.2, 76, 3.71, 3.06, 'Medium')
# ('sushiboot', 'Sushiboot', 13.33, 4.6, 181, 4.36, 3.06, 'Medium')
# ('aroy-brasschaat', 'Aroy', 13.89, 4.6, 571, 4.52, 3.07, 'Medium')
# ('topogigio', 'TopoGigio', 10.9, 4.2, 54, 3.54, 3.07, 'Medium')
# ('wolfgang-leuven', 'Wolfgang', 11.0, 4.1, 69, 3.58, 3.07, 'Medium')
# ('yarsagumba-beveren', 'Yarsagumba', 12.16, 4.4, 90, 3.96, 3.07, 'Medium')
# ('bejacks', 'BE-JACKS', 13.82, 4.5, 5674, 4.49, 3.08, 'Medium')
# ('callpizza', 'Call Pizza', 13.19, 4.3, 2431, 4.28, 3.08, 'Medium')
# ('himalaya-gent-1', 'Himalaya', 10.54, 4.1, 50, 3.42, 3.08, 'Medium')
# ('nonna', 'La Nonna', 12.54, 4.2, 309, 4.07, 3.08, 'Medium')
# ('perle-dasie', "Perle d'Asie", 11.96, 3.9, 2295, 3.88, 3.08, 'Medium')
# ('pizza-trenti-aartselaar-2', 'Pizza Trenti', 13.21, 4.3, 2944, 4.29, 3.08, 'Medium')
# ('pizzaworld-1', 'Pizzaworld', 12.63, 4.2, 399, 4.1, 3.08, 'Medium')
# ('pizzeria-la-ora', 'Pizzeria la Ora', 12.35, 4.6, 68, 4.01, 3.08, 'Medium')
# ('thai-chiangmai', 'Thaï Chiangmai', 11.7, 4.1, 124, 3.79, 3.08, 'Medium')
# ('la-sardegna', 'La Sardegna', 12.61, 4.4, 127, 4.08, 3.09, 'Medium')
# ('new-asia-schaerbeek', 'New Asia', 11.91, 3.9, 876, 3.86, 3.09, 'Medium')
# ('oishi-sushi-kortrijk', 'Oishi Sushi', 11.14, 4.6, 36, 3.6, 3.09, 'Medium')
# ('onder-pide-new', 'Onder Pide', 10.51, 4.3, 38, 3.4, 3.09, 'Medium')
# ('pizza-service-mechelen', 'Pizza Service', 13.88, 4.5, 4147, 4.49, 3.09, 'Medium')
# ('pizza-talia-waregem', 'Pizza Talia Original', 12.63, 4.1, 2463, 4.08, 3.09, 'Medium')
# ('scape', 'S~Cape', 12.1, 4.2, 135, 3.91, 3.09, 'Medium')
# ('veziroglu', 'Veziroglu', 12.34, 5, 455, 4.0, 3.09, 'Medium')
# ('bonsai-sushi-1', 'Bonsai Sushi', 13.53, 4.4, 1066, 4.36, 3.1, 'Medium')
# ('bostonpizza', 'Boston Pizza Liedekerke', 12.63, 4.1, 1769, 4.08, 3.1, 'Medium')
# ('eethuis-botan', 'Eethuis Botan', 11.63, 3.9, 248, 3.75, 3.1, 'Medium')
# ('genco-pizza', 'Genco Pizza', 11.11, 4.7, 32, 3.58, 3.1, 'Medium')
# ('pizza-heart', 'Pizza Heart', 12.07, 4.1, 187, 3.89, 3.1, 'Medium')
# ('pizza-pasta-nr1-city-antwerpen', 'Pizza Pasta Nr1 City', 12.87, 4.2, 909, 4.15, 3.1, 'Medium')
# ('tenshi-sushi-docks', 'Tenshi Sushi', 11.77, 3.9, 370, 3.8, 3.1, 'Medium')
# ('the-pizza-masters-gent', 'The Pizza Masters', 12.61, 4.1, 1051, 4.06, 3.1, 'Medium')
# ('chulo', 'Chulo', 10.33, 4.3, 34, 3.32, 3.11, 'Medium')
# ('kibo-sushi', 'Kibo Sushi', 11.48, 4.3, 61, 3.69, 3.11, 'Medium')
# ('mabista-sushi', 'Mabista Sushi', 14.15, 4.6, 870, 4.55, 3.11, 'Medium')
# ('munis-mechelen', 'Munis Restaurant', 11.97, 3.9, 733, 3.85, 3.11, 'Medium')
# ('njoy-1', "N'Joy", 12.43, 5, 116, 4.0, 3.11, 'Medium')
# ('noedels-en-co', 'Noedels & Co. Chinese wok en sushi bar', 11.76, 3.8, 1139, 3.77, 3.12, 'Medium')
# ('olis-house', "Oli's House", 12.17, 4.6, 56, 3.9, 3.12, 'Medium')
# ('ottoman-pizza-bbq-gent-9000', 'Ottoman Pizza & BBQ', 12.79, 4.4, 136, 4.1, 3.12, 'Medium')
# ('pizza-lounge-hamme-1', 'Pizza Lounge', 12.7, 4.1, 1289, 4.07, 3.12, 'Medium')
# ('sushi-plaza', 'Sushi Plaza', 11.2, 3.8, 169, 3.59, 3.12, 'Medium')
# ('sushi-today-deurne', 'Sushi Today', 11.61, 3.9, 216, 3.73, 3.12, 'Medium')
# ('thai-gourmet-1', 'Thai Gourmet', 11.09, 3.6, 863, 3.56, 3.12, 'Medium')
# ('antalya-kebab-2280', 'Antalya Kebab', 10.36, 4.5, 28, 3.32, 3.13, 'Medium')
# ('gonia-greek-bistro', 'Gonia Greek Bistro', 12.92, 4.3, 249, 4.13, 3.13, 'Medium')
# ('gouden-paard', 'Gouden Paard', 13.51, 4.4, 494, 4.31, 3.13, 'Medium')
# ('istanbul-balen', 'Istanbul', 11.61, 4.8, 34, 3.71, 3.13, 'Medium')
# ('kintsugi-sushi-bar-grill', 'Kintsugi Sushi Bar & Grill', 12.57, 4.3, 145, 4.02, 3.13, 'Medium')
# ('milo-ii-kebap-pizza-pasta', 'Milo II Kebap Pizza Pasta', 10.51, 3.5, 236, 3.36, 3.13, 'Medium')
# ('sushi-sake', 'Sushi Sake', 11.09, 3.6, 668, 3.55, 3.13, 'Medium')
# ('xinxin', 'Xinxin', 13.13, 4.3, 398, 4.19, 3.13, 'Medium')
# ('xiongmao-panda', 'Xiongmao Panda', 12.34, 4.5, 71, 3.94, 3.13, 'Medium')
# ('cuisine-speciale', 'Cuisine Spéciale', 14.07, 4.7, 210, 4.49, 3.14, 'Medium')
# ('de-fontein', 'De Fontein', 13.4, 4.4, 321, 4.27, 3.14, 'Medium')
# ('floryakebab', 'Florya Kebab & Pizzeria', 10.23, 3.3, 829, 3.26, 3.14, 'Medium')
# ('la-cite-du-mandarin', 'La Cité Du Mandarin', 12.39, 4.3, 112, 3.95, 3.14, 'Medium')
# ('pizza-fast', 'Pizza Fast', 13.02, 4.8, 63, 4.14, 3.14, 'Medium')
# ('pizza-king-bruxelles', 'Pizza King', 11.81, 3.8, 1186, 3.77, 3.14, 'Medium')
# ('pizza-vali', 'Pizza Vali', 13.41, 4.3, 1373, 4.27, 3.14, 'Medium')
# ('rinascente-eethuis', 'Rinascente Eethuis', 10.96, 4.3, 43, 3.49, 3.14, 'Medium')
# ('bonito', 'Bonito Sushi & Thai', 13.94, 4.5, 604, 4.43, 3.15, 'Medium')
# ('la-grillade', 'La Grillade Chez Nikos', 12.89, 4.1, 3241, 4.09, 3.15, 'Medium')
# ('pizza-planet-oostende', 'Pizza Planet', 13.57, 4.4, 460, 4.31, 3.15, 'Medium')
# ('ramses-laeken-1', 'Ramses', 10.89, 3.9, 79, 3.46, 3.15, 'Medium')
# ('wakame-sushi-bar', 'WaKame Sushi Bar', 12.2, 4.1, 167, 3.87, 3.15, 'Medium')
# ('bij-hasan', 'Eethuis Bij Hakan', 10.1, 4.3, 29, 3.2, 3.16, 'Medium')
# ('chitir-chicken-woluwe-saint-lambert', 'Chitir Chicken', 10.17, 3.7, 67, 3.22, 3.16, 'Medium')
# ('le-jasmin-vise', 'Le Jasmin', 12.73, 4.1, 514, 4.02, 3.16, 'Medium')
# ('pizzeria-da-mario-jodoigne', 'Pizzeria da Mario', 11.84, 4.1, 105, 3.74, 3.16, 'Medium')
# ('side-kebap', 'Side Kebap', 11.5, 3.7, 546, 3.63, 3.16, 'Medium')
# ('antalya-pita', 'Antalya Pita', 12.31, 3.9, 2694, 3.89, 3.17, 'Medium')
# ('casa-pizza', 'Casa Pizza', 13.27, 4.3, 384, 4.19, 3.17, 'Medium')
# ('pitaverne-wilrijk', 'Pitaverne Wilrijk', 11.6, 3.7, 1040, 3.66, 3.17, 'Medium')
# ('pizza-pita-house', 'Pizza Pita House', 11.03, 3.5, 1888, 3.48, 3.17, 'Medium')
# ('pizza-taxi-berchem', 'Pizza Taxi', 14.46, 4.6, 1429, 4.57, 3.17, 'Medium')
# ('takumi-ramen-centraal-station', 'Takumi Ramen Kitchen', 13.79, 4.5, 280, 4.34, 3.17, 'Medium')
# ('the-cousins', "The Cousin's", 11.83, 3.9, 230, 3.74, 3.17, 'Medium')
# ('chinees-restaurant-chi', 'Chinees restaurant Chi', 13.97, 4.7, 143, 4.39, 3.18, 'Medium')
# ('el-bocado-1', 'El Bocado', 13.76, 4.5, 253, 4.33, 3.18, 'Medium')
# ('il-forno-de-haan', 'Il Forno', 12.32, 3.9, 1300, 3.87, 3.18, 'Medium')
# ('leonardo-da-vinci-1', 'Leonardo Da Vinci', 10.88, 3.9, 71, 3.42, 3.18, 'Medium')
# ('miams-burger-saint-gilles', "Miam's Burger", 10.59, 3.4, 505, 3.33, 3.18, 'Medium')
# ('pearl-of-hongkong', 'Pearl of Hongkong', 13.47, 4.6, 119, 4.24, 3.18, 'Medium')
# ('pizza-pasta-nr1-kontich-antwerpen', 'Pizza Pasta Nr1', 11.67, 3.8, 276, 3.67, 3.18, 'Medium')
# ('pizza-royal-waregem', 'Pizza Royal', 11.75, 3.8, 342, 3.69, 3.18, 'Medium')
# ('the-pizza-corner-antwerpen', 'The Pizza Corner', 12.63, 4.1, 305, 3.97, 3.18, 'Medium')
# ('zakuro-2830', 'Sushi Town', 14.53, 4.6, 1871, 4.58, 3.18, 'Medium')
# ('andiamo-pizza-jette', 'Andiamo Pizza', 12.36, 4.2, 117, 3.87, 3.19, 'Medium')
# ('asian-king', 'Asian King', 11.49, 3.8, 181, 3.6, 3.19, 'Medium')
# ('kebabstore-1', 'Kebabstore', 10.22, 4.6, 23, 3.21, 3.19, 'Medium')
# ('matiate-docks', 'Matiate Docks', 10.43, 3.8, 62, 3.27, 3.19, 'Medium')
# ('namaste-sint-niklaas', 'Namaste', 12.57, 4.1, 255, 3.95, 3.19, 'Medium')
# ('nobu-sushi', 'Nobu Sushi', 13.72, 4.5, 216, 4.3, 3.19, 'Medium')
# ('pizza-phone-brasschaat', 'Pizza Phone', 11.66, 3.7, 766, 3.65, 3.19, 'Medium')
# ('pizzeria-pazza-inter', 'Pizzeria Pazza Inter', 12.34, 4.7, 47, 3.88, 3.19, 'Medium')
# ('aly-baba', 'Aly Baba', 10.09, 3.2, 623, 3.15, 3.2, 'Medium')
# ('brasserie-de-stenen-molen-putte', 'Brasserie De Stenen Molen', 12.93, 4.1, 727, 4.04, 3.2, 'Medium')
# ('gari-sushi', 'Gari Sushi Brasschaat', 13.29, 4.2, 902, 4.15, 3.2, 'Medium')
# ('la-piazzetta-leuven-1', 'La Piazzetta', 13.15, 4.3, 213, 4.11, 3.2, 'Medium')
# ('les-enfants-du-piree-1', 'Les enfants du pirée', 14.18, 4.5, 674, 4.43, 3.2, 'Medium')
# ('pizza-talia-oudenaarde', 'Pizza Talia Original', 10.74, 3.4, 757, 3.36, 3.2, 'Medium')
# ('pizzeria-al-doppio-a', 'Pizzeria Al Doppio A', 12.6, 4.5, 69, 3.93, 3.2, 'Medium')
# ('restaurant-libanais', 'Les Saveurs du Liban', 11.59, 3.7, 495, 3.63, 3.2, 'Medium')
# ('sushi-at-home', 'Sushi At Home', 13.58, 4.5, 161, 4.24, 3.2, 'Medium')
# ('thai-bangkok', 'Thai Bangkok', 11.68, 3.7, 782, 3.65, 3.2, 'Medium')
# ('apero-bouffe-lobsang', 'Apero bouffe Lobsang', 11.85, 4.4, 52, 3.69, 3.21, 'Medium')
# ('loulou-schaerbeek', 'Loulou', 10.47, 3.3, 1016, 3.27, 3.21, 'Medium')
# ('restaurant-marmaris', 'Restaurant Marmaris', 13.04, 4.1, 1089, 4.06, 3.21, 'Medium')
# ('sushi-dushi-more', 'Sushi Dushi & More', 13.21, 4.5, 107, 4.12, 3.21, 'Medium')
# ('antica-italia', 'Maritimo Da Gino', 11.7, 3.9, 139, 3.64, 3.22, 'Medium')
# ('kazuki-sushi', 'Kazuki Sushi', 14.54, 4.7, 237, 4.51, 3.22, 'Medium')
# ('moshi-sushi', 'Moshi Sushi', 14.96, 4.7, 907, 4.65, 3.22, 'Medium')
# ('pizza-pasta-nr1-mechelen', 'Pizza Pasta Nr1', 12.64, 4.1, 218, 3.92, 3.22, 'Medium')
# ('pizzaco', 'Pizza&Co', 12.31, 4.1, 136, 3.82, 3.22, 'Medium')
# ('3piramiden', 'De 3 Piramiden', 10.95, 3.6, 163, 3.39, 3.23, 'Medium')
# ('boston-pizza-schepdaal', 'Boston Pizza', 14.07, 4.4, 1002, 4.36, 3.23, 'Medium')
# ('china-putte', 'New China', 11.63, 4.6, 36, 3.6, 3.23, 'Medium')
# ('mati-sushi-aarschot', 'Mati Sushi', 13.75, 4.4, 286, 4.25, 3.23, 'Medium')
# ('nikko-sushi', 'Nikko Sushi', 14.2, 4.5, 402, 4.39, 3.23, 'Medium')
# ('otomat-leuven', 'Otomat', 13.12, 4.3, 170, 4.06, 3.23, 'Medium')
# ('the-black-horse', 'The Black Horse', 14.69, 4.9, 127, 4.54, 3.23, 'Medium')
# ('the-borly', 'Forty Seven', 11.99, 3.8, 448, 3.72, 3.23, 'Medium')
# ('bite', 'Bite', 10.22, 4.9, 18, 3.15, 3.24, 'Medium')
# ('kapadokya-doner', 'Kapadokya döner', 12.84, 4.1, 304, 3.97, 3.24, 'Medium')
# ('oinaris-1', 'Oinaris', 13.63, 4.3, 463, 4.21, 3.24, 'Medium')
# ('pizza-angelo-tienen-1', 'Pizza Angelo', 10.96, 3.7, 108, 3.39, 3.24, 'Medium')
# ('pizza-taliano', 'Pizza Taliano', 14.81, 4.6, 1986, 4.58, 3.24, 'Medium')
# ('eethuis-orient-heusden-1', 'Eethuis Orient', 13.59, 4.2, 1819, 4.18, 3.25, 'Medium')
# ('esaki-sushi-hasselt', 'Esaki Sushi', 13.84, 4.3, 1059, 4.26, 3.25, 'Medium')
# ('house-of-flavors', 'House of Flavors', 11.73, 4.9, 28, 3.61, 3.25, 'Medium')
# ('kumpir-eethuis-1', 'Kumpir Eethuis', 11.89, 4.2, 68, 3.66, 3.25, 'Medium')
# ('la-parenthese-ganshoren', 'La Parenthèse', 11.5, 3.7, 222, 3.54, 3.25, 'Medium')
# ('pita-alexandria', 'Pita Alexandria', 12.47, 4.3, 82, 3.83, 3.25, 'Medium')
# ('pizza-service-brugge', 'Pizza Service', 12.63, 4.1, 186, 3.89, 3.25, 'Medium')
# ('pizzeria-la-familia', 'Pizzeria La Familia', 10.78, 4.5, 28, 3.32, 3.25, 'Medium')
# ('sushi-palace-gent', 'Sushi Palace', 13.43, 4.5, 112, 4.13, 3.25, 'Medium')
# ('sushi-today-1', 'Sushi Today', 11.65, 3.6, 2136, 3.58, 3.25, 'Medium')
# ('alo-pizza-turnhout', 'Alo Pizza', 11.7, 3.6, 2223, 3.58, 3.26, 'Medium')
# ('pizza-palace-kruibeke', 'Pizza Palace', 12.51, 3.9, 580, 3.83, 3.26, 'Medium')
# ('pizza-pasta-time', 'Pizza Pasta Time', 12.61, 4.4, 72, 3.86, 3.26, 'Medium')
# ('pizza-tower-1', 'Pizza Tower', 13.29, 4.1, 1793, 4.08, 3.26, 'Medium')
# ('selis-noodles-bar', "Seli's Noodles Bar", 11.11, 4.3, 38, 3.4, 3.26, 'Medium')
# ('zengo', 'Zengo', 12.89, 4.2, 163, 3.96, 3.26, 'Medium')
# ('balls-glory-gent', 'Balls & Glory', 12.1, 3.9, 182, 3.7, 3.27, 'Medium')
# ('cleopatra-poperinge', 'Cleopatra', 10.79, 3.6, 111, 3.3, 3.27, 'Medium')
# ('de-appel', 'De Appel', 14.56, 4.6, 294, 4.45, 3.27, 'Medium')
# ('flavours-of-india', 'Flavours of India', 11.53, 4.6, 33, 3.53, 3.27, 'Medium')
# ...
# ('pizarro-pizza-slice-shop', 'Pizarro Pizza Slice Shop', 11.0, 4.1, 8, 1.82, 6.04, 'Medium')
# ('otomat-merode', 'Otomat', 13.44, 3.6, 16, 2.22, 6.07, 'Medium')
# ('au-bon-coeur', 'Au Bon Coeur 2', 12.95, 3.9, 12, 2.13, 6.09, 'Medium')
# ('pantheon', 'Pantheon', 21.09, 3.9, 79, 3.46, 6.09, 'High')
# ('pizza-company-9120', 'Pizza Company', 10.23, 1.7, 881, 1.68, 6.09, 'Medium')
# ('brasserie-gribaumont', 'Brasserie Gribaumont', 14.1, 4.6, 10, 2.3, 6.13, 'Medium')
# ('la-riviera-bruxelles', 'La Riviera', 14.27, 3.7, 17, 2.33, 6.13, 'Medium')
# ('in-dish', 'In-Dish', 13.68, 4.7, 9, 2.23, 6.14, 'Medium')
# ('les-deux-petits-diables', 'Les Deux Petits Diables', 14.1, 4.2, 12, 2.29, 6.15, 'Medium')
# ('moon-house-1', 'Moon House', 18.45, 4, 128, 3.0, 6.15, 'Medium')
# ('de-milano', 'Pizza Service', 15.52, 2.6, 324, 2.52, 6.16, 'Medium')
# ('restaurant-athene', 'Restaurant Athene', 12.71, 4.3, 9, 2.04, 6.24, 'Medium')
# ('le-pain-quotidien-1', 'Le Pain Quotidien', 10.66, 3.4, 10, 1.7, 6.27, 'Medium')
# ('na-kampenhout', 'Peppino Pazzo Kampenhout', 21.37, 3.5, 366, 3.41, 6.27, 'High')
# ('restaurant-medina', 'Restaurant Medina', 19.73, 4.5, 23, 3.14, 6.29, 'Medium')
# ('nepal-delight-leuven', 'Nepal Delight', 12.59, 4, 15, 2.0, 6.3, 'Medium')
# ('pizzeria-san-remo-antwerpen', 'Pizzeria San Remo', 16.73, 3.8, 23, 2.65, 6.32, 'Medium')
# ('ohfresh', "Oh' Fresh", 11.8, 4.5, 7, 1.85, 6.37, 'Medium')
# ('cherry-flower-woluwe-saint-lambert', 'Cherry Flower', 12.09, 4.6, 7, 1.89, 6.38, 'Medium')
# ('kaai-pizzeria', 'Kaai Pizzeria', 13.5, 2.9, 27, 2.12, 6.38, 'Medium')
# ('swatow-deurne', 'Swatow', 19.51, 4.5, 21, 3.05, 6.4, 'Medium')
# ('l-italiano', "l'Italiano", 20.83, 3.5, 129, 3.25, 6.41, 'High')
# ('sushi-saki', 'Sushi & Saki', 13.64, 3.9, 12, 2.13, 6.41, 'Medium')
# ('de-zorba', 'De Zorba', 16.93, 3.2, 47, 2.64, 6.42, 'Medium')
# ('quetzal-de-chocoladebar', 'Quetzal De Chocoladebar', 18.58, 4.8, 15, 2.88, 6.45, 'Medium')
# ('chef-sam-sint-kruis', 'Chef Sam', 12.93, 4, 13, 2.0, 6.46, 'Medium')
# ('rosario-lier', 'Rosario', 19.38, 4, 420, 3.0, 6.46, 'Medium')
# ('restaurant-bella-italia-brugge', 'Restaurant Bella Italia', 13.18, 4.3, 9, 2.04, 6.47, 'Medium')
# ('turkische-food', 'Turkische Food', 10.2, 2.2, 25, 1.57, 6.49, 'Medium')
# ('balls-glory-mechelen', 'Balls & Glory', 11.24, 4.6, 6, 1.72, 6.51, 'Medium')
# ('lifeis-sushi', "Lifei's Sushi", 10.45, 4.8, 5, 1.6, 6.53, 'Medium')
# ('bagetino-deluxe', 'Bagatino Deluxe', 13.0, 4.2, 9, 1.99, 6.54, 'Medium')
# ('tokyo-sushi', 'Tokyo Sushi', 14.08, 4.3, 10, 2.15, 6.55, 'Medium')
# ('pizza-hut-delivery-mechelen-1', 'Pizza Hut Delivery', 17.34, 2.7, 422, 2.64, 6.58, 'Medium')
# ('gok-2', 'Gok 2 - Turkse keuken', 18.14, 2.9, 177, 2.74, 6.61, 'Medium')
# ('nani', 'Nani', 15.19, 4.2, 12, 2.29, 6.63, 'Medium')
# ('poisson-du-monde', 'Poisson du Monde', 13.5, 3.1, 19, 2.03, 6.65, 'Medium')
# ('akwa-nord', 'Akwa Nord', 17.39, 3.7, 24, 2.61, 6.66, 'Medium')
# ('kuala-lumpur', 'Kuala Lumpur', 12.93, 4.1, 9, 1.94, 6.66, 'Medium')
# ('fratelli-ditalia-gent', "Da Pino - Fratelli D'Italia", 17.21, 4.3, 15, 2.58, 6.67, 'Medium')
# ('chez-giovanni', 'Chez Giovanni', 13.4, 4, 27, 2.0, 6.7, 'Medium')
# ('sapori-del-sud-kessel-lo', 'Sapori Del Sud', 16.42, 4.2, 14, 2.45, 6.7, 'Medium')
# ('da-maurizio-new', 'Da Maurizio', 10.76, 3.6, 8, 1.6, 6.73, 'Medium')
# ('le-zinneke', 'Le Zinneke', 24.75, 4.6, 39, 3.66, 6.76, 'High')
# ('fujiyama-sushibar-sint-truiden', 'Fujiyama Sushibar', 15.09, 4.7, 9, 2.23, 6.78, 'Medium')
# ('yu-thai-1', 'Yu Thai', 13.9, 4.1, 10, 2.05, 6.78, 'Medium')
# ('inzia', 'Inzia', 15.26, 2.5, 86, 2.24, 6.81, 'Medium')
# ('thaithanee', 'Thai Thanee', 19.07, 3.8, 28, 2.8, 6.81, 'Medium')
# ('little-beirut', 'Little Beirut', 14.75, 3.6, 15, 2.16, 6.83, 'Medium')
# ('de-arme-duivel', 'De Mezzanine by De Arme Duivel', 10.76, 4.7, 5, 1.57, 6.87, 'Medium')
# ('the-vexican', 'The Vexican', 10.78, 4.7, 5, 1.57, 6.88, 'Medium')
# ('pizza-hut-delivery-antwerpen-3', 'Pizza Hut Delivery', 17.34, 2.9, 66, 2.52, 6.89, 'Medium')
# ('osteria-michele', 'Osteria Michele', 22.18, 3.3, 367, 3.21, 6.9, 'High')
# ('de-5e-smaak', 'De 5e smaak', 13.84, 5, 14, 2.0, 6.92, 'Medium')
# ('allo-beyrouth', 'Allo Beyrouth', 10.65, 4.1, 6, 1.54, 6.93, 'Medium')
# ('al-solito-posto', 'Al Solito Posto', 14.51, 4.4, 9, 2.08, 6.96, 'Medium')
# ('entreprise', "D'entreprise", 10.97, 4.2, 6, 1.58, 6.97, 'Medium')
# ('lebanon-uccle', 'Lebanon', 12.59, 3.3, 12, 1.8, 7.0, 'Medium')
# ('china-keuken', 'China Keuken', 12.36, 4.7, 6, 1.76, 7.01, 'Medium')
# ('san-marco-gent', 'San Marco Gent', 17.82, 3.8, 20, 2.53, 7.03, 'Medium')
# ('villa-borghese-oostende-1', 'Villa Borghèse', 10.88, 4.6, 5, 1.53, 7.1, 'Medium')
# ('winterput', 'Winterput', 14.94, 3.6, 14, 2.1, 7.12, 'Medium')
# ('spicy-grill', 'Spicy Grill', 15.74, 3.9, 13, 2.2, 7.14, 'Medium')
# ('le-paradis-du-liban', 'Le Paradis du Liban', 22.72, 4.2, 31, 3.18, 7.15, 'High')
# ('balls-glory-leuven-1', 'Balls & Glory Leuven', 11.83, 4.4, 6, 1.65, 7.17, 'Medium')
# ('rosario-2800', 'Rosario', 16.2, 2.8, 40, 2.24, 7.23, 'Medium')
# ('petit-kaiyou', 'Petit Kaiyou', 14.51, 4, 28, 2.0, 7.26, 'Medium')
# ('brasserie-byblos-1898', 'Brasserie Byblos 1898', 12.29, 4.1, 7, 1.69, 7.28, 'Medium')
# ('midtown-oostkamp', 'Midtown Oostkamp', 15.72, 3.7, 14, 2.16, 7.28, 'Medium')
# ('pizza-hut-delivery-waregem-1', 'Pizza Hut Delivery', 17.34, 3.2, 29, 2.38, 7.29, 'Medium')
# ('lotus-maastricht', 'Lotus Maastricht', 14.68, 3, 355, 2.0, 7.34, 'Medium')
# ('lujain-restaurant', 'Lujain Restaurant', 14.7, 4, 18, 2.0, 7.35, 'Medium')
# ('everest-gurkha', 'Everest Gurkha', 15.82, 4.1, 11, 2.15, 7.37, 'Medium')
# ('mamma-mia-3', 'Mamma Italia', 13.96, 4.6, 7, 1.89, 7.37, 'Medium')
# ('faitsdivers', 'Faits Divers', 14.07, 3.8, 10, 1.9, 7.4, 'Medium')
# ('brunch-corner-bruxelles', 'Brunch Corner', 12.59, 3.4, 10, 1.7, 7.41, 'Medium')
# ('shapla-masala', 'Shapla Masala', 14.82, 4, 22, 2.0, 7.41, 'Medium')
# ('made-in-sud', 'Made in Sud', 15.05, 3.7, 12, 2.02, 7.46, 'Medium')
# ('shiso', 'Shiso', 13.21, 4.3, 7, 1.77, 7.46, 'Medium')
# ('verdi-brugge', 'Verdi', 21.67, 4.8, 15, 2.88, 7.52, 'High')
# ('ornina-syrian-sweets', 'Ornina Syrian Sweets', 13.94, 4.5, 7, 1.85, 7.53, 'Medium')
# ('the-avocado-bar-mechelen', 'The Avocado Bar', 13.03, 4.6, 6, 1.72, 7.56, 'Medium')
# ('laurora', "Villa l'Aurora", 17.94, 3.9, 15, 2.34, 7.66, 'Medium')
# ('le-porto-fino', 'Le Porto fino', 12.71, 3.5, 9, 1.66, 7.66, 'Medium')
# ('yamas', 'Yamas', 15.92, 3.8, 12, 2.07, 7.68, 'Medium')
# ('t-pallieterke', "'t Pallieterke", 15.44, 4, 10, 2.0, 7.72, 'Medium')
# ('falafel-habibi', 'Falafel Habibi', 13.38, 4.6, 6, 1.72, 7.76, 'Medium')
# ('le-mainz', 'Le Mainz', 11.05, 3.8, 6, 1.42, 7.76, 'Medium')
# ('art-sushi-gent', 'Art Sushi', 11.97, 4.1, 6, 1.54, 7.79, 'Medium')
# ('chez-kloe', 'Chez Kloé', 15.59, 4, 17, 2.0, 7.8, 'Medium')
# ('gabbiani-reali', 'Gabbiani Reali', 17.36, 3.8, 14, 2.22, 7.83, 'Medium')
# ('tapasbox-by-adai', 'Tapasbox by Adai', 10.07, 4.5, 4, 1.29, 7.83, 'Medium')
# ('la-boqueria', 'La Boqueria', 12.7, 3.2, 10, 1.6, 7.94, 'Medium')
# ('5th-gok', '5th Gok', 24.0, 3.9, 34, 3.01, 7.96, 'High')
# ('la-pizza-bio-la-pizza-bio', 'La Pizza Bio', 13.15, 3.7, 8, 1.64, 8.0, 'Medium')
# ('district-13', 'District 13', 15.64, 3.9, 10, 1.95, 8.02, 'Medium')
# ('grezio-grez-doiceau', "Grez'io", 15.64, 4.1, 9, 1.94, 8.05, 'Medium')
# ('tokcel-gent', 'Tokcel', 11.02, 4.1, 5, 1.37, 8.06, 'Medium')
# ('le-gourmet-bruxelles', 'Le Gourmet', 12.29, 3.2, 9, 1.52, 8.11, 'Medium')
# ('saveurs-du-monde-saint-gilles', 'Saveurs du monde', 17.82, 4.1, 11, 2.15, 8.3, 'Medium')
# ('parillada-argentina-antwerpen', 'Parillada Argentina', 24.72, 3.9, 32, 2.97, 8.32, 'High')
# ('haoxuan-brugge', 'Haoxuan Chinees Restaurant', 19.48, 3.9, 15, 2.34, 8.33, 'Medium')
# ('kumpir-deurne-antwerpen', 'Kumpir Deurne', 12.6, 4.5, 5, 1.5, 8.4, 'Medium')
# ('pizza-hut-delivery-brugge-sint-andries', 'Pizza Hut Delivery', 17.34, 2.1, 566, 2.06, 8.41, 'Medium')
# ('le-chapeau-blanc-associes', 'Le Chapeau Blanc Anderlecht', 20.21, 4.4, 12, 2.4, 8.42, 'High')
# ('c-kitchen-gent', 'C-Kitchen', 12.6, 3.6, 7, 1.48, 8.5, 'Medium')
# ('patrick-foleys', "Patrick Foley's", 14.64, 3.8, 8, 1.69, 8.67, 'Medium')
# ('pizza-hut-delivery-brugge-sint-kruis', 'Pizza Hut Delivery Brugge Sint-Kruis', 17.34, 3, 544, 2.0, 8.67, 'Medium')
# ('pizza-hut-delivery-lokeren', 'Pizza Hut Delivery', 17.34, 3, 217, 2.0, 8.67, 'Medium')
# ('sushi-planet-izegem', 'Sushi Planet', 13.99, 4.3, 6, 1.61, 8.67, 'Medium')
# ('rnin-asian-fusion', 'Rōnin Asian Fusion', 11.87, 4.1, 5, 1.37, 8.68, 'Medium')
# ('captain-johns-fish-and-chips-new', "Captain John's Fish and Chips", 11.35, 3.9, 5, 1.3, 8.73, 'Medium')
# ('le-monte-carlo', 'Le Monte Carlo', 12.76, 3.9, 6, 1.46, 8.73, 'Medium')
# ('litaliano-nieppe', "L'Italiano", 10.83, 3.3, 6, 1.24, 8.75, 'Medium')
# ('traiteur-gloss', 'Traiteur Gloss', 16.24, 4.9, 6, 1.84, 8.84, 'Medium')
# ('les-4-saisons-bxl', 'Les 4 Saisons', 10.92, 4.3, 4, 1.23, 8.89, 'Medium')
# ('the-better-pizza-company', 'The Better Pizza Company', 14.5, 4.3, 6, 1.61, 8.99, 'Medium')
# ('croque-n-roll-mechelen', "Croque 'n Roll", 12.61, 4.1, 5, 1.37, 9.23, 'Medium')
# ('amy-mary-specialty-ice-creams', 'Amy & Mary Specialty Ice Creams', 14.92, 4.3, 6, 1.61, 9.25, 'Medium')
# ('ciao-pizza-waterloo-1', 'Ciao Pizza', 23.95, 4.4, 14, 2.57, 9.33, 'High')
# ('le-syrtaki-wavre', 'Le Syrtaki', 16.58, 4.3, 7, 1.77, 9.36, 'Medium')
# ('le-pecheur', 'Le Pêcheur', 25.09, 4.1, 18, 2.64, 9.52, 'High')
# ('thuy-hanoi', 'Thuy Hanoi', 17.13, 4.8, 6, 1.8, 9.52, 'Medium')
# ('jeronimos-pizza', "Jeronimo's Pizza", 12.93, 4.7, 4, 1.34, 9.63, 'Medium')
# ('pizza-pasta-toscana', 'Pizzeria Toscana', 13.1, 3.3, 7, 1.36, 9.64, 'Medium')
# ('oasian-gent', 'Oasian', 14.34, 3.6, 7, 1.48, 9.67, 'Medium')
# ('mikazuki', 'Mikazuki', 15.2, 4.7, 5, 1.57, 9.7, 'Medium')
# ('zorba-de-griek-gent-1', 'Zorba de Griek', 20.46, 4.2, 10, 2.1, 9.74, 'High')
# ('sushi-culture', 'Sushi Culture', 16.1, 4.4, 6, 1.65, 9.75, 'Medium')
# ('indian-tandoori-bruges', 'Indian Tandoori', 14.65, 4.5, 5, 1.5, 9.76, 'Medium')
# ('oh-my-kimchi', 'Oh, my kimchi!', 11.35, 3.1, 6, 1.16, 9.76, 'Medium')
# ('la-familia-saint-nicolas-1', 'La Familia', 17.03, 4.2, 7, 1.73, 9.84, 'Medium')
# ('golden-buddha-home', 'Golden Buddha @ Home', 13.7, 4.8, 4, 1.37, 9.99, 'Medium')
# ('le-brussels-1', 'Le Brussels', 14.01, 4.2, 5, 1.4, 10.01, 'Medium')
# ('palestijns-restaurant', 'Palestijns Restaurant', 10.03, 4, 8, 1.0, 10.03, 'Medium')
# ('duo-bruxelles', 'Duo', 13.8, 4.8, 4, 1.37, 10.06, 'Medium')
# ('hong-kong-restaurant-willebroek', 'Hong Kong Restaurant', 13.33, 4.6, 4, 1.31, 10.14, 'Medium')
# ('beyzade-antwerpen-1', 'Beyzade', 10.15, 4, 9, 1.0, 10.15, 'Medium')
# ('hoffys', "Hoffy's Take Away", 18.75, 4.8, 6, 1.8, 10.42, 'Medium')
# ('pizza-fresca-woluwe-1', 'Pizza Fresca Woluwe', 16.29, 3.5, 8, 1.56, 10.47, 'Medium')
# ('brasserie-keizershof', 'Brasserie Keizershof', 18.96, 4.8, 6, 1.8, 10.53, 'Medium')
# ('la-table-du-winners', "La Table du Winner's", 10.01, 4.1, 3, 0.95, 10.58, 'Medium')
# ('tayba-sweet', 'Tayba Sweet Mons', 11.5, 3.8, 4, 1.09, 10.59, 'Medium')
# ('tasty-thai', 'Tasty Thai', 13.9, 3.9, 5, 1.3, 10.69, 'Medium')
# ('rio-cafe', 'Rio Café', 17.22, 4.8, 5, 1.6, 10.76, 'Medium')
# ('tandoori-home', 'Tandoori Home', 10.47, 4.2, 3, 0.97, 10.8, 'Medium')
# ('japans-restaurant-amatsu', 'Japans Restaurant Amatsu', 38.47, 4.4, 42, 3.55, 10.82, 'Premium')
# ('punjab-tandoori-cuisine', 'Punjab Tandoori Cuisine', 22.1, 3.9, 11, 2.04, 10.82, 'High')
# ('gardenia', 'Gardenia', 13.54, 4.3, 4, 1.23, 11.02, 'Medium')
# ('liberta', 'Libertà', 18.0, 4.8, 5, 1.6, 11.25, 'Medium')
# ('ristorante-pizzeria-benvenuto', 'Ristorante Pizzeria Benvenuto', 14.15, 2.4, 11, 1.26, 11.25, 'Medium')
# ('maison-grill-anderlecht', 'Maison Grill Anderlecht', 15.63, 3.7, 6, 1.39, 11.26, 'Medium')
# ('la-rotonde-by-dl', 'La Rotonde by DL', 15.46, 4.8, 4, 1.37, 11.27, 'Medium')
# ('so-sushi-kraainem', 'So Sushi Kraainem', 11.44, 4, 8, 1.0, 11.44, 'Medium')
# ('antipasti-sapori', 'Antichi Sapori', 12.47, 3.8, 4, 1.09, 11.49, 'Medium')
# ('chicken-tok-tok-brugge', 'Chicken Tok Tok', 12.48, 3.8, 4, 1.09, 11.49, 'Medium')
# ('gel-tov', 'Gel Tov', 11.54, 4, 7, 1.0, 11.54, 'Medium')
# ('den-toren', 'Drank Express', 23.39, 3, 53, 2.0, 11.69, 'High')
# ('oakberry', 'Oakberry', 11.73, 5, 4, 1.0, 11.73, 'Medium')
# ('yokoso-mechelen', 'Yokoso', 19.16, 4.9, 5, 1.63, 11.73, 'Medium')
# ('anoot', 'Anoot', 12.6, 4.6, 3, 1.06, 11.87, 'Medium')
# ('bellanata', 'Restaurant Pizzeria Bellanata', 15.44, 3.9, 5, 1.3, 11.88, 'Medium')
# ('beyranet', 'Beyranet', 16.37, 4.8, 4, 1.37, 11.93, 'Medium')
# ('bella-italia-la-hulpe', 'Bella Italia', 12.0, 5, 5, 1.0, 12.0, 'Medium')
# ('sina-pasta-forest', 'Sina Pasta', 14.05, 3.5, 5, 1.17, 12.05, 'Medium')
# ('el-bocado-bilzen', 'El Bocado', 13.23, 4.7, 3, 1.08, 12.2, 'Medium')
# ('met-jeanine', 'Met Jeaninne', 19.33, 4.7, 5, 1.57, 12.34, 'Medium')
# ('munchies-ieper', 'Munchies Ieper', 12.4, 5, 6, 1.0, 12.4, 'Medium')
# ('the-golden-olive', 'The Golden Olive', 12.07, 2.9, 5, 0.97, 12.48, 'Medium')
# ('booboo-cakes', 'Boo Boo Cakes', 15.0, 3.2, 6, 1.2, 12.5, 'Medium')
# ('karasu-antwerpen', 'Karasu', 19.44, 3.5, 8, 1.56, 12.5, 'Medium')
# ('monopoli', 'Monopoli', 12.4, 4.3, 3, 0.99, 12.5, 'Medium')
# ('emporio-brazil', 'Emporio Brazil', 12.59, 5, 5, 1.0, 12.59, 'Medium')
# ('mere-liban', 'Mère Liban', 34.55, 4.4, 16, 2.71, 12.76, 'Premium')
# ('le-guignol-uccle', 'Le Guignol', 15.69, 4.3, 4, 1.23, 12.77, 'Medium')
# ('la-cueva-de-castilla-schaerbeek-1', 'La Cueva de Castilla', 25.55, 4, 11, 2.0, 12.78, 'High')
# ('fueangbun-wiphada', 'Wiphada Thai Food & Take Away', 15.86, 4.3, 4, 1.23, 12.91, 'Medium')
# ('la-bagatelle-de-lou', 'La Bagatelle De Lou', 12.23, 3.3, 4, 0.94, 12.97, 'Medium')
# ('vero-napoli-kontich-1', 'Vero Napoli', 13.29, 4, 4, 1.0, 13.29, 'Medium')
# ('siam', 'Siam Heverlee', 13.32, 4.3, 3, 0.99, 13.42, 'Medium')
# ('rubens-grillade-1040', 'Grillade Rubens', 26.9, 4, 12, 2.0, 13.45, 'High')
# ('les-tables-de-breughel', 'Les Tables de Breughel', 13.48, 5, 3, 1.0, 13.48, 'Medium')
# ('volle-gas-1', 'Volle Gas', 19.78, 3.9, 6, 1.46, 13.53, 'Medium')
# ('mister-spaghetti-oostende', 'Mister Spaghetti', 13.57, 5, 3, 1.0, 13.57, 'Medium')
# ('zuiver-op-de-graat', 'Zuiver Op De Graat', 32.64, 4.8, 10, 2.4, 13.6, 'Premium')
# ('tasty-thai-express-antwerp', 'Tasty Thai Express', 12.84, 3.3, 4, 0.94, 13.61, 'Medium')
# ('foods-n-moods-1000', "Foods 'n' Moods", 10.9, 2.4, 5, 0.8, 13.62, 'Medium')
# ('la-pomme-de-pin-uccle-1', 'La Pomme de Pin', 15.36, 4.7, 3, 1.08, 14.16, 'Medium')
# ('chez-eline', 'Chez Eline', 14.6, 5, 4, 1.0, 14.6, 'Medium')
# ('liborio', 'Liborio', 13.79, 3.3, 4, 0.94, 14.63, 'Medium')
# ('mount-masala-ranst', 'Mount Masala', 14.85, 5, 3, 1.0, 14.85, 'Medium')
# ('brugge-burger', 'Brugge Burger', 14.91, 4, 6, 1.0, 14.91, 'Medium')
# ('persepolis', 'Persepolis', 14.85, 4.3, 3, 0.99, 14.97, 'Medium')
# ('le-mezze-chez-firas', 'Le Mezze - Chez Firas', 13.08, 3.7, 3, 0.85, 15.32, 'Medium')
# ('bruschetta-mia-deinze', 'Bruschetta Mia', 16.87, 4.7, 3, 1.08, 15.55, 'Medium')
# ('de-blauwe-schuit', 'De Blauwe Schuit', 22.85, 3.9, 6, 1.46, 15.62, 'High')
# ('la-favola', 'La Favola', 23.17, 3.9, 6, 1.46, 15.84, 'High')
# ('china-star', 'China Star', 16.73, 4, 7, 1.0, 16.73, 'Medium')
# ('little-ethiopia-antwerpen-1', 'Little Ethiopia', 28.81, 3.8, 7, 1.56, 18.41, 'High')
# ('restaurant-gabriel', 'Restaurant Gabriel', 19.8, 5, 4, 1.0, 19.8, 'Medium')
# ('la-torre-antwerpen-1', 'La Torre', 20.02, 3, 19, 1.0, 20.02, 'High')
# ('yokoso-gent', 'Yokoso', 19.99, 4.2, 3, 0.97, 20.63, 'Medium')
# ('orso-pizzeria', 'Orso Pizzeria Pop Up', 17.79, 3.7, 3, 0.85, 20.84, 'Medium')
# ('uzume-sushi-overpoort', 'Uzume Sushi Overpoort', 14.09, 2.8, 3, 0.65, 21.81, 'Medium')
# ('mai-thai', 'Mai Thai', 21.49, 3.1, 4, 0.89, 24.26, 'High')
# ('pizza-hut-delivery-beernem', 'Pizza Hut Delivery', 17.34, 1.9, 6, 0.71, 24.34, 'Medium')
# ('wok-van-antwerpen', 'Wok van Antwerpen', 20.5, 2.5, 5, 0.83, 24.6, 'High')
# ('pizza-pasta-kiel', 'Pizza Pasta Kiel', 13.57, 2.3, 3, 0.53, 25.56, 'Medium')
# ('d-afroflavours', 'D-Afro Flavours', 16.01, 2.3, 3, 0.53, 30.17, 'Medium')
# ('restaurant-henri-1er', 'New Restaurant Henri 1er', 23.85, 3.2, 3, 0.74, 32.3, 'High')

# %%
try: 
    uberEats = """SELECT
                            ue.menu_items.restaurant_id,
                            ue.restaurants.title,
                            CAST(ROUND(AVG(ue.menu_items.price_float), 2) AS FLOAT) AS avg_price,
                            ue.restaurants.rating__rating_value,
                            CAST(REPLACE(ue.restaurants.rating__review_count, '+', '') AS INTEGER) AS numeric_review_count,
                            CAST(ROUND(
                                (ue.restaurants.rating__rating_value * CAST(REPLACE(ue.restaurants.rating__review_count, '+', '') AS INTEGER)) / 
                                (CAST(REPLACE(ue.restaurants.rating__review_count, '+', '') AS INTEGER) + 10), 2
                            ) AS FLOAT) AS weighted_rating,
                            CAST(ROUND(
                                AVG(ue.menu_items.price_float) / 
                                ((ue.restaurants.rating__rating_value * CAST(REPLACE(ue.restaurants.rating__review_count, '+', '') AS INTEGER)) / 
                                (CAST(REPLACE(ue.restaurants.rating__review_count, '+', '') AS INTEGER) + 10)), 2
                            ) AS FLOAT) AS price_to_weighted_rating_ratio,
                            CASE 
                                WHEN AVG(ue.menu_items.price_float)  < 10 THEN 'Low'
                                WHEN AVG(ue.menu_items.price_float)  BETWEEN 10 AND 20 THEN 'Medium'
                                WHEN AVG(ue.menu_items.price_float)  BETWEEN 20 AND 30 THEN 'High'
                                ELSE 'Premium'
                            END AS price_bucket
                    FROM
                        ue.menu_items
                    INNER JOIN
                        ue.restaurants 
                    ON 
                        ue.menu_items.restaurant_id = restaurants.id
                    WHERE
                        CAST(ue.menu_items.price_float AS FLOAT) > 0
                        AND ue.menu_items.price_float IS NOT NULL
                        AND ue.restaurants.rating__rating_value IS NOT NULL
                        AND ue.restaurants.rating__review_count IS NOT NULL
                        AND CAST(REPLACE(ue.restaurants.rating__review_count, '+', '') AS INTEGER) > 0
                    GROUP BY
                        ue.menu_items.restaurant_id, ue.restaurants.title, ue.restaurants.rating__rating_value, ue.restaurants.rating__review_count
                    HAVING
                        price_bucket != 'Low'
                        AND price_to_weighted_rating_ratio IS NOT NULL
                        AND avg_price IS NOT NULL
                    ORDER BY
                        price_to_weighted_rating_ratio ASC;"""
            
    uberEats_results = conn.execute(uberEats).fetchall()
    for row in uberEats_results:
        print(row)
except sqlite3.OperationalError as e:
    print("Error:", e)
# Out:
# ('12f8afc2-a915-428f-8c35-a7dd7cc70e1b', 'Delitraiteur - WoluwÃ©-Saint-Lambert - Rue Voot', 10.68, 4.6, 144, 4.3, 2.48, 'Medium')
# ('206e2163-5790-4fe8-8a2e-bd5d89dd7ba1', 'Chitir Chicken - WoluwÃ© Shopping', 10.16, 4.5, 102, 4.1, 2.48, 'Medium')
# ('62ce5f24-7440-46eb-9b4b-23827c5249ab', 'Schievelavabo - Forest', 10.62, 4.6, 125, 4.26, 2.49, 'Medium')
# ('c5fcdabc-2465-4bf8-9eb6-ab980a1d1b7d', 'Be Burger - Stockel', 10.44, 4.4, 200, 4.19, 2.49, 'Medium')
# ('e832f48b-21ae-46db-b721-e4243080938d', 'Dawag', 10.31, 4.4, 133, 4.09, 2.52, 'Medium')
# ('d0cce746-fa30-5968-9542-4e874a2a85bb', 'Belchicken - Vilvoorde', 10.14, 4.3, 137, 4.01, 2.53, 'Medium')
# ('4e357653-5455-5a2c-8ce3-38faa5a11f7d', 'Fuji House', 10.06, 4.6, 62, 3.96, 2.54, 'Medium')
# ('99ed5332-a16a-443a-8b4f-57720d5e68a8', 'Brasserie du Tennis', 10.16, 4.7, 57, 4.0, 2.54, 'Medium')
# ('e9dec8eb-6598-4154-b861-3e865f322d23', 'Otomat â€“ Leopoldplaats', 10.2, 4.4, 100, 4.0, 2.55, 'Medium')
# ('ad2f5252-8a2c-4ca6-b779-8ac8fbcda4b5', 'Delitraiteur - Fort Jaco', 10.9, 4.8, 75, 4.24, 2.57, 'Medium')
# ('029b837b-62fe-4434-8dc9-81eb023a0de5', 'SUSHIRIA - Jette', 10.84, 4.4, 171, 4.16, 2.61, 'Medium')
# ('52a7ccd1-15ff-43d1-9cf7-d65792320fce', 'Pizza Di Mamma', 10.43, 4.2, 200, 4.0, 2.61, 'Medium')
# ('ac5b5e08-3e7b-44d7-a4ff-8be90fba80be', 'Ikura Sushi', 10.5, 4.4, 100, 4.0, 2.62, 'Medium')
# ('d69c0c9c-9fd5-42e7-848b-c773fe85f490', 'KFC - Leuven ', 10.02, 4.2, 100, 3.82, 2.62, 'Medium')
# ('a19d8b57-cb72-4cfa-bbd9-001283e1ba7d', 'Belchicken - Westland', 10.53, 4.2, 200, 4.0, 2.63, 'Medium')
# ('c0caddd6-6564-5e70-8a1c-4c3c06547fbe', 'Omonni Korean Fried Chicken - Antwerpen', 11.04, 4.6, 100, 4.18, 2.64, 'Medium')
# ('e5808bed-2a9e-50df-a2d1-cd9c87ced0ff', 'La Cucina - Pizzeria Tradizionale - Anderlecht', 11.23, 4.5, 178, 4.26, 2.64, 'Medium')
# ('e897f8d0-ea52-577d-a9a4-c65916acc006', 'Belchicken - Waterloo', 10.8, 4.3, 183, 4.08, 2.65, 'Medium')
# ('6f09496c-5a5d-4424-b06c-35b0b3aaf61d', 'Pizza heart', 10.06, 4.2, 89, 3.78, 2.67, 'Medium')
# ('bc468035-d3e3-4b0d-9921-843d85bf3cf0', 'Le Chef Poon', 11.15, 4.8, 66, 4.17, 2.67, 'Medium')
# ('c48c3439-85e2-4a0b-afc9-3db2254b702c', 'Arrivero Pizza - Schaerbeek', 10.33, 4.2, 116, 3.87, 2.67, 'Medium')
# ('714035d3-f50b-4514-8029-b3a62fc9256b', 'Tard La Night 2', 10.38, 4.3, 91, 3.87, 2.68, 'Medium')
# ('c425f3f1-7057-4cc4-9566-ef22f45de427', 'Oost-Azie', 10.46, 4.5, 66, 3.91, 2.68, 'Medium')
# ('50cd62fa-e8f1-5a59-93b8-1ce51731ac74', 'Kyoto Sushi', 10.71, 4.6, 64, 3.98, 2.69, 'Medium')
# ('21c1468f-1c9a-4753-b0f8-5e1846043204', 'Arrivero Pizza - Uccle', 10.17, 4.3, 71, 3.77, 2.7, 'Medium')
# ('d67b4645-2a2b-4dd9-b705-e848017bdbbe', 'Au village de Shanghai', 11.11, 4.5, 106, 4.11, 2.7, 'Medium')
# ('b58bd5cc-7acd-4a68-9333-7adb31bcdb1a', 'Sushi Tokyo', 10.28, 4.6, 46, 3.78, 2.72, 'Medium')
# ('d46d80f7-9b8b-4f0a-98c2-4508c61274fa', 'Red Chillies', 11.71, 4.6, 145, 4.3, 2.72, 'Medium')
# ('fef4259c-d8c1-5421-ae1c-af788c2d98ed', 'KingRibs - Berchem', 10.43, 4.6, 49, 3.82, 2.73, 'Medium')
# ('8062a04f-0fa9-5ada-ae2c-40dcb0f671d1', 'Neuf-Neuf Dragon', 10.28, 4.2, 85, 3.76, 2.74, 'Medium')
# ('9c5cde8c-4331-4aef-bbf8-8c98a39e62be', 'Ellis - Leuven', 10.22, 4.1, 100, 3.73, 2.74, 'Medium')
# ('75300eb0-3108-4a86-9969-b63d37f5c5d2', 'Sushi Shop - Waterloo', 11.47, 4.6, 98, 4.17, 2.75, 'Medium')
# ('47de7bd3-8ee0-455b-8470-4de751cbe29f', 'Pizzeria Romeo e Giulietta', 11.01, 4.3, 129, 3.99, 2.76, 'Medium')
# ('e8b46a0b-8535-4701-a8ec-70f4f719b79b', 'Sushi Buzz', 10.37, 4.7, 40, 3.76, 2.76, 'Medium')
# ('3ba03cb1-7d28-4e6f-bdac-23a338ce2a18', 'Pronto Pizza', 10.28, 4.4, 54, 3.71, 2.77, 'Medium')
# ('7d6942e0-9a60-4b4b-b4e1-ae218d5a2328', 'Le Pain Quotidien - Wemmel', 10.46, 4.6, 46, 3.78, 2.77, 'Medium')
# ('1cda864e-decd-486e-ae30-6ed7a1487443', 'Woodiz Basilique', 11.96, 4.6, 148, 4.31, 2.78, 'Medium')
# ('18cd3ee7-25e4-4b95-bdfd-fad5796632cf', 'Ni Hao', 10.96, 4.5, 68, 3.92, 2.79, 'Medium')
# ('f64673d5-ed6b-4046-b595-0318c6ba7d88', 'Taste of curry', 11.32, 4.4, 109, 4.03, 2.81, 'Medium')
# ('fd209364-1d88-4213-b9b2-96df85e4ddfe', 'BAVET - Hooiaard ', 11.12, 4.4, 90, 3.96, 2.81, 'Medium')
# ('4371b28f-bc9b-440f-b967-9ff1bb10a968', 'Simple Asia', 12.41, 4.6, 200, 4.38, 2.83, 'Medium')
# ('084b2c14-d32c-4f41-ba93-72edd24b0a38', 'La Pomme', 12.16, 4.7, 103, 4.28, 2.84, 'Medium')
# ('43fbd0cf-4e70-4189-8c60-820ebe85e54e', 'Takumi Ramen Kitchen - Marnix', 11.87, 4.6, 100, 4.18, 2.84, 'Medium')
# ('62e69218-c421-4e02-afc0-42eb6d46c96e', 'Pizarro', 12.19, 4.8, 82, 4.28, 2.85, 'Medium')
# ('6ded928a-9e76-4593-8a74-5e9a5c72b220', 'BAVET - MAS', 11.91, 4.6, 100, 4.18, 2.85, 'Medium')
# ('70a14ad1-f139-4b88-a9f3-4d6acdd659c6', 'Pizzeria Per Passione', 11.86, 4.5, 124, 4.16, 2.85, 'Medium')
# ('a7b89b79-dd8e-4574-9c25-b6a22e076ae8', 'Balls & Glory - Gent', 11.06, 4.5, 62, 3.88, 2.85, 'Medium')
# ('4ef2b39c-39c7-44aa-b5cb-9716c922aa73', 'Frituur pizzarie houba ', 10.87, 4.5, 55, 3.81, 2.86, 'Medium')
# ('b0bc113f-86e9-41ed-95e1-7e8d4957ac9f', 'Pizza Autentica', 11.0, 4.9, 36, 3.83, 2.87, 'Medium')
# ('7a1e0adb-de62-58c9-8326-68051103196d', 'KFC - Groot Bijgaarden', 10.24, 4.1, 64, 3.55, 2.89, 'Medium')
# ('89b7fe5a-613a-45a6-934e-a6202fdbe480', 'Pizzeria Zirar Saint-Denis', 10.52, 4.4, 48, 3.64, 2.89, 'Medium')
# ('22bdb428-3894-4d97-b877-bd208f050b23', 'JanYa Thai Wok', 10.51, 5.0, 26, 3.61, 2.91, 'Medium')
# ('58b36870-ec8c-57d6-9b35-d8a3efec96be', 'Pizzapastanr1 - Mechelen', 11.95, 4.5, 100, 4.09, 2.92, 'Medium')
# ('e6912819-7e9d-4ec6-b031-24e138082ea4', 'Mission Masalaâ€™s Curry Club - Antwerpen', 12.51, 4.7, 100, 4.27, 2.93, 'Medium')
# ('044cefe0-5cc7-4bc0-abf4-b39f8c4000f3', 'Paradise of India', 12.3, 4.6, 99, 4.18, 2.94, 'Medium')
# ('18a25d1f-2c53-44a2-a2be-53f43b75fdf7', 'Fu Bao', 12.41, 4.8, 72, 4.21, 2.94, 'Medium')
# ('790205ae-7d78-46f6-b689-f849730a8c13', 'Balls & Glory - Antwerpen', 11.07, 4.6, 44, 3.75, 2.95, 'Medium')
# ('94786f78-4183-4fc7-90b9-af8da24fc587', 'BAVET - Verlorenkost', 11.91, 4.5, 87, 4.04, 2.95, 'Medium')
# ('9dc6b860-3fd0-4044-89df-0eb4d0f15113', 'Takumi Ramen Kitchen - Centraal Station', 12.03, 4.6, 77, 4.07, 2.95, 'Medium')
# ('38913403-40ca-4799-ba96-b39d5abc22fd', 'Umamido - Vooruit', 11.85, 4.4, 100, 4.0, 2.96, 'Medium')
# ('5bf1cadc-37ab-4ef8-a0dc-d65fc7c35558', 'Hoshi Hoshi', 10.73, 4.4, 47, 3.63, 2.96, 'Medium')
# ('657b1574-c1ca-4f92-8f5b-e25f1f7090f3', 'Pizza Pazza', 11.78, 4.5, 76, 3.98, 2.96, 'Medium')
# ('8f86d439-f1f0-470b-bc06-e4e5e7eb09d2', 'Kalura', 12.03, 4.7, 63, 4.06, 2.97, 'Medium')
# ('26f74131-24e6-4029-a702-65be95051b77', 'Sumac - Kammenstraat', 11.86, 4.5, 77, 3.98, 2.98, 'Medium')
# ('9c3af6c4-47fb-5e1a-a56f-fde5ab5a5c2f', 'Casa Grande', 12.78, 4.7, 96, 4.26, 3.0, 'Medium')
# ('c60d20b7-be96-5c59-be19-d1cd2900b41e', 'The Ribhouse - Ghent', 11.57, 4.4, 71, 3.86, 3.0, 'Medium')
# ('34c0e0e6-42e1-4d34-b817-89955f3a6a77', 'Uzume Sushi Overpoort', 10.16, 4.3, 36, 3.37, 3.02, 'Medium')
# ('a19873d3-e010-41c1-b620-a7d326c7e92f', 'Otomat - MAS', 12.05, 4.5, 79, 3.99, 3.02, 'Medium')
# ('112e98b9-5e3e-4b59-8147-9013cb1de30a', 'Pizzeria Milano - Anderlecht', 10.37, 4.6, 29, 3.42, 3.03, 'Medium')
# ('52ea5fd9-168a-51a6-ad94-e169356c2fee', 'V Pizza', 12.14, 4.4, 100, 4.0, 3.03, 'Medium')
# ('d11de997-a81c-494b-844a-db2a2ee0bd59', 'PIZZAPAZZIA TOTO DILBEEK!', 11.53, 4.3, 76, 3.8, 3.03, 'Medium')
# ('3e90869b-8a9f-408e-948f-1359e99d32e4', 'Sum Sum', 11.59, 4.2, 100, 3.82, 3.04, 'Medium')
# ('963c0203-0e62-5e2d-8a37-c417b47a8160', 'Hanoi Station - CamÃ©lÃ©on', 12.35, 4.7, 63, 4.06, 3.04, 'Medium')
# ('2b87d62c-d72f-404b-b4c6-cfc267472f55', 'Wok masala', 10.4, 4.5, 31, 3.4, 3.06, 'Medium')
# ('33d02572-e6df-438d-acd8-109c509d9ab8', 'Delitraiteur - Kraainem', 10.17, 4.6, 26, 3.32, 3.06, 'Medium')
# ('da5a21d7-aab4-4a75-a9f5-9ad92a17eceb', 'Umamido - Leuven', 11.78, 4.3, 85, 3.85, 3.06, 'Medium')
# ('4a3db1bb-9540-42ad-bace-b76a73bef112', 'Royal Tokyo Sushi Antwerpen', 12.82, 4.6, 100, 4.18, 3.07, 'Medium')
# ('5c8c0826-02f5-4d10-a0f2-cc77e8c3223d', 'Le Pain Quotidien - De Wael', 10.57, 4.4, 36, 3.44, 3.07, 'Medium')
# ('8582def7-6693-4686-9936-7b0908575bf3', 'Boo-Bo Pizza & Pasta ', 12.54, 4.6, 79, 4.08, 3.07, 'Medium')
# ('7385e828-c318-43a5-8185-1c716510ac01', 'Pizza Hut - Evere', 13.54, 4.6, 200, 4.38, 3.09, 'Medium')
# ('768646d5-9a1c-4b42-ac7f-ca8f221b2b50', 'Asian King', 12.08, 4.6, 57, 3.91, 3.09, 'Medium')
# ('022dcbf7-e19c-46cd-9ded-6fc205bc0c28', 'BAVET - Muinkkaai', 12.12, 4.4, 79, 3.91, 3.1, 'Medium')
# ('e7b6ba0c-a450-4818-8a9f-c355cc0f956b', 'Nani.', 12.86, 4.7, 76, 4.15, 3.1, 'Medium')
# ('ca391c1a-3c8a-441e-8ec5-9bfe030bf465', 'Umamido - Antwerpen Zuid', 11.94, 4.5, 57, 3.83, 3.12, 'Medium')
# ('351f26f6-728c-4f50-a003-07b9843b0cbd', 'Otomat - Gent', 11.66, 4.3, 65, 3.73, 3.13, 'Medium')
# ('5843d5e0-145c-5cd9-9469-7db64f97ade5', 'Chez Giovanni', 13.4, 4.5, 200, 4.29, 3.13, 'Medium')
# ('127c7053-6eb4-42d9-87b3-1fea14117aad', '18 sushi', 10.16, 4.7, 22, 3.23, 3.14, 'Medium')
# ('6a7cf886-a14b-41e9-8185-8309fd6b2b02', 'Pizza Pasta Nr 1 - City', 12.86, 4.6, 82, 4.1, 3.14, 'Medium')
# ('d42aa778-a45d-4cbf-bbfb-334f84d1f975', 'Hau Wang', 11.89, 4.2, 91, 3.78, 3.14, 'Medium')
# ('a6df3927-f1ff-4589-b644-12224c4b4889', 'Yaki Noodle Bar', 12.61, 4.6, 67, 4.0, 3.15, 'Medium')
# ('271c3881-1f8a-429b-83bb-29d7c4096a01', 'BAVET - Nationalestraat', 12.34, 4.3, 100, 3.91, 3.16, 'Medium')
# ('8d677e7f-a73c-4127-bf76-824bac5c3307', 'Tutti Atelier', 11.54, 4.5, 43, 3.65, 3.16, 'Medium')
# ('d42de154-acf8-4ffe-9086-23e98593dcfa', 'La Taqueria', 10.53, 4.1, 43, 3.33, 3.16, 'Medium')
# ('eb03eb02-343d-4dc1-abcd-73aaa934d168', 'Il Pastaiolo', 10.89, 4.6, 30, 3.45, 3.16, 'Medium')
# ('f3a3c3ca-5c93-43ad-bb36-6f57e1001e8d', 'Ellis - Leopold De Wael', 11.17, 4.2, 53, 3.53, 3.16, 'Medium')
# ('119a6b93-bb35-43e9-a6ea-febfb2576ef0', 'Wagamama - Antwerpen', 12.96, 4.5, 100, 4.09, 3.17, 'Medium')
# ('4a37df1f-49c1-4e34-8a46-1e62201d4078', 'Ni Hao', 11.09, 4.4, 39, 3.5, 3.17, 'Medium')
# ('66d6c742-83b6-499e-8567-689176a26711', 'LouLou ', 11.17, 3.7, 200, 3.52, 3.17, 'Medium')
# ('ca107dcd-71f0-457d-96e2-5ebd9183d722', 'Makiline', 10.63, 4.4, 32, 3.35, 3.17, 'Medium')
# ('c04019bd-f140-465c-829e-b91b891db16d', 'Orient Express', 12.49, 4.4, 82, 3.92, 3.18, 'Medium')
# ('f21d6762-8a3a-40fb-9e5a-d0f24d1e8ef5', 'Orient Kitchen', 12.79, 4.4, 105, 4.02, 3.18, 'Medium')
# ('df300943-cfd3-4df1-b0df-a7992c1632ac', 'Schievelavabo - Uccle', 13.36, 4.5, 132, 4.18, 3.19, 'Medium')
# ('795c7611-0260-4562-b9cf-760144d5144f', 'Sensei Sushi - Jette', 13.38, 4.5, 131, 4.18, 3.2, 'Medium')
# ('890cb20e-8629-4eab-a2f1-cc27ecedcd7c', 'Sushi Shop - Woluwe', 11.75, 4.2, 69, 3.67, 3.2, 'Medium')
# ('c507c826-fb79-4e20-b9ec-415ee9a731ac', 'BAVET - Tiensestraat', 12.12, 4.3, 74, 3.79, 3.2, 'Medium')
# ('8078306b-7f47-4140-9588-63aa930b2127', 'Tenshi - Stockel', 14.33, 4.7, 191, 4.47, 3.21, 'Medium')
# ('86558e8c-a928-45eb-ab7f-236f17ada7ba', 'Ho Chan House', 13.41, 4.7, 80, 4.18, 3.21, 'Medium')
# ('cccf8111-b65b-4d08-a44f-3a60ded5ab5e', 'Schievelavabo - Auderghem', 12.31, 4.5, 57, 3.83, 3.22, 'Medium')
# ('47132f54-9b92-4aa1-9781-80d61c7745bb', 'Fugu - Sushi Bar', 11.06, 4.1, 51, 3.43, 3.23, 'Medium')
# ('96401492-c877-4308-a033-8658c141459f', 'Prima Donna', 12.41, 4.4, 68, 3.84, 3.24, 'Medium')
# ('a8550966-2ace-5c8d-8a86-5144e50aa6c3', 'Acqua e Farina', 11.25, 4.2, 48, 3.48, 3.24, 'Medium')
# ('5c5297dc-a6f2-475e-a034-b48d478b2544', 'Be sushi pokebowl', 11.87, 4.8, 32, 3.66, 3.25, 'Medium')
# ('9b2e90b8-ccf5-48fc-8e0d-86d19aef9234', 'Indian Curry House', 13.58, 4.6, 100, 4.18, 3.25, 'Medium')
# ('2fe65cc7-4228-4a0e-bd13-3c50f6f9dc7a', 'BeÃ¯rut - Restaurant Libanais', 11.95, 4.2, 67, 3.65, 3.27, 'Medium')
# ('2d7eabe9-b35e-46ca-82c3-98ca2b19956c', 'Byblos', 11.23, 4.5, 32, 3.43, 3.28, 'Medium')
# ('4eb3b470-9771-48a8-8113-15dd508fbaa0', 'Pizza Hut - Zaventem', 13.54, 4.5, 109, 4.12, 3.29, 'Medium')
# ('07e88211-5196-48f3-a7ab-586724e092c3', 'Azzurro Pizza', 12.37, 4.6, 43, 3.73, 3.31, 'Medium')
# ('57089fd2-42f6-4567-b6d4-29eaff8626bf', 'PokÃ© House - Uccle', 14.5, 4.6, 200, 4.38, 3.31, 'Medium')
# ('411e7e37-06d1-4c92-b909-46ceb63926a0', 'Mia pizza - Evere', 11.77, 4.5, 37, 3.54, 3.32, 'Medium')
# ('4e51a274-6f6f-4896-8d6a-7196f059a4b2', 'Nora tandoori', 11.57, 4.2, 49, 3.49, 3.32, 'Medium')
# ('e39015f0-6e3e-4f09-99eb-f7ab419ddf35', 'Pizza Pasta Concept', 12.64, 4.3, 77, 3.81, 3.32, 'Medium')
# ('eb218e94-44ea-4b15-acd9-46a2355ab4ab', 'Pizza Hut - Jette', 13.54, 4.4, 128, 4.08, 3.32, 'Medium')
# ('fab04a45-8b36-42d9-a504-c2463c153af8', 'BAVET - Mechelen', 11.91, 4.4, 44, 3.59, 3.32, 'Medium')
# ('04299cbe-f657-4745-af55-1cdfa459921c', 'De Gekroonde Hoofden - Gent', 14.76, 4.9, 89, 4.41, 3.35, 'Medium')
# ('08243c69-25ef-428f-ac0e-8866b55a0341', 'Pizza Hut - Antwerpen', 13.4, 4.4, 100, 4.0, 3.35, 'Medium')
# ('4b365383-498d-4055-917a-e018ddb92562', 'Thai CafÃ© - Fort Jaco', 14.65, 4.6, 181, 4.36, 3.36, 'Medium')
# ('9a19371b-1357-4137-a1a2-02a44a5f593d', 'New SaÃ¯gon Bangkok', 11.33, 3.8, 78, 3.37, 3.36, 'Medium')
# ('e5bd6d4f-72aa-4ef0-b2e1-c34d54c78644', 'KFC - Wijnegem', 10.02, 3.3, 92, 2.98, 3.37, 'Medium')
# ('78077359-37df-4ad1-a51d-1e04faf0c24a', 'Pizza Hut - Waterloo', 13.54, 4.5, 79, 3.99, 3.39, 'Medium')
# ('a3c1d39e-2a6d-5444-b3bf-4ec09efba9dc', 'The Cousinâ€™s', 12.11, 4.1, 67, 3.57, 3.39, 'Medium')
# ('025e6035-b77e-5767-bb5b-d6c99c26d071', 'BAVET - Oostende', 12.12, 4.5, 38, 3.56, 3.4, 'Medium')
# ('0aad518a-e237-4823-9943-a08da27774ac', 'La Grande Muraille', 10.79, 4.1, 34, 3.17, 3.4, 'Medium')
# ('68badd0a-7353-41ce-b667-b7049a704ae4', 'Pita Ster', 10.06, 4.3, 22, 2.96, 3.4, 'Medium')
# ('de8f613c-45f1-436f-becd-258a8812270e', 'Tito fresh pasta', 11.96, 4.3, 45, 3.52, 3.4, 'Medium')
# ('e149beb9-57a5-4b99-ac00-3fbe2ad8673d', 'Donki - Leuven', 13.61, 4.4, 100, 4.0, 3.4, 'Medium')
# ('e22c612d-c208-5817-bc59-38024f03b229', 'BFC ZAVENTEM', 11.67, 4.0, 61, 3.44, 3.4, 'Medium')
# ('fa477df9-fed7-5346-9e26-3eebaed79c70', 'Asian Time ', 10.61, 4.1, 32, 3.12, 3.4, 'Medium')
# ('17e99c64-35ed-47e7-b1f7-99cecb86b4d1', 'Pizza Taxi', 13.6, 4.5, 77, 3.98, 3.41, 'Medium')
# ('1e7fece4-8ba9-4bb6-85ee-7cf78f1fa1e6', 'Pizza Hut - Sint Pieters Leeuw', 13.54, 4.5, 76, 3.98, 3.41, 'Medium')
# ('4ca52afe-48b8-4e5d-899c-b1f4ca5cdc01', 'Pizza Hut - Heuvelpoort', 13.54, 4.6, 63, 3.97, 3.41, 'Medium')
# ('7793b66d-1d43-4e69-aaa2-d9b32d55a3ee', 'Pizza Hut - St-Annastraat', 13.54, 4.5, 75, 3.97, 3.41, 'Medium')
# ('c2720bb2-ce36-4896-b4c5-7a73e62f15a7', 'Yu-Thai', 13.48, 4.4, 85, 3.94, 3.42, 'Medium')
# ('efb3eaee-ab4f-4d60-ba98-f588cebcc4df', 'Takumi Ramen & Yakisoba', 12.92, 4.6, 46, 3.78, 3.42, 'Medium')
# ('f3562d7d-3a2b-4d9c-855f-3b2c39abb5a9', 'Taste of India - Oostende', 10.95, 4.6, 23, 3.21, 3.42, 'Medium')
# ('cc5940d0-6ca7-4e02-8f61-c7f5d5872d30', 'La Cucina - Pizzeria Tradizionale', 14.75, 4.5, 199, 4.28, 3.44, 'Medium')
# ('9d9cae01-1ed2-4e4f-83a4-530b4a5514e9', 'Hokkaido sushi', 10.92, 4.6, 22, 3.16, 3.45, 'Medium')
# ('71bf98d2-d7e8-50b8-b4ba-77af95ef12fb', 'Asian express', 10.5, 4.3, 24, 3.04, 3.46, 'Medium')
# ('e899174b-a00a-43db-8a3d-34ebc83850d7', 'Lucy Chang - Gent', 13.53, 4.3, 100, 3.91, 3.46, 'Medium')
# ('0d90b28b-6418-4b26-8a16-a9549be85d39', 'Le Croissant', 10.05, 4.7, 16, 2.89, 3.47, 'Medium')
# ('eea047ad-40a2-4375-95ef-6ec559ff1136', 'Pita vogelmarkt', 11.53, 4.3, 34, 3.32, 3.47, 'Medium')
# ('1a547cb8-b20a-4ee3-8b77-82cf81e584bb', 'Thai CafÃ© - Stockel', 14.59, 4.4, 200, 4.19, 3.48, 'Medium')
# ('3edae651-c19f-4ee9-aec7-4b030cb54582', 'Pizza Hut - Anderlecht', 13.54, 4.4, 76, 3.89, 3.48, 'Medium')
# ('d55c8626-3ecc-4359-a73b-665705ef637f', 'Pizza Hut - Berchem', 13.54, 4.5, 64, 3.89, 3.48, 'Medium')
# ('fbeddf48-b35a-4f35-890d-d3bfdd047769', 'Sushi Berchem', 12.3, 4.8, 28, 3.54, 3.48, 'Medium')
# ('9e46368b-576c-41cd-aeb6-d2efd5737810', 'Thai CafÃ© - Waterloo', 14.45, 4.5, 110, 4.13, 3.5, 'Medium')
# ('bf9c8e29-36d4-5de7-a322-412117ac3521', 'BAVET - Kortrijk', 12.81, 4.8, 32, 3.66, 3.5, 'Medium')
# ('ccf231cb-22b9-49f6-8049-7350316a9d9d', 'De Kraanvogel', 13.95, 4.5, 78, 3.99, 3.5, 'Medium')
# ('f2d4cb4e-0f74-436e-a0e5-d1fb10ae3e57', 'Thai CafÃ© - Forest', 14.66, 4.5, 129, 4.18, 3.51, 'Medium')
# ('7c699910-9262-4621-9dea-1ad9ae06bfe3', 'Indian Royal Food', 10.7, 4.3, 24, 3.04, 3.52, 'Medium')
# ('9973c231-b333-4bd4-b9d8-dbf9d5fac3ea', 'Lucy Chang - Marnixplaats', 13.53, 4.2, 100, 3.82, 3.54, 'Medium')
# ('ff1432a8-cff0-4c87-b367-ea9f41cae863', 'Pastabar Da Riccardo', 11.31, 4.3, 29, 3.2, 3.54, 'Medium')
# ('c1f820dd-226a-4800-b6c7-7d2327f1bf5f', 'Royal sushi', 12.11, 4.2, 43, 3.41, 3.55, 'Medium')
# ('4d5b0503-25dd-5c03-b834-4cbddaff7d9b', 'Made in Sud', 13.6, 4.4, 66, 3.82, 3.56, 'Medium')
# ('7f96d43e-4570-4c12-872c-e2e6cb61cdb9', 'Ni Hao Mechelen', 12.82, 4.2, 60, 3.6, 3.56, 'Medium')
# ('8a1f803f-c7bd-54b7-ae11-7ae9aa8dd719', 'Sushi Mama', 10.08, 4.5, 17, 2.83, 3.56, 'Medium')
# ('fbb98cc9-91d3-5ecd-8df8-2953931a74e4', 'Brozen Restaurant', 11.65, 4.4, 29, 3.27, 3.56, 'Medium')
# ('0286b761-b00a-4942-9e1e-0bc4aef11634', "Domino's Pizza  - Berchem St Agathe", 10.93, 3.9, 36, 3.05, 3.58, 'Medium')
# ('92b036b3-ce6e-45d8-b567-8a994aec9e7e', 'Sushi Plaza', 11.28, 4.2, 30, 3.15, 3.58, 'Medium')
# ('bcc0dec2-ca22-48c4-8226-72ec11e4bf9c', 'Mother India', 14.16, 4.3, 116, 3.96, 3.58, 'Medium')
# ('ad0a4cfc-54c1-495e-adc7-249d102981a3', 'Thai CafÃ© - Docks', 14.52, 4.4, 112, 4.04, 3.59, 'Medium')
# ('1b5cee62-9371-4f4f-a027-f8e636d53d8e', 'Libanese Snack', 10.72, 4.4, 21, 2.98, 3.6, 'Medium')
# ('4d05fdaf-ddf8-4a9d-b1d1-0ed77c68e3da', "Seli's Noodlebar", 11.94, 4.5, 28, 3.32, 3.6, 'Medium')
# ('53b56c2d-9a50-4d24-912c-7e249762a09e', 'Pizza Del Conte', 12.24, 4.5, 31, 3.4, 3.6, 'Medium')
# ('62e86d58-8805-4985-8416-9431f5892f86', 'Lunch Korea (choolchool-i)', 13.22, 4.9, 30, 3.67, 3.6, 'Medium')
# ('6f143d5c-f3de-4294-862d-bcd8ba2a3992', 'Pizza Hut - Wemmel', 13.73, 4.3, 78, 3.81, 3.6, 'Medium')
# ('fb5465c8-d3f2-4251-b3cc-a42703a80087', "BE Jack's", 12.33, 4.1, 51, 3.43, 3.6, 'Medium')
# ('3651098f-7222-4c77-9cf6-670d6ddb247f', 'Little BÃšN - Theater', 13.0, 4.6, 36, 3.6, 3.61, 'Medium')
# ('50d0b09c-9f20-5c8f-99cb-378950f7dcd9', 'MiTo Orban / Milano Torino', 16.18, 4.7, 200, 4.48, 3.61, 'Medium')
# ('752912fa-981c-4eb4-ac92-161bdac42769', 'Pizza service Brugge ', 13.06, 4.4, 46, 3.61, 3.61, 'Medium')
# ('16ff4de0-4498-4e05-bc8f-4c0c0af34963', 'Nobu Sushi', 13.51, 4.5, 49, 3.74, 3.62, 'Medium')
# ('bb259509-17ec-4e58-93b2-69e4e7c47c57', 'Nuoc Mam', 15.57, 4.8, 86, 4.3, 3.62, 'Medium')
# ('cc84a050-e573-4ce4-b0bf-4367cbb56d2f', 'Bois Savanes', 15.73, 4.7, 120, 4.34, 3.62, 'Medium')
# ('367bb6bc-63b1-4401-8c99-8742e44f54e5', 'Dacci un taglio', 13.76, 4.5, 52, 3.77, 3.64, 'Medium')
# ('bb790477-2330-5036-9dec-e68bb7cbe2cc', 'Belchicken - Aalst', 13.9, 4.2, 100, 3.82, 3.64, 'Medium')
# ('e60b1ac0-39e2-4641-80e7-29f36b073d43', 'Himalaya', 10.32, 4.5, 17, 2.83, 3.64, 'Medium')
# ('08018899-91d0-4764-a1b8-3c39bb169d84', "Hell's kitchen", 10.12, 4.4, 17, 2.77, 3.65, 'Medium')
# ('dcf96772-8188-423d-89cb-615ba63359e2', 'Otomat - Leuven', 12.78, 4.3, 44, 3.5, 3.65, 'Medium')
# ('17a7d904-ab96-4bdc-9eac-24f67a8c6717', 'Wabi Sushi', 13.27, 4.1, 76, 3.62, 3.66, 'Medium')
# ('5948d775-8b90-483c-8c1f-007d15dd49db', "Giuseppe's pizza forno a legna", 14.44, 4.4, 86, 3.94, 3.66, 'Medium')
# ('69c7b94a-a697-42d9-96ae-337363824aa4', 'Banh Mi Kiosk', 10.46, 4.9, 14, 2.86, 3.66, 'Medium')
# ('cb36e000-facd-4eb1-8f53-35f15d4962e1', 'Le Lion belge', 13.25, 4.5, 41, 3.62, 3.66, 'Medium')
# ('163a76bf-5239-40fc-9e65-5e3ac7bd5739', 'Peppermint Park ', 13.7, 4.5, 49, 3.74, 3.67, 'Medium')
# ('1bb88af8-1846-4947-95f8-3ab1c894e474', 'Tasty Thai Express', 11.27, 4.4, 23, 3.07, 3.67, 'Medium')
# ('d5dde7ec-a7fc-4472-997a-3eed6864e789', 'Pizzeria Gloria ', 12.83, 4.7, 29, 3.49, 3.67, 'Medium')
# ('95f787ae-9aa5-49d9-98b3-f186f4592376', 'Delitraiteur - Ganshoren', 10.17, 4.3, 18, 2.76, 3.68, 'Medium')
# ('9f415747-d357-4f53-a450-1fca91ad5a7b', 'Il Teatro', 12.89, 4.5, 35, 3.5, 3.68, 'Medium')
# ('61769f6b-6819-4168-ae83-a7a9b651c882', 'Uzume Sushi Bar', 13.04, 4.4, 41, 3.54, 3.69, 'Medium')
# ('75fcb665-281e-44e6-bda4-6c221afdced4', 'Taj Mahal', 12.37, 4.4, 32, 3.35, 3.69, 'Medium')
# ('d2b8c787-21c7-4f04-ad2e-9bd546b326a5', 'New Holy Cow', 13.37, 4.4, 47, 3.63, 3.69, 'Medium')
# ('6422a5f2-f3b5-46a1-a26d-cdfcaa9f8f37', 'Pizza Hut - Halle', 13.54, 4.6, 39, 3.66, 3.7, 'Medium')
# ('e30e5f90-de04-4597-bf34-4f8fb7fc04ff', 'Ninja Restaurant', 12.76, 4.6, 30, 3.45, 3.7, 'Medium')
# ('98de46f6-8dfc-4497-9113-e75eb0a5f52d', 'BAVET - Simon Stevinplein ', 11.65, 4.3, 27, 3.14, 3.71, 'Medium')
# ('19e8eabb-7eaf-41a0-ab84-636bce37ec7e', 'JEAN sur MER Harbor Cafe', 11.79, 4.1, 34, 3.17, 3.72, 'Medium')
# ('98956037-21ac-4577-baf0-79e2aa27633b', 'GULZIG', 13.76, 4.6, 41, 3.7, 3.72, 'Medium')
# ('bb46c349-ad59-4013-9762-5351f7bd1188', 'Moochie Frozen Yogurt - Antwerpen', 10.1, 4.5, 15, 2.7, 3.74, 'Medium')
# ('f5cf5976-b101-46ec-8cca-663cd6821290', 'My kebab - Zonhoven', 11.07, 4.6, 18, 2.96, 3.74, 'Medium')
# ('3e52e315-6bb6-4008-80ce-527c9310a5b6', 'Pizza factory 100% Italiano', 13.84, 4.4, 52, 3.69, 3.75, 'Medium')
# ('735b9aef-09ec-54b1-958a-7d0a5c30deb9', 'KingRibs - Schoten', 10.61, 4.6, 16, 2.83, 3.75, 'Medium')
# ('8c651841-ca82-5986-b65c-f7ade29361b1', 'I DUE FRATELLI', 11.98, 4.0, 40, 3.2, 3.75, 'Medium')
# ('e027e277-bd16-4c3a-85f2-0d98102865ac', 'Banana Leaf  Indian Restaurant', 11.6, 4.5, 22, 3.09, 3.75, 'Medium')
# ('379d181f-0315-4c38-abca-4d5b59d878d3', 'Zaowang', 15.71, 4.6, 100, 4.18, 3.76, 'Medium')
# ('6437e492-908b-4e25-bef2-ebbc7776b4a0', 'Petit Thai', 14.62, 4.7, 48, 3.89, 3.76, 'Medium')
# ('b7a277a6-e29f-48a3-81e3-bb4fb3da2947', 'Pizza Hut - Tervuursevest', 13.54, 4.5, 40, 3.6, 3.76, 'Medium')
# ('12bab333-ab28-436c-a1f1-63f55c53569b', 'La CitÃ© Du Mandarin', 14.09, 4.3, 66, 3.73, 3.77, 'Medium')
# ('17fbf143-13ab-400c-b309-4255f3137271', 'Belchicken - Rooigemlaan', 14.4, 4.2, 100, 3.82, 3.77, 'Medium')
# ('45be42ad-936d-49e5-8182-87db1f2fee2c', 'Pizza Vito', 12.92, 4.7, 27, 3.43, 3.77, 'Medium')
# ('1b703638-b75b-4720-9b47-d94733523ea0', 'La Feuille de Menthe', 11.15, 3.9, 31, 2.95, 3.78, 'Medium')
# ('4c42c77e-67da-5478-b756-db222606869f', 'Asian Burger Wok & Sushi', 12.04, 4.0, 39, 3.18, 3.78, 'Medium')
# ('71a0a31f-0ac6-4d90-93cb-16fe33fb9cbd', 'Tandoori-Pasta', 14.16, 4.6, 43, 3.73, 3.79, 'Medium')
# ('bdc6049d-422b-49d7-9ff9-1b3d75c3ce63', 'Pita Amon', 11.88, 4.7, 20, 3.13, 3.79, 'Medium')
# ('6264b7ce-0409-48b1-ad71-c66df1a201c5', 'Himalayan Cuisine', 12.18, 4.1, 36, 3.21, 3.8, 'Medium')
# ('b06cca89-ba36-4cb5-8c0a-141cc08b6992', 'Comme Chez Fleur', 15.61, 4.4, 137, 4.1, 3.81, 'Medium')
# ('22e41231-af0f-446a-8195-bb6c49050ba8', 'Ellis - Aalst', 11.25, 4.0, 28, 2.95, 3.82, 'Medium')
# ('2f0344c4-5d8b-4a3c-b2c4-525a8e831a56', 'BellaVita', 10.6, 4.4, 17, 2.77, 3.83, 'Medium')
# ('63e69ab4-2e97-4519-bbda-88e27a5eb481', 'Twilight sushi', 13.06, 4.5, 31, 3.4, 3.84, 'Medium')
# ('91c22b31-4527-44a6-b749-dc037d05a7d6', 'Pizza Hut - Molenbeek', 13.54, 4.2, 52, 3.52, 3.84, 'Medium')
# ('bd3f3a3b-0746-40f4-9391-fcc324c7c95b', 'Nour Al Cham - Zain Damas', 14.57, 4.6, 47, 3.79, 3.84, 'Medium')
# ('f69a5f51-5312-59e0-b416-00564b85bbbc', 'La Zone ðŸ’¯', 11.55, 3.8, 38, 3.01, 3.84, 'Medium')
# ('bd29adad-8a10-4cf5-a1ed-38adcda17af9', 'Traiteur Wang ', 12.82, 4.6, 26, 3.32, 3.86, 'Medium')
# ('20cbfa88-3f17-4985-b283-8c92acb10489', 'Pizza Hut - Heldenplein', 13.54, 4.5, 35, 3.5, 3.87, 'Medium')
# ('82806fe5-1ff2-4519-83b0-8542796f4983', 'Beiruti', 12.23, 4.0, 37, 3.15, 3.88, 'Medium')
# ('8e57fc94-a61b-49b5-b816-db50e97ddb22', 'Standard', 12.96, 4.2, 39, 3.34, 3.88, 'Medium')
# ('fdb12383-c29a-435e-b1db-9dc7d92a7905', "Pizzeria l'Ami", 12.34, 3.9, 44, 3.18, 3.88, 'Medium')
# ('33efa2b0-e9ce-5125-a511-da3b3aee1aeb', 'Rebel Kitchens', 11.08, 4.6, 16, 2.83, 3.91, 'Medium')
# ('8f8cd0df-b2c6-44a0-a5e5-cb18469aeda1', 'Oishi Sushi', 11.01, 4.3, 19, 2.82, 3.91, 'Medium')
# ('a3aadad8-d638-4ae0-9492-4a555763ad8e', 'Au Coeur Bleu', 14.07, 4.8, 30, 3.6, 3.91, 'Medium')
# ('002b3539-72a4-49ce-a606-51da9fd8a07a', 'Pizzeria La Lanterna', 13.78, 4.3, 45, 3.52, 3.92, 'Medium')
# ('7a2dc3db-c05b-5ab6-8797-cc97e356d3d7', 'Sezer Snack-Pizza', 11.34, 4.0, 26, 2.89, 3.92, 'Medium')
# ('94389925-5af5-4fa7-9a55-15011f1928dc', 'Ellis - Gent', 11.03, 3.4, 47, 2.8, 3.93, 'Medium')
# ('c0889ac3-658f-50a3-bf57-76704b4cea06', 'Pizzeria Parma', 11.68, 4.2, 24, 2.96, 3.94, 'Medium')
# ('f9785060-0b6d-43d0-a312-fb2df8ed5029', 'Damas Veneto', 10.36, 3.2, 46, 2.63, 3.94, 'Medium')
# ('1a31a96e-9d41-4e9a-ba72-d941556e1b96', 'Alfons Burger - Zaventem', 10.14, 4.4, 14, 2.57, 3.95, 'Medium')
# ('1d64e6e9-710e-5b8c-b90b-1d76631a78b7', 'New Time', 10.66, 4.2, 18, 2.7, 3.95, 'Medium')
# ('c23770aa-5541-4f02-a41c-2603968cb8fd', 'Pizza Meet Point', 13.27, 4.2, 40, 3.36, 3.95, 'Medium')
# ('8b114221-1759-5e0f-bbb1-c1f094f04d54', 'Sensei Sushi - Meizer', 13.35, 4.3, 36, 3.37, 3.97, 'Medium')
# ('3204a47d-3df3-5634-8618-28d947d819f5', 'Signature Sushi', 11.49, 4.8, 15, 2.88, 3.99, 'Medium')
# ('4a44250f-b552-4072-bf33-7f156502ef54', 'Chez Hassan ', 17.09, 4.6, 135, 4.28, 3.99, 'Medium')
# ('7fdd8fd2-c35c-4909-9354-86e67f5a86fe', 'Source du Liban', 13.65, 4.6, 29, 3.42, 3.99, 'Medium')
# ('adb8e1f6-e76e-4e6b-9cfa-6bef57e3fe5d', 'Pizzeria NICOLETTA', 14.84, 4.2, 77, 3.72, 3.99, 'Medium')
# ('b8607ac4-5eb7-4758-b2fa-60d1e0ac91f8', 'Sushi Aalst', 11.81, 4.6, 18, 2.96, 3.99, 'Medium')
# ('ce5b4389-ef9b-48c7-a69b-832b379d2567', 'Doy Doys', 10.16, 4.5, 13, 2.54, 4.0, 'Medium')
# ('141d9bdb-95e5-4530-ac44-4d7d7275400e', 'Mei Wei Cheng', 12.19, 4.3, 24, 3.04, 4.01, 'Medium')
# ('dd4984e3-b7f5-4fd1-931e-5d9d53218bbe', 'Pizza Sole Mio', 11.3, 3.9, 26, 2.82, 4.01, 'Medium')
# ('56277f2a-eb76-405a-9225-70c38d031a7e', 'Pizzeria 77', 15.13, 4.6, 45, 3.76, 4.02, 'Medium')
# ('db4740f9-4ac3-5922-9cae-6ac27e510342', 'The Pizza Corner', 11.92, 4.2, 24, 2.96, 4.02, 'Medium')
# ('2fc91685-b2ba-41e4-af35-a86b78af32e5', 'PRIMO Pasta Fresca - Vleurgat', 12.63, 4.5, 23, 3.14, 4.03, 'Medium')
# ('efe95f5c-17b5-4b5d-ba09-3828520c3d67', 'Moochie Frozen Yogurt - Gent', 10.33, 4.7, 12, 2.56, 4.03, 'Medium')
# ('53ddd84d-f3e8-5293-8bf9-5ecc601a7990', '@Wok', 10.6, 4.8, 12, 2.62, 4.05, 'Medium')
# ('0ac6094b-5a01-426f-9dbd-20e2668ab573', 'Diamond Pizza Merksem', 12.02, 4.6, 18, 2.96, 4.06, 'Medium')
# ('47e5c639-6f5d-4f6c-8aa7-d049df70f702', "L'Amusoir", 12.0, 4.6, 18, 2.96, 4.06, 'Medium')
# ('f6a742bd-e31e-4d08-b6e8-01a6293659e3', 'Umi Sushi', 16.06, 4.7, 53, 3.95, 4.06, 'Medium')
# ('79053682-d33f-421a-9124-601b8a667060', 'Pizza Hut - Oostende', 13.54, 4.4, 31, 3.33, 4.07, 'Medium')
# ('87350b9d-e577-58ce-bcba-5b2047c1ebf3', 'Can pizzeria', 10.31, 4.2, 15, 2.52, 4.09, 'Medium')
# ('d6d1d860-22cb-4e27-9df4-8e5ece36679a', 'Whitegrass', 12.07, 4.5, 19, 2.95, 4.09, 'Medium')
# ('4751726f-5145-420a-b244-9c814acd5cb4', 'Bronzi', 13.86, 4.5, 30, 3.38, 4.11, 'Medium')
# ('8af8f289-402c-43b7-9dea-0bf994d3b5e5', 'malaciorta', 14.78, 4.5, 40, 3.6, 4.11, 'Medium')
# ('c5b9fcf8-84c0-4448-995d-54a040a98fdf', 'SUSHI EILAND', 15.85, 4.7, 45, 3.85, 4.12, 'Medium')
# ('6d3e30fc-ee82-46c3-bdb3-f8fc97b4ae16', 'Thai CafÃ© - Genval', 14.55, 4.2, 51, 3.51, 4.14, 'Medium')
# ('a22dc4aa-fa6d-4df4-8ff0-58de35caafdc', 'Le Guignol Uccle', 15.03, 4.8, 31, 3.63, 4.14, 'Medium')
# ('16766ef3-5680-4526-aec2-c89ec390b33b', 'My Thai', 13.92, 4.7, 25, 3.36, 4.15, 'Medium')
# ('5e56f5d0-ff5d-5645-9014-a9fd465cd2a9', 'Pita Piramide', 12.58, 4.2, 26, 3.03, 4.15, 'Medium')
# ('c7375e92-40a4-492d-a3f8-5365c4270749', 'Ellis - Keyserlei', 11.25, 4.0, 21, 2.71, 4.15, 'Medium')
# ('f413f637-51bc-4967-a4b4-008f0373f594', 'Rosso Peperone', 14.13, 4.5, 31, 3.4, 4.15, 'Medium')
# ('cf98f1ae-4dab-52f1-8cb0-dd03edec17ad', 'Bollyfood Stories By Bivouwag', 12.64, 4.3, 24, 3.04, 4.16, 'Medium')
# ('33f43767-8674-5129-9a34-e669db0c8c7b', 'Corner City', 13.93, 4.3, 35, 3.34, 4.17, 'Medium')
# ('4e26ab07-37fb-42b7-b243-9d0bfac33c62', 'Ellis - Brugge', 11.49, 4.0, 22, 2.75, 4.18, 'Medium')
# ('5673f14d-9cd3-4dd9-8ced-519be398b1a7', 'Dilmon', 14.96, 4.7, 32, 3.58, 4.18, 'Medium')
# ('cf776c0d-9e64-4214-995f-c5539dd22635', 'Sushi Leuven', 12.09, 4.2, 22, 2.89, 4.19, 'Medium')
# ('1a11a28e-43d0-4a0f-8990-569e26b4bd8f', 'Pizza Hut - Deurne', 13.54, 4.2, 33, 3.22, 4.2, 'Medium')
# ('595d888c-22f4-4523-9ced-46b90a73b802', 'I Love Pizza ðŸ\x8d•', 12.49, 4.0, 29, 2.97, 4.2, 'Medium')
# ('a48e7421-c34b-4c27-bb17-a4c3fdbc6aaf', 'Pizza Hut - Aalst', 13.54, 4.1, 37, 3.23, 4.2, 'Medium')
# ('dd74cdce-5dcb-48ac-8233-f46106b8578b', 'Lotus Bleu ', 12.48, 4.2, 24, 2.96, 4.21, 'Medium')
# ('4b7a68fc-7030-4a74-a5f3-5908f270200f', 'Oasian', 14.77, 4.7, 29, 3.49, 4.23, 'Medium')
# ('5a603fd8-4bfa-44e7-a4ad-47063893957f', "Fratello's", 13.38, 4.9, 18, 3.15, 4.25, 'Medium')
# ('9c5465c1-8f0d-4142-9edf-2555dc35142b', 'Yum Yum Sushi', 16.32, 4.4, 68, 3.84, 4.26, 'Medium')
# ('bb4acd25-382e-4294-9441-ef65429e70e9', 'Pizza gulhan', 11.44, 4.6, 14, 2.68, 4.26, 'Medium')
# ('1ddb91aa-d357-489a-be5b-6e1a6ed241b6', 'Rasoi - Indian Cuisine', 10.13, 4.2, 13, 2.37, 4.27, 'Medium')
# ('b3501228-42bc-4b53-84a6-c495e9b6c7af', 'Saki Sushi', 14.02, 4.5, 27, 3.28, 4.27, 'Medium')
# ('b6d2257c-eba7-49b3-acb3-0bdaf1a8cdc7', 'Belchicken - Abdijstraat', 10.42, 3.6, 21, 2.44, 4.27, 'Medium')
# ('3497df18-089e-44a8-9542-1dd0f65f7aee', 'Yotaya', 13.73, 4.2, 32, 3.2, 4.29, 'Medium')
# ('4f04dfe8-d434-4a38-9d22-e187a140c48e', "Tang's Palace", 15.98, 4.7, 38, 3.72, 4.29, 'Medium')
# ('9d163314-a982-4945-a034-d1532be62abb', 'New Asia', 12.8, 4.4, 21, 2.98, 4.29, 'Medium')
# ('187e69c9-73d5-400d-b648-a5f223c0119e', "Pizza Talia's", 13.16, 4.2, 27, 3.06, 4.3, 'Medium')
# ('508d1519-7c58-4ee2-9d04-629071ff17ea', 'Chulo', 10.94, 4.5, 13, 2.54, 4.3, 'Medium')
# ('bd137a40-f7a7-4fe1-b0da-e4a8df638612', 'Balls & Glory - Mechelen', 10.79, 4.3, 14, 2.51, 4.3, 'Medium')
# ('c7ab4139-00c0-497c-8f0c-9739bc146252', 'BAVET - Hasselt', 12.12, 4.7, 15, 2.82, 4.3, 'Medium')
# ('6342e219-d712-4591-b761-ba9c10deee10', 'Matiate Kinepolis', 10.82, 3.6, 23, 2.51, 4.31, 'Medium')
# ('b9657bfa-0c3b-4e7b-bb20-e64ed11666e8', 'Take-a-Thai', 13.95, 4.3, 30, 3.23, 4.33, 'Medium')
# ('9b21f3b5-1ac5-4e3f-b404-b24f31ce4e4b', 'BOKER TOV - Markgrave', 16.51, 4.6, 48, 3.81, 4.34, 'Medium')
# ('52ea5d10-e04a-4596-81b4-a40afc683735', 'La Rustica', 13.66, 4.3, 27, 3.14, 4.35, 'Medium')
# ('56a56259-512a-45b2-b046-5331a8ce9646', 'La Trinacria', 17.65, 4.3, 160, 4.05, 4.36, 'Medium')
# ('2e33ed00-1149-5996-9da3-e411b70e4ac2', 'Ristorante La Penisola', 12.66, 4.6, 17, 2.9, 4.37, 'Medium')
# ('22d2b31a-c75d-4b10-ba1e-644c408ac369', 'Takumi Japanse Noodle Bar ', 12.96, 4.7, 17, 2.96, 4.38, 'Medium')
# ('44b8644c-d7da-4fd8-8d36-372c427a9090', 'Pizza Trenti Schoten', 12.83, 4.2, 23, 2.93, 4.38, 'Medium')
# ('ec9a011a-e5b1-4740-a2b7-d279d97594a1', 'Sushi Katelijne', 14.15, 4.3, 30, 3.23, 4.39, 'Medium')
# ('99e62d5c-6f7c-5209-95a4-7c66558333f7', 'Little BÃšN - MAS', 13.63, 4.5, 22, 3.09, 4.41, 'Medium')
# ('156719b2-bd3c-41f0-8456-7606097e8018', 'Rai Sushi & Wok', 12.13, 4.7, 14, 2.74, 4.42, 'Medium')
# ('f1796cb9-5ac7-49fd-ad0e-6beb4488f28b', 'Dolce e Salato', 12.27, 4.5, 16, 2.77, 4.43, 'Medium')
# ('2d37062e-56d4-40e0-8496-c166b66ec76d', 'India Palace', 12.56, 4.4, 18, 2.83, 4.44, 'Medium')
# ('c2cf3d54-9166-4e9b-9a14-8bb7c5f2fd61', ' Thai Smile', 11.39, 4.4, 14, 2.57, 4.44, 'Medium')
# ('e8010719-59ee-4145-b5a6-d0de7389010e', 'Ellis - Mechelen', 11.25, 3.8, 20, 2.53, 4.44, 'Medium')
# ('c5543147-c436-537d-ac15-6127e234112d', 'Pizza Boxx Antwerpen', 12.76, 4.3, 20, 2.87, 4.45, 'Medium')
# ('029fe76f-a690-41ed-a364-44b9ee99c820', 'Night Shop Delivery', 14.73, 4.8, 22, 3.3, 4.46, 'Medium')
# ('b5cff7a2-cd07-4157-8ba7-c50facd00783', 'Pizza Hut - Kessel-Lo', 13.54, 4.2, 26, 3.03, 4.46, 'Medium')
# ('8d1da6cb-c47d-4475-a349-b29d816bac06', 'Bella Ciao', 14.19, 4.2, 31, 3.18, 4.47, 'Medium')
# ('9ebbfc8b-beae-48ad-94ef-663b79ced81b', 'Wiseguys', 12.39, 4.4, 17, 2.77, 4.47, 'Medium')
# ('a473f47e-ca45-5e4c-b968-790ee038593b', "Luigi's", 16.38, 4.5, 44, 3.67, 4.47, 'Medium')
# ('9ce828d1-6e86-5417-8db9-5b2e2ea37e16', 'Kefi taverna', 14.74, 4.2, 36, 3.29, 4.48, 'Medium')
# ('56274f41-bf4c-4643-9437-ad558f430401', 'La Carretta', 17.78, 4.5, 72, 3.95, 4.5, 'Medium')
# ('edd197f8-07d2-49e4-a3df-b84733e1c49c', 'La Piazza', 14.5, 4.5, 25, 3.21, 4.51, 'Medium')
# ('829ce749-bdc9-4f43-a14b-3eefd22efeb9', 'Da Giovanni - Center', 15.9, 4.1, 60, 3.51, 4.52, 'Medium')
# ('974b5fa6-0382-437c-bdcf-3fd2bcb733df', 'Pici', 12.64, 4.2, 20, 2.8, 4.52, 'Medium')
# ('f7675cff-9841-4c63-9eb0-72ecfb2b4f81', 'Pizza Hut - Kortrijk', 13.54, 4.3, 23, 3.0, 4.52, 'Medium')
# ('bcc74dad-056b-550a-9b17-9d6941b8d202', 'Avanti Pizza Genval', 11.14, 3.9, 17, 2.46, 4.54, 'Medium')
# ('8819e152-362b-5db5-8945-319620138027', 'Sushi Hungry Eye', 10.85, 3.7, 18, 2.38, 4.56, 'Medium')
# ('c2044975-f805-4712-bad5-81524c590643', 'Unique Asia', 10.84, 3.7, 18, 2.38, 4.56, 'Medium')
# ('e1eb55cd-30ad-4244-9c7b-bee3a457bc37', "Judy's Lobster Shack", 15.43, 4.7, 25, 3.36, 4.6, 'Medium')
# ('f5781028-057b-547c-8252-66e5339b60fb', 'Munis Restaurant', 11.71, 4.5, 13, 2.54, 4.6, 'Medium')
# ('13d29e36-62f7-4262-8a76-51c7e5b4497d', 'De Gekroonde Hoofden - Aalst', 15.07, 4.9, 20, 3.27, 4.61, 'Medium')
# ('d57c3a7e-488f-4c04-a091-32f607440086', 'Nimmanhaemin', 18.04, 4.7, 50, 3.92, 4.61, 'Medium')
# ('75f3b649-bdba-5865-9e77-118ec77ca357', 'BoeÌˆna', 17.31, 4.6, 43, 3.73, 4.64, 'Medium')
# ('0d66ee0d-2cc4-472c-add0-a283eae5a8af', 'Jilles Beer & Burgers Zuid', 10.27, 3.9, 13, 2.2, 4.66, 'Medium')
# ('d16a9c69-24d2-40c1-93c2-b95495392ec7', 'Pizza Viaaa', 11.42, 4.2, 14, 2.45, 4.66, 'Medium')
# ('d0960a37-4bcb-4aba-bef8-20d266bb3518', 'Mister Spaghetti - Aalst', 14.51, 4.3, 26, 3.11, 4.67, 'Medium')
# ('50efce2a-7f48-4b03-847e-f10cef988c5d', 'La Dolce Vita', 17.11, 4.3, 57, 3.66, 4.68, 'Medium')
# ('765cd8ca-82bf-4796-af3b-c6abd19fce18', 'La trattoria Italiana', 13.96, 4.4, 21, 2.98, 4.68, 'Medium')
# ('4da8f001-e159-47a8-babc-300e7043f0b9', 'Pizza Hut - Palinghuizen', 13.54, 4.2, 22, 2.89, 4.69, 'Medium')
# ('fd3cc8e7-2998-4fc1-9561-6f86c9a89f26', 'Ekersushi', 12.7, 4.4, 16, 2.71, 4.69, 'Medium')
# ('bbd5396a-c5fa-4cba-ab87-fa431dd62918', 'Pizza Planet', 11.32, 4.6, 11, 2.41, 4.7, 'Medium')
# ('503e0832-e4e1-4227-bd02-083f58c183ae', 'Balls & Glory - Leuven', 11.31, 4.8, 10, 2.4, 4.71, 'Medium')
# ('d8088dcb-a12b-4c51-803d-f9a51de615f8', 'China Meal', 15.76, 4.3, 35, 3.34, 4.71, 'Medium')
# ('9cbc75a4-5b57-5fff-ae77-dbfebc3381fa', 'Pa Pa Pasta', 10.05, 2.7, 37, 2.13, 4.73, 'Medium')
# ('8e22d419-b377-5578-8059-1011eb6fe8c2', "L'Ananas", 12.15, 4.7, 12, 2.56, 4.74, 'Medium')
# ('7704c6c0-2872-5860-b5d0-efe2cca368dc', 'Lou Soleou - Waterloo', 15.64, 4.7, 23, 3.28, 4.77, 'Medium')
# ('c632d0b7-3a62-5ae4-8707-ffa8e80b228c', 'Sushi poel', 11.69, 4.9, 10, 2.45, 4.77, 'Medium')
# ('d0e5c64f-4089-4d1d-b4be-d514de489c68', 'La Rosa Blu Pizzeria Ristorante', 14.11, 4.6, 18, 2.96, 4.77, 'Medium')
# ('40949220-4ff1-4b5e-b998-1b8c7a1b242d', 'Rosso Forno', 13.38, 4.8, 14, 2.8, 4.78, 'Medium')
# ('4650c416-5903-48aa-b3a1-dcd0f417a6f0', 'Le Baron', 16.27, 4.4, 34, 3.4, 4.78, 'Medium')
# ('c15f1ff6-ecd8-45b1-afae-ac52b83772ad', 'Deluxe Burger', 12.04, 4.6, 12, 2.51, 4.8, 'Medium')
# ('a599154a-36e8-4696-851b-09c13e13bd26', 'Sushi Sawara', 13.73, 4.1, 23, 2.86, 4.81, 'Medium')
# ('c85b4003-1242-4644-980c-c64046c44de9', 'Eight Sushi', 16.22, 4.5, 30, 3.38, 4.81, 'Medium')
# ('ee19b71f-a969-52c2-a2b3-248c0d715c5a', 'Churrascaria do miao', 16.09, 4.8, 23, 3.35, 4.81, 'Medium')
# ('067e6fc6-312e-475f-a466-8d64babec5de', 'Flavours of India', 12.66, 4.0, 19, 2.62, 4.83, 'Medium')
# ('8cf728b4-bfda-5e3c-9650-c955f8216504', 'Epicuro', 16.69, 4.3, 41, 3.46, 4.83, 'Medium')
# ('4be62ba7-4f5f-5479-90d7-4ef8b7ecb274', 'KingRibs - Sint-Niklaas', 10.72, 3.9, 13, 2.2, 4.86, 'Medium')
# ('d80c583c-7138-4af6-a475-7e4cd01c92c4', 'PIDEM', 12.2, 3.5, 25, 2.5, 4.88, 'Medium')
# ('82fabd33-bd8a-4e52-8473-62d9ed0ec6cf', 'Kaiso Sushi', 13.25, 4.4, 16, 2.71, 4.89, 'Medium')
# ('b0fc4e50-eb89-5ee4-8850-099d93b85cc6', 'Sushi Royal', 12.65, 4.3, 15, 2.58, 4.9, 'Medium')
# ('0653d6b2-007d-43b6-85a5-a6a20d1937fd', 'Da Giovanni - Eilandje', 15.43, 4.4, 25, 3.14, 4.91, 'Medium')
# ('6c0d8129-fd77-4459-861b-640ed75dbf53', 'Pasta Ruffo', 12.34, 4.8, 11, 2.51, 4.91, 'Medium')
# ('8a9db627-60e5-4bc7-a958-5dc67594f87e', 'Collina 2 go', 13.28, 4.6, 14, 2.68, 4.95, 'Medium')
# ('90ad2f20-454e-496c-84d7-4f20cf8dd4e4', 'Tomi Sushi', 14.96, 4.4, 22, 3.03, 4.95, 'Medium')
# ('4b45df9e-33fa-4549-880f-dd1e3f9be94c', 'Thai CafÃ© - Mechelen', 14.52, 3.9, 30, 2.92, 4.96, 'Medium')
# ('74a1f83e-26e3-4256-b788-a4c2fd7fde02', 'Capital 88', 16.57, 4.2, 39, 3.34, 4.96, 'Medium')
# ('32a2d1b9-087d-4db6-bc66-2d8c507d5b56', 'Pizzeria Margarita', 11.68, 4.7, 10, 2.35, 4.97, 'Medium')
# ('1fd75fa6-d621-4d44-874b-34e2ea20cf17', 'Ping', 13.73, 4.6, 15, 2.76, 4.98, 'Medium')
# ('6166b326-3be7-4047-a9a4-572414cc0d07', 'Pizzeria Number One', 11.47, 4.6, 10, 2.3, 4.99, 'Medium')
# ('1fd8b259-fa01-4cc5-a6fd-c79270d166a1', 'Sushi Antwerpen ', 14.1, 3.5, 41, 2.81, 5.01, 'Medium')
# ('362fe710-c404-4eae-9ec6-93b795b53ee5', "pizzatalia's concept", 13.27, 3.8, 23, 2.65, 5.01, 'Medium')
# ('5fae08d8-3dad-491c-902f-e1251a603e14', 'Lucy Chang - Brasschaat', 13.25, 4.3, 16, 2.65, 5.01, 'Medium')
# ('a08ceb14-3ef8-47f0-91ae-2589e8016722', 'Pizza Pronto Salvatore', 11.73, 3.9, 15, 2.34, 5.01, 'Medium')
# ('f23eda80-7ac8-47bf-b590-d59336a8dace', 'Campus & Fratelli', 10.84, 3.3, 19, 2.16, 5.01, 'Medium')
# ('67072f44-b0db-4d15-bbfe-a7ca0f83afef', 'Tontons', 22.33, 4.8, 124, 4.44, 5.03, 'High')
# ('24d6dde7-2790-4019-90bc-9e706f6217aa', 'Miss Yu', 12.85, 4.5, 13, 2.54, 5.05, 'Medium')
# ('63266ec9-5a69-422c-ac24-77ed7ae8c07e', 'Pizza Hut - Deurne zuid', 13.54, 3.8, 24, 2.68, 5.05, 'Medium')
# ('149333b7-eaf5-4387-b03f-0f04427eaefe', 'K&B - Kitchen & Bar at Courtyard', 13.16, 4.6, 13, 2.6, 5.06, 'Medium')
# ('664ef302-0133-4cba-9c45-89c5ac567156', 'Sushi Paradise', 12.59, 4.4, 13, 2.49, 5.06, 'Medium')
# ('a88f124e-7d54-47ee-82bb-ef5bd05dd1fa', 'SANGEETHA VEG', 10.63, 3.5, 15, 2.1, 5.06, 'Medium')
# ('01145c8b-0365-4568-8ebb-14d3c6274808', 'Sumac', 19.71, 4.3, 94, 3.89, 5.07, 'Medium')
# ('f84b9138-d14b-4b18-8402-26934eaecab0', 'Sushi Point', 16.25, 4.6, 23, 3.21, 5.07, 'Medium')
# ('81ad5e79-420c-4ce7-81d5-3ba0f5725bb0', 'Pizza Hut - Mechelen', 13.54, 3.5, 32, 2.67, 5.08, 'Medium')
# ('114ff01b-321a-45e6-a707-e32ce67fd739', 'Golden Dragon', 14.66, 3.6, 40, 2.88, 5.09, 'Medium')
# ('19a54486-fb7b-46a9-a43b-9a1627679284', 'Les Enfants du PirÃ©e', 17.99, 4.8, 28, 3.54, 5.09, 'Medium')
# ('38288aee-30a7-53f5-9d85-31b29d616c36', 'JB Sushi Bar and wok', 12.1, 4.2, 13, 2.37, 5.1, 'Medium')
# ('cea64248-9852-42c8-b433-32b10dd9f8fa', 'Tikka N Talk', 10.96, 3.8, 13, 2.15, 5.1, 'Medium')
# ('3743b36d-125c-4ec4-b03b-e41ada377a39', 'Domus', 15.71, 4.6, 20, 3.07, 5.12, 'Medium')
# ('de7627a4-0c48-523f-8a7c-083bef9b8074', 'Pizza Fresca - WoluwÃ©', 16.93, 4.3, 33, 3.3, 5.13, 'Medium')
# ('5cd0e2a6-3fc3-4d86-a8ed-a29b7d054dd4', 'YOKOSO', 20.22, 4.5, 70, 3.94, 5.14, 'High')
# ('d4cd8901-df8f-47e5-b6a0-da9bf57f1443', "L'Arlecchino Pizzeria & Cucina", 19.36, 4.6, 45, 3.76, 5.14, 'Medium')
# ('8245c0f3-b591-4b9a-8645-0ff1a7c1538b', 'Diamond Pizza Berchem', 13.27, 4.4, 14, 2.57, 5.17, 'Medium')
# ('23d89b53-233e-408c-97f5-8c475f4a78c9', 'Ramen Bambu ', 12.76, 4.7, 11, 2.46, 5.18, 'Medium')
# ('2a90bd59-cf71-41e1-bb5d-7d9dd6429e85', 'Annapurna', 13.88, 4.9, 12, 2.67, 5.19, 'Medium')
# ('db3071d0-f7ac-4ca5-9e06-a6be04b00ec0', "Les Baguettes d'Or", 15.21, 4.3, 21, 2.91, 5.22, 'Medium')
# ('8e591697-e009-4b72-be44-f51bc492ac3a', 'Soroki Sushi Kessel-Lo', 11.28, 4.3, 10, 2.15, 5.25, 'Medium')
# ('76abc458-0965-444a-a8f9-5ad7b812907d', 'Kai Thai', 15.17, 4.4, 19, 2.88, 5.26, 'Medium')
# ('ea04e73f-57e6-4581-8d0b-b05c544daf9b', 'De Appel', 13.92, 4.2, 17, 2.64, 5.26, 'Medium')
# ('9be57c54-3151-40c9-888a-ce7ac0e9fa46', 'Jilles Beer & Burgers - Oostende', 10.27, 3.9, 10, 1.95, 5.27, 'Medium')
# ('abd148e3-0bc9-55da-b551-0fa7011442c5', 'Wok Box', 14.31, 3.8, 25, 2.71, 5.27, 'Medium')
# ('e9092772-aa5f-4b52-9f42-0c8b5c445f70', 'La Brochette du Chalet', 14.35, 4.5, 15, 2.7, 5.31, 'Medium')
# ('2c9aea17-37d1-46f6-9dad-39f3f2cbde74', 'MARE E MONTI', 19.07, 4.2, 58, 3.58, 5.32, 'Medium')
# ('dbaef85b-3b89-4c66-812e-d37b6d33a169', 'Pizza king', 12.78, 4.4, 12, 2.4, 5.33, 'Medium')
# ('dd742bf9-b4cf-4da8-ab5a-c5a26a332536', 'So Sushi - Kraainem', 11.81, 3.6, 16, 2.22, 5.33, 'Medium')
# ('5e8754f8-0c09-4aeb-9655-52d3eae7bfac', 'Tsuru Sushi', 14.2, 4.1, 18, 2.64, 5.39, 'Medium')
# ('6dc6a308-026c-49b4-9681-03611eb82192', 'Le Belle-Vue', 12.75, 4.5, 11, 2.36, 5.41, 'Medium')
# ('b3bd983d-3188-44db-b9a7-595e3641c073', 'Pizza Verdi', 11.39, 4.0, 11, 2.1, 5.44, 'Medium')
# ('7255e7a2-247e-4690-9923-74fff09ea54c', 'Feta & Oregano ', 15.86, 4.7, 16, 2.89, 5.48, 'Medium')
# ('ea754bb7-0a61-5e01-ae4f-5720d249fd1d', 'La Trinacria', 16.73, 3.5, 67, 3.05, 5.49, 'Medium')
# ('39d8a2bb-af06-4b3c-abd7-d0417e1a0324', 'Il Fuoco', 14.75, 4.9, 12, 2.67, 5.52, 'Medium')
# ('a285dca2-955b-430b-99e0-6a78d8cf3938', "Mag's Burgerbar", 17.19, 4.6, 21, 3.12, 5.52, 'Medium')
# ('4e14f9cc-8611-4813-9d9b-9612290ac6fe', 'LucMoon', 14.95, 4.2, 18, 2.7, 5.54, 'Medium')
# ('cf718471-7e25-4956-9be1-f1f6d10b7d2e', 'Restaurant & Pizzeria Regina', 19.28, 4.4, 37, 3.46, 5.57, 'Medium')
# ('8b1d0698-d59e-5f96-a8d1-4cbe4b4a3e99', 'Sushi Royal Tokyo Borsbeek', 14.34, 4.4, 14, 2.57, 5.59, 'Medium')
# ('d93f210a-6736-499e-95d4-5cd2d3c572fd', 'Nuova Era', 19.43, 4.1, 56, 3.48, 5.59, 'Medium')
# ('70b21c5d-afa0-488f-a0e3-9473dd745bc6', 'Ellis - Hasselt', 11.25, 4.0, 10, 2.0, 5.63, 'Medium')
# ('11679965-0d4a-4a88-8086-4ae478977049', 'Thai CafÃ© - Alsemberg', 15.3, 4.5, 15, 2.7, 5.67, 'Medium')
# ('208d9822-2ad8-5e25-879f-aaf359e4cf36', 'La Pugliese', 15.23, 4.1, 19, 2.69, 5.67, 'Medium')
# ('3a465d73-f8b3-48b6-8103-7b13b4a32232', 'Himalayan Restaurant', 13.39, 4.5, 11, 2.36, 5.68, 'Medium')
# ('70bd3802-c79f-49c5-ae1a-ee3e0e01f0be', 'Restaurant Olympiade', 19.22, 4.1, 47, 3.38, 5.69, 'Medium')
# ('90bc9f37-16ca-4860-9a64-24ae279fb1d6', 'Pizza Hut - St-Kruis', 13.54, 3.7, 18, 2.38, 5.69, 'Medium')
# ('62be66b4-185d-4f4e-94e1-b3ab8f7a147f', 'Le ParthÃ©non', 13.53, 4.2, 13, 2.37, 5.7, 'Medium')
# ('c5be20bc-29a5-4f53-869e-8d82fa4b9fd8', 'De Bomma', 17.8, 4.6, 21, 3.12, 5.71, 'Medium')
# ('a254e822-238b-46b6-bf9c-666361235c14', 'Zuru Zuru Ramen', 14.4, 4.6, 12, 2.51, 5.74, 'Medium')
# ('0ecde79f-1a67-4483-9e5e-feb16a6681ab', 'Tomo Sushi', 14.7, 4.5, 13, 2.54, 5.78, 'Medium')
# ('180af33b-2020-4e37-aeec-cbdba94c505a', 'Thai CafÃ© - Hasselt', 14.55, 4.2, 15, 2.52, 5.78, 'Medium')
# ('ff3ec629-57cd-495b-abec-21accc33ab47', 'Frederiksborg', 14.18, 4.2, 14, 2.45, 5.79, 'Medium')
# ('d8b4b3cf-1464-4cee-bc7e-b13c83746761', 'Pita pocket', 10.96, 3.0, 17, 1.89, 5.8, 'Medium')
# ('fe206dd5-36cd-58df-b148-e19a6a0acca1', 'Indian Thai Resto', 13.33, 3.8, 15, 2.28, 5.85, 'Medium')
# ('a2c6762c-5432-4e73-bad6-7d39dd879b57', 'Da Basilico', 20.77, 4.5, 37, 3.54, 5.86, 'High')
# ('9cad7e27-07bc-4fd7-97c0-b92ebfb3bed2', 'Il Sorrento', 18.55, 4.2, 30, 3.15, 5.89, 'Medium')
# ('b477235b-107a-4399-9987-9d76bbc651d3', 'Ristorante San Marco 100%', 16.06, 3.9, 23, 2.72, 5.91, 'Medium')
# ('c3e24342-aff1-466e-9798-1f71873f1dd7', 'Greenway - Gent', 16.77, 4.5, 17, 2.83, 5.92, 'Medium')
# ('4a1cf0d3-5f79-4a63-aa12-116bd1f52e03', 'BOKER TOV - Eilandje', 14.23, 4.0, 15, 2.4, 5.93, 'Medium')
# ('ba6b26fc-76c2-473e-96a7-7052fbf5b5fa', 'Le Mounier', 17.56, 4.8, 16, 2.95, 5.95, 'Medium')
# ('bdc5d004-8c75-4e3d-b29e-42ed18fc3f27', 'Greenway - Leuven', 15.42, 4.3, 15, 2.58, 5.98, 'Medium')
# ('8234cf5c-8dd9-4707-bacb-bbc0a2ac8e6b', 'Nam Fong', 14.85, 3.6, 22, 2.48, 6.0, 'Medium')
# ('40b7e125-e719-5197-ac5e-5d86a87b1b60', 'Kap ou pas Kap Salon', 12.75, 3.5, 15, 2.1, 6.07, 'Medium')
# ('9ccdc19a-088f-5e05-82c8-7bb72c27fc6e', 'One Thai', 15.67, 4.4, 14, 2.57, 6.11, 'Medium')
# ('85bae12b-e36f-524c-be41-75ef56ab1705', 'Swatow', 18.43, 4.3, 23, 3.0, 6.15, 'Medium')
# ('742a1a40-e864-44d1-839f-6b0c99abb6b0', 'Tokyo sushi', 14.26, 4.6, 10, 2.3, 6.2, 'Medium')
# ('357cf2d2-1ddd-46a4-898b-21fa1a7922c4', 'La Monte Carlo - City', 12.92, 3.8, 12, 2.07, 6.23, 'Medium')
# ('3792f57e-feae-4e44-831d-a1859a04f091', 'Osteria Michele ', 22.34, 4.0, 71, 3.51, 6.37, 'High')
# ('3a57429a-b764-5fd9-80a6-34a5ac356109', 'Mr spare ribs', 15.71, 4.7, 11, 2.46, 6.38, 'Medium')
# ('5ae246f9-6503-44d8-af6a-cf1f20d47734', 'Afrosian', 16.95, 3.9, 21, 2.64, 6.41, 'Medium')
# ('c34f3f47-9fb5-4aa2-b708-8c10462abd12', 'Villa La Dolce Vita', 14.79, 4.4, 11, 2.3, 6.42, 'Medium')
# ('b71f9699-f4b3-4f75-925b-fcb4c9ccf3f3', 'Royal Lebanon', 15.85, 4.1, 15, 2.46, 6.44, 'Medium')
# ('afca00c5-7921-4ed7-ad49-1c5f4e395fcf', 'Moon House', 18.5, 4.1, 23, 2.86, 6.48, 'Medium')
# ('717e020c-5a90-4cb6-a92a-dbb1c575d1e2', 'Thai CafÃ© - Knokke', 14.88, 4.2, 12, 2.29, 6.5, 'Medium')
# ('8aa9c671-e583-5492-8a92-219d05b90e35', 'Burger District', 12.87, 3.5, 13, 1.98, 6.5, 'Medium')
# ('52da80d0-6f0f-47cb-acb8-226eda3e7c2e', 'Pizzeria-La Fornaccia ', 13.52, 3.8, 12, 2.07, 6.52, 'Medium')
# ('59ab9660-337d-47c6-a028-be727729e9b3', 'Osaka Sushi Takeaway', 11.79, 2.8, 18, 1.8, 6.55, 'Medium')
# ('d881e941-fea7-4eed-b6f4-82b5c72e1f85', 'Burgerij - Eilandje', 10.51, 3.2, 10, 1.6, 6.57, 'Medium')
# ('f330b5f7-687c-5411-b858-af6380a8dd9e', 'Ristorante-Pizzeria Milano', 18.0, 4.5, 15, 2.7, 6.67, 'Medium')
# ('6d0d38a0-919e-4145-b511-539c8081a3e2', 'Pizza@Home', 10.61, 3.0, 11, 1.57, 6.75, 'Medium')
# ('02165a21-8c30-4d06-bc0c-92f5831da786', 'Pizza Service', 11.09, 2.9, 13, 1.64, 6.76, 'Medium')
# ('1ebe9a21-cd58-455c-9542-55f0144dd019', 'Open Wok', 14.91, 4.1, 11, 2.15, 6.94, 'Medium')
# ('9fb53636-6737-4000-b95e-3ccc994bca14', 'Brasserie Mykonos', 19.66, 4.5, 17, 2.83, 6.94, 'Medium')
# ('2bd1fe79-9089-4e05-b348-00cfad2d4c2a', 'Thai Zen', 14.97, 4.3, 10, 2.15, 6.96, 'Medium')
# ('a667125b-6c6d-50c6-b5e4-641bd029068f', 'Restaurant Cleopatra', 12.04, 3.4, 10, 1.7, 7.08, 'Medium')
# ('339705ab-b2cc-44ed-935a-ea86de7881ab', 'Tangthai', 18.61, 4.5, 14, 2.63, 7.09, 'Medium')
# ('c5cb36d9-5501-5be1-b20f-41ac58e51fc1', 'Mamma Roma - Gent Korenmarkt', 15.47, 3.8, 13, 2.15, 7.2, 'Medium')
# ('8ae26dde-5286-4725-ac6a-00bac4bf7f89', 'La Lumaca', 14.78, 4.0, 10, 2.0, 7.39, 'Medium')
# ('01acb7b4-ed67-425d-bb99-897f8f4bf6a3', 'Twins Tavern', 17.62, 4.2, 13, 2.37, 7.42, 'Medium')
# ('f432a69e-6562-4c75-ad96-d1db968c2ffd', 'Olympia', 17.51, 4.5, 11, 2.36, 7.43, 'Medium')
# ('e5bf561b-5408-4ea9-95db-0f9ba4098097', 'AmunÃ¬', 14.88, 4.0, 10, 2.0, 7.44, 'Medium')
# ('e393d737-2f4f-47b2-9942-5ad13feea578', 'Loui Sushi - Halle', 14.04, 3.7, 10, 1.85, 7.59, 'Medium')
# ('365c5af3-89ab-5641-92f8-8be8a716ce95', 'Ciao Pizza ', 19.48, 4.7, 12, 2.56, 7.6, 'Medium')
# ('e3c3877f-f95d-5e93-bbaf-bb58b9c55bbb', 'Villa Lâ€™aurora', 17.97, 4.7, 10, 2.35, 7.65, 'Medium')
# ('dd3bfe14-102e-402e-a004-ae9afb882679', 'Brasserie Heydenberg', 20.99, 4.8, 13, 2.71, 7.74, 'High')
# ('44fb695f-8321-4c3e-99a8-39836de2b6da', 'Via Vai', 18.29, 3.9, 15, 2.34, 7.81, 'Medium')
# ('2502b140-107d-4caf-9d54-01859974a7c4', 'Lebnan ', 25.63, 4.6, 22, 3.16, 8.11, 'High')
# ('89415989-578f-4ae1-94f2-220bdb6bd8b5', 'Triangolo', 17.16, 3.6, 14, 2.1, 8.17, 'Medium')
# ('7ee3e327-b00f-4bdf-a89f-cf26b6261b98', 'Everest Gurkha', 15.48, 3.7, 10, 1.85, 8.37, 'Medium')
# ('dd8d6e93-0502-4cd6-b519-cd9694980270', 'Krua Thai', 16.08, 3.6, 10, 1.8, 8.93, 'Medium')
